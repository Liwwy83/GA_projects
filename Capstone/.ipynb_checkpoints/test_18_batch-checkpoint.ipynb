# %%
import pandas as pd

# %%
GCEA2019 = pd.read_csv('input_data/GCEA 2019.csv', index_col='NEWID')
GCEA2019
# Out:
#           MA2  FM2  MA1 MA3-MOE
# NEWID
# 20180001    A  NaN  NaN     NaN
# 20180002    A  NaN  NaN     NaN
# 20180003    A  NaN  NaN     NaN
# 20180004  NaN  NaN  NaN     NaN
# 20180005    A  NaN  NaN     NaN
# ...       ...  ...  ...     ...
# 20181150    A  NaN  NaN     NaN
# 20181151    A  NaN  NaN     NaN
# 20181152    B  NaN  NaN     NaN
# 20181153    D  NaN  NaN     NaN
# 20181154    C  NaN  NaN     NaN
#
# [1154 rows x 4 columns]

# %%
GCEA2020 = pd.read_csv('input_data/GCEA 2020.csv', index_col='NEWID')
GCEA2020

# %%
GCEA2019.value_counts('MA2')

# %%
GCEA2019.value_counts('MA2',normalize=True)

# %%
GCEA2019.isna().sum()

# %%
GCEA2020.value_counts('MA2')

# %%
GCEA2020.value_counts('MA2', normalize=True)

# %%
Prelim2020 = pd.read_csv('input_data/2020 Prelim.csv', index_col='NEWID')
Prelim2020

# %%
Prelim2019 = pd.read_csv('input_data/2019 Prelim.csv', index_col='NEWID')
Prelim2019
# Out:
#          GENDER  PSLE REPEAT                  INTAKE  \
# NEWID
# 20180001      M   260    NaN                IP (HCI)
# 20180002      F   253    NaN  JAE Ordinary Admission
# 20180003      F   262    NaN               IP (NYGH)
# 20180004      F   242    NaN  JAE Ordinary Admission
# 20180005      M   237    NaN  JAE Ordinary Admission
# ...         ...   ...    ...                     ...
# 20181150      M   263    NaN                IP (HCI)
# 20181151      M   248    NaN                IP (HCI)
# 20181152      F   246    NaN  JAE Ordinary Admission
# 20181153      F   259    NaN               IP (NYGH)
# 20181154      M     0    NaN  JAE Ordinary Admission
#
#                                    SEC SCHOOL PW   GP   KI KI (H)  MA2  ...  \
# NEWID                                                                   ...
# 20180001  HWA CHONG INSTITUTION (HIGH SCHOOL)  A    B  NaN    NaN    A  ...
# 20180002  METHODIST GIRLS' SCHOOL (SECONDARY)  A    C  NaN    NaN    A  ...
# ...

# %%
Prelim2021 = pd.read_csv('input_data/2021 Prelim.csv', index_col='NEWID')
Prelim2021

# %%
test2019 = Prelim2019[['MA2','PTS']].join(GCEA2019[['MA2']], rsuffix='GCEA')

# %%
Prelim2019.merge(GCEA2019, on='NEWID')
# Out:
#          GENDER  PSLE REPEAT                  INTAKE  \
# NEWID
# 20180001      M   260    NaN                IP (HCI)
# 20180002      F   253    NaN  JAE Ordinary Admission
# 20180003      F   262    NaN               IP (NYGH)
# 20180004      F   242    NaN  JAE Ordinary Admission
# 20180005      M   237    NaN  JAE Ordinary Admission
# ...         ...   ...    ...                     ...
# 20181150      M   263    NaN                IP (HCI)
# 20181151      M   248    NaN                IP (HCI)
# 20181152      F   246    NaN  JAE Ordinary Admission
# 20181153      F   259    NaN               IP (NYGH)
# 20181154      M     0    NaN  JAE Ordinary Admission
#
#                                    SEC SCHOOL PW   GP   KI KI (H) MA2_x  ...  \
# NEWID                                                                    ...
# 20180001  HWA CHONG INSTITUTION (HIGH SCHOOL)  A    B  NaN    NaN     A  ...
# 20180002  METHODIST GIRLS' SCHOOL (SECONDARY)  A    C  NaN    NaN     A  ...
# ...

# %%
GCEA2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154 entries, 0 to 1153
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   NEWID    1154 non-null   int64
#  1   MA2      1097 non-null   object
#  2   FM2      12 non-null     object
#  3   MA1      41 non-null     object
#  4   MA3-MOE  33 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 45.2+ KB

# %%
Prelim2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154 entries, 0 to 1153
# Data columns (total 57 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NEWID       1154 non-null   int64
#  1   GENDER      1154 non-null   object
#  2   PSLE        1154 non-null   int64
#  3   REPEAT      4 non-null      object
#  4   INTAKE      1154 non-null   object
#  5   SEC SCHOOL  1154 non-null   object
#  6   PW          1154 non-null   object
#  7   GP          1096 non-null   object
#  8   KI          30 non-null     object
#  9   KI (H)      28 non-null     object
#  10  MA2         1097 non-null   object
#  11  FM2         12 non-null     object
#  12  CP2         53 non-null     object
#  13  PH2         498 non-null    object
#  14  CH2         902 non-null    object
#  15  BY2         444 non-null    object
#  16  EL2         89 non-null     object
#  17  EL2 (H)     57 non-null     object
#  18  ELL2        15 non-null     object
# ...
