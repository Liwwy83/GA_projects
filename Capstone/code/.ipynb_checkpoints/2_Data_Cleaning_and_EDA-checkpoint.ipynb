# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import KNNImputer

plt.rcParams['figure.figsize'] = [16,8]
plt.style.use('fivethirtyeight')

# %% [markdown]
# # (1) Target - A Level Grades

# %%
# load target, only MA2 (H2 Math) ignore other subjects FM2, MA1 and MA3-MOE
GCEA_18 = pd.read_csv('../data_raw/18 Batch GCEA.csv', usecols=['NEWID','MA2'], index_col='NEWID')
GCEA_19 = pd.read_csv('../data_raw/19 Batch GCEA.csv', usecols=['NEWID','MA2'], index_col='NEWID')

display(GCEA_18.head())
print('Batch 18')

display(GCEA_19.head())
print('Batch 19')
# Out:
#           MA2
# NEWID
# 20180001    A
# 20180002    A
# 20180003    A
# 20180004  NaN
# 20180005    A
# Batch 18
#          MA2
# NEWID
# 20190001   B
# 20190002   A
# 20190003   A
# 20190004   B
# 20190005   C
# Batch 19

# %%
# check number of rows, no duplicates in 'NEWID' and number of students who did not take MA2
print(' Batch 18 '.center(34, "="))
print(f"Number of rows: {GCEA_18.shape[0]}")
print(f"Number of unique IDs: {GCEA_18.index.nunique()}")
print(f"Number of students without MA2: {GCEA_18['MA2'].isna().sum()}")

print()

print(' Batch 19 '.center(34, "="))
print(f"Number of rows: {GCEA_19.shape[0]}")
print(f"Number of unique IDs: {GCEA_19.index.nunique()}")
print(f"Number of students without MA2: {GCEA_19['MA2'].isna().sum()}")
# Out:
# ============ Batch 18 ============
# Number of rows: 1154
# Number of unique IDs: 1154
# Number of students without MA2: 57
#
# ============ Batch 19 ============
# Number of rows: 1099
# Number of unique IDs: 1099
# Number of students without MA2: 35

# %%
# save indices to remove rows without from datasets
ind_to_del_18 = GCEA_18[GCEA_18['MA2'].isna()].index
ind_to_del_19 = GCEA_19[GCEA_19['MA2'].isna()].index

# drop students who did not take MA2
GCEA_18.drop(index=ind_to_del_18, inplace=True)
GCEA_19.drop(index=ind_to_del_19, inplace=True)

# frequency of grades
print('Batch 18')
print(GCEA_18.value_counts().sort_index())
print()
print('Batch 19')
print(GCEA_19.value_counts().sort_index())
# Out:
# Batch 18
# MA2
# A      851
# B      149
# C       70
# D       20
# E        4
# S        1
# U        2
# dtype: int64
#
# Batch 19
# MA2
# A      814
# B      159
# C       64
# D       19
# E        7
# S        1
# dtype: int64

# %%
# combine grades E, S, U into one category as the frequencies are very low
GCEA_18['MA2'] = GCEA_18['MA2'].map(lambda g: g if g in ['A','B','C','D'] else 'ESU')
GCEA_19['MA2'] = GCEA_19['MA2'].map(lambda g: g if g in ['A','B','C','D'] else 'ESU')

# frequency of grades
print('Batch 18')
print(GCEA_18.value_counts().sort_index())
print()
print('Batch 19')
print(GCEA_19.value_counts().sort_index())
# Out:
# Batch 18
# MA2
# A      851
# B      149
# C       70
# D       20
# ESU      7
# dtype: int64
#
# Batch 19
# MA2
# A      814
# B      159
# C       64
# D       19
# ESU      8
# dtype: int64

# %%
# plot histogram showing grade distribution
grade_cat = {'A':'Excellent', 'B':'Good', 'C':'Ok', 'D':'Ok', 'ESU':'Need Attention'}
GCEA_18['Category'] = GCEA_18['MA2'].map(grade_cat)
GCEA_19['Category'] = GCEA_19['MA2'].map(grade_cat)

fig, ax = plt.subplots(1,2)
fig.suptitle('H2 Math Grade Distribution in GCE A Levels', fontsize=28)
sns.histplot(GCEA_18.sort_values('MA2'), x='MA2', hue='Category', palette='Dark2', ax=ax[0], legend=False)
ax[0].set_title('Batch 18')
ax[0].set_xlabel('Grade')
sns.histplot(GCEA_19.sort_values('MA2'), x='MA2', hue='Category', palette='Dark2', ax=ax[1])
ax[1].set_title('Batch 19')
ax[1].set_xlabel('Grade')

plt.tight_layout();

# %% [markdown]
# ## Analysis of Grade Distribution
# The vast majority of students obtained an excellent grade of A, and a very small minority (only 7 or 8 out of more than 1000 students) either failed (grade S or U) or were very close to failing (grade E).
#
# The distribution patterns of both batches are very similar, indicating stability across batches, hence it is reasonable to build a model to make predictions for future batches as well.

# %%
# convert to numeric and export to csv
y_dict = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'ESU': 5}

y_18 = GCEA_18['MA2'].map(y_dict).rename('Target')
y_19 = GCEA_19['MA2'].map(y_dict).rename('Target')

y_18.to_csv('../data_cleaned/GCEA_18.csv')
y_19.to_csv('../data_cleaned/GCEA_19.csv')

# %% [markdown]
# # (2) Prelim Grades, Marks and Percentiles

# %%
# load Batch 18 datasets on Prelim Results
Prelim_Grades_18 = pd.read_csv('../data_raw/18 Batch Prelim Grades.csv', index_col='NEWID')
Prelim_Marks_18 = pd.read_csv('../data_raw/18 Batch Prelim Marks.csv', index_col='NEWID')
Prelim_Perc_18 = pd.read_csv('../data_raw/18 Batch Prelim Percentiles.csv', index_col='NEWID')

# load Batch 19 datasets on Prelim Results
Prelim_Grades_19 = pd.read_csv('../data_raw/19 Batch Prelim Grades.csv', index_col='NEWID')
Prelim_Marks_19 = pd.read_csv('../data_raw/19 Batch Prelim Marks.csv', index_col='NEWID')
Prelim_Perc_19 = pd.read_csv('../data_raw/19 Batch Prelim Percentiles.csv', index_col='NEWID')

# load Batch 20 datasets on Prelim Results
Prelim_Grades_20 = pd.read_csv('../data_raw/20 Batch Prelim Grades.csv', index_col='NEWID')
Prelim_Marks_20 = pd.read_csv('../data_raw/20 Batch Prelim Marks.csv', index_col='NEWID')
Prelim_Perc_20 = pd.read_csv('../data_raw/20 Batch Prelim Percentiles.csv', index_col='NEWID')

print(' Batch 20 '.center(34, "="))
# check number of rows in Batch 20
print(f"Number of rows: {Prelim_Grades_20.shape[0]}")
# check no duplicates in 'NEWID' of Batch 20
print(f"Number of unique IDs: {Prelim_Grades_20.index.nunique()}")
# number of students who did not take MA2 in Batch 20
print(f"Number of students without MA2: {Prelim_Grades_20['MA2'].isna().sum()}")
# Out:
# ============ Batch 20 ============
# Number of rows: 1057
# Number of unique IDs: 1057
# Number of students without MA2: 32

# %%
# save indices to remove rows without MA2 from datasets
ind_to_del_20 = Prelim_Grades_20[Prelim_Grades_20['MA2'].isna()].index
ind_list = [ind_to_del_18, ind_to_del_19, ind_to_del_20]

# for looping purposes
Prelim_Data = [[Prelim_Grades_18, Prelim_Marks_18, Prelim_Perc_18, Prelim_Grades_18],
               [Prelim_Grades_19, Prelim_Marks_19, Prelim_Perc_19, Prelim_Grades_19],
               [Prelim_Grades_20, Prelim_Marks_20, Prelim_Perc_20, Prelim_Grades_20],
               [Prelim_Grades_18, Prelim_Marks_18, Prelim_Perc_18, Prelim_Grades_18]
              ]
batch = [18, 19, 20, 18]
dataset_type = ['Grades', 'Marks', 'Percentiles', 'Grades']

# drop students who did not take MA2 and print shape
for i in range(3):
    print(f' Batch {batch[i]} '.center(30, "="))
    for j in range(3):
        Prelim_Data[i][j].drop(index=ind_list[i], inplace=True)
        print(f"{dataset_type[j]}: {Prelim_Data[i][j].shape}")
    print()
# Out:
# ========== Batch 18 ==========
# Grades: (1097, 56)
# Marks: (1097, 50)
# Percentiles: (1097, 50)
#
# ========== Batch 19 ==========
# Grades: (1064, 55)
# Marks: (1064, 49)
# Percentiles: (1064, 49)
#
# ========== Batch 20 ==========
# Grades: (1025, 55)
# Marks: (1025, 49)
# Percentiles: (1025, 49)

# %% [markdown]
# ## Observations
# The number of rows are correct at 1154 - 57 = 1097, 1099 - 35 = 1064 and 1057 - 32 = 1025 for Batches 18, 19 and 20 respectively.
#
# Prelim Grades dataset has 6 more columns than the corresponding Marks and Percentiles datasets of the same year. Batch 18 datasets have 1 more column than Batch 19 and Batch 20 dataset. We check the column names to find the differences.

# %%
# columns in first dataset but not in second dataset
def print_diff(df1, df2):
    print(df1.columns.difference(df2.columns).values)

for i in range(3):
    print(f" Batch {batch[i]} ".center(50, "="))
    for j in range(3):
        print(f"In {dataset_type[j]} dataset but not in {dataset_type[j+1]} dataset:")
        print_diff(Prelim_Data[i][j],Prelim_Data[i][j+1])
    print()
    
print(" Differences between Batches ".center(50, "="))
for i in range(3): 
    print(f"In Batch {batch[i]} dataset but not in Batch {batch[i+1]} dataset:")
    print_diff(Prelim_Data[i][0],Prelim_Data[i+1][0])
    print(f"In Batch {batch[i+1]} dataset but not in Batch {batch[i]} dataset:")
    print_diff(Prelim_Data[i+1][0],Prelim_Data[i][0])
    print()
# Out:
# ==================== Batch 18 ====================
# In Grades dataset but not in Marks dataset:
# ['%' 'MSG/GPA' 'MTL' 'P/F' 'PTS' 'PW.1' 'RANK']
# In Marks dataset but not in Percentiles dataset:
# []
# In Percentiles dataset but not in Grades dataset:
# ['SN']
#
# ==================== Batch 19 ====================
# In Grades dataset but not in Marks dataset:
# ['%' 'MSG/GPA' 'MTL' 'P/F' 'PTS' 'PW.1' 'RANK']
# In Marks dataset but not in Percentiles dataset:
# []
# In Percentiles dataset but not in Grades dataset:
# ['SN']
#
# ==================== Batch 20 ====================
# In Grades dataset but not in Marks dataset:
# ['%' 'MSG/GPA' 'MTL' 'P/F' 'PTS' 'PW.1' 'RANK']
# In Marks dataset but not in Percentiles dataset:
# []
# In Percentiles dataset but not in Grades dataset:
# ['SN']
#
# ========== Differences between Batches ===========
# In Batch 18 dataset but not in Batch 19 dataset:
# ['BY1' 'JP2']
# In Batch 19 dataset but not in Batch 18 dataset:
# ['CLL3-MOE']
#
# In Batch 19 dataset but not in Batch 20 dataset:
# ['EH1']
# In Batch 20 dataset but not in Batch 19 dataset:
# ['JP2']
#
# In Batch 20 dataset but not in Batch 18 dataset:
# ['CLL3-MOE']
# In Batch 18 dataset but not in Batch 20 dataset:
# ['BY1' 'EH1']

# %% [markdown]
# ## Differences in columns
# Marks and Percentiles datasets are identical with the same number of columns and an empty list for their differences. They have an additional column 'SN' that duplicates information in 'NEWID' and will be discarded.
#
# Grades dataset has 7 additional columns: 'PW.1', 'MTL', 'P/F', 'RANK', '%', 'MSG/GPA', 'PTS'. We check the Grades dataframe head to determine what these columns represent.
#
# There are some minor differences in subjects between the batches, but these subjects are rarely taken. They are H1 Biology (BY1), H1 History (EH1), H2 Japanese (JP2) and H3 CLL (CLL3-MOE). These subjects as well as other subjects with small candidatures will be merged after more exploratory data analysis as we do not want to overtrain our model.

# %%
# create columns of NaN in dataframes where subjects are missing
Prelim_Data[0][0]['CLL3-MOE'] = np.nan
Prelim_Data[1][0]['BY1'] = np.nan
Prelim_Data[1][0]['JP2'] = np.nan
Prelim_Data[2][0]['EH1'] = np.nan
Prelim_Data[2][0]['BY1'] = np.nan

# %%
# display grades dataframe head
for i in range(3):
    display(Prelim_Data[i][0].head())
    print(f'Batch {batch[i]}')
# Out:
#          GENDER  PSLE REPEAT                  INTAKE  \
# NEWID
# 20180001      M   260    NaN                IP (HCI)
# 20180002      F   253    NaN  JAE Ordinary Admission
# 20180003      F   262    NaN               IP (NYGH)
# 20180005      M   237    NaN  JAE Ordinary Admission
# 20180006      M   246    NaN  JAE Ordinary Admission
#
#                                    SEC SCHOOL PW   GP   KI KI (H) MA2  ...  \
# NEWID                                                                  ...
# 20180001  HWA CHONG INSTITUTION (HIGH SCHOOL)  A    B  NaN    NaN   A  ...
# 20180002  METHODIST GIRLS' SCHOOL (SECONDARY)  A    C  NaN    NaN   A  ...
# 20180003           NANYANG GIRLS' HIGH SCHOOL  A    C  NaN    NaN   B  ...
# 20180005             MARIS STELLA HIGH SCHOOL  B    D  NaN    NaN   C  ...
# 20180006                 CATHOLIC HIGH SCHOOL  A  NaN    A    NaN   B  ...
#
#          PW.1 MTL     P/F RANK   % MSG/GPA   PTS NO OF CCA  \
# NEWID
# 20180001    A   A  Passed  192  83     1.4  85.0         1
# 20180002    A   B  Passed  420  63     2.1  80.0         1
# 20180003    A   B  Passed  987  14     4.1  57.5         1
# 20180005    B   B  Passed  887  23     3.3  65.0         1
# 20180006    A   B  Passed   65  94     1.2  87.5         1
#
#                                                      CCA CLL3-MOE
# NEWID
# 20180001                                 SQUASH (Member)      NaN
# 20180002                         SYMPHONIC BAND (Member)      NaN
# 20180003                         BADMINTON (Welfare I/C)      NaN
# 20180005                                LIBRARY (Member)      NaN
# 20180006  HWA CHONG PUBLICATIONS SOCIETY (HCPS) (Editor)      NaN
#
# [5 rows x 57 columns]
# Batch 18
#          GENDER  PSLE REPEAT                  INTAKE  \
# NEWID
# 20190001      M   189    NaN               DSA (CCA)
# 20190002      M   256    NaN                IP (HCI)
# 20190003      M   231    NaN                IP (HCI)
# 20190004      M   255    NaN                IP (HCI)
# 20190005      M     0    NaN  JAE Ordinary Admission
#
#                                    SEC SCHOOL PW   KI GP KI (H) MA2  ... MTL  \
# NEWID                                                                ...
# 20190001                 CATHOLIC HIGH SCHOOL  A  NaN  S    NaN   S  ...   E
# 20190002  HWA CHONG INSTITUTION (HIGH SCHOOL)  A  NaN  A    NaN   A  ...   B
# 20190003  HWA CHONG INSTITUTION (HIGH SCHOOL)  A  NaN  B    NaN   B  ...   A
# 20190004  HWA CHONG INSTITUTION (HIGH SCHOOL)  B  NaN  C    NaN   E  ...   B
# 20190005             MARIS STELLA HIGH SCHOOL  A  NaN  C    NaN   U  ...   A
#
#              P/F  RANK   % MSG/GPA    PTS NO OF CCA  \
# NEWID
# 20190001  Passed  1021   7     4.3  47.50         1
# 20190002  Passed    43  96     1.2  88.75         1
# 20190003  Passed   364  67     1.9  81.25         1
# 20190004  Passed   929  15     4.0  58.75         1
# 20190005  Passed  1006   8     4.6  50.00         1
#
#                                                      CCA BY1 JP2
# NEWID
# 20190001                               SOFTBALL (Member) NaN NaN
# 20190002  HWA CHONG PUBLICATIONS SOCIETY (HCPS) (Member) NaN NaN
# 20190003                              BADMINTON (Member) NaN NaN
# 20190004                               FOOTBALL (Member) NaN NaN
# 20190005      INTERACT CLUB (Community Service Director) NaN NaN
#
# [5 rows x 57 columns]
# Batch 19
#          GENDER  PSLE REPEAT                  INTAKE  \
# NEWID
# 20200001      F     0    NaN  JAE Ordinary Admission
# 20200002      F     0    NaN               IP (NYGH)
# 20200003      F     0    NaN  JAE Ordinary Admission
# 20200004      M     0    NaN                IP (HCI)
# 20200005      F     0    NaN               IP (NYGH)
#
#                                            SEC SCHOOL PW   KI GP KI (H) MA2  \
# NEWID
# 20200001  SCHOOL OF SCIENCE AND TECHNOLOGY, SINGAPORE  A  NaN  B    NaN   A
# 20200002                   NANYANG GIRLS' HIGH SCHOOL  A  NaN  B    NaN   B
# 20200003                        NAN CHIAU HIGH SCHOOL  A  NaN  B    NaN   B
# 20200004          HWA CHONG INSTITUTION (HIGH SCHOOL)  A  NaN  C    NaN   D
# 20200005                   NANYANG GIRLS' HIGH SCHOOL  A  NaN  D    NaN   S
#
#           ... MTL     P/F RANK   % MSG/GPA    PTS NO OF CCA  \
# NEWID     ...
# 20200001  ...   E  Passed  227  78     1.4  85.00         1
# 20200002  ...   A  Passed  489  54     2.1  78.75         1
# 20200003  ...   A  Passed  782  26     3.4  66.25         1
# 20200004  ...   B  Passed  936  11     4.6  52.50         2
# 20200005  ...   A  Passed  974   8     5.0  43.75         1
#
#                                                       CCA EH1 BY1
# NEWID
# 20200001                              LIBRARY (President) NaN NaN
# 20200002        TRACK & FIELD (Sectional Leader - Throws) NaN NaN
# 20200003                          SYMPHONIC BAND (Member) NaN NaN
# 20200004  CROSS-COUNTRY (Captain), TRACK & FIELD (Member) NaN NaN
# 20200005             CHINESE CALLIGRAPHY SOCIETY (Member) NaN NaN
#
# [5 rows x 57 columns]
# Batch 20

# %%
# check for null entries
for i in range(3):
    print(f'Batch {batch[i]}')
    display(Prelim_Data[i][0].info())
# Out:
# Batch 18
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1097 entries, 20180001 to 20181154
# Data columns (total 57 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GENDER      1097 non-null   object
#  1   PSLE        1097 non-null   int64
#  2   REPEAT      4 non-null      object
#  3   INTAKE      1097 non-null   object
#  4   SEC SCHOOL  1097 non-null   object
#  5   PW          1097 non-null   object
#  6   GP          1055 non-null   object
#  7   KI          27 non-null     object
#  8   KI (H)      15 non-null     object
#  9   MA2         1097 non-null   object
#  10  FM2         12 non-null     object
#  11  CP2         53 non-null     object
#  12  PH2         496 non-null    object
#  13  CH2         898 non-null    object
#  14  BY2         441 non-null    object
#  15  EL2         59 non-null     object
#  16  EL2 (H)     44 non-null     object
#  17  ELL2        9 non-null      object
#  18  EC2         758 non-null    object
#  19  EC2 (H)     35 non-null     object
#  20  EH2         53 non-null     object
#  21  EH2 (H)     21 non-null     object
#  22  EG2         52 non-null     object
#  23  EG2 (H)     9 non-null      object
#  24  AP2         11 non-null     object
#  25  MP2         4 non-null      object
#  26  CLL2        32 non-null     object
#  27  CSC2        73 non-null     object
#  28  TRC2        7 non-null      object
#  29  FR2         2 non-null      object
#  30  GM2         6 non-null      object
#  31  JP2         2 non-null      object
#  32  SP2         2 non-null      object
#  33  MA1         0 non-null      object
#  34  PH1         3 non-null      object
#  35  CH1         24 non-null     object
#  36  BY1         2 non-null      object
#  37  EL1         14 non-null     object
#  38  EC1         120 non-null    object
#  39  EH1         1 non-null      object
#  40  EG1         2 non-null      object
#  41  MA3-MOE     34 non-null     object
#  42  PH3-MOE     14 non-null     object
#  43  CH3-MOE     58 non-null     object
#  44  BY3-MOE     22 non-null     object
#  45  EC3-MOE     23 non-null     object
#  46  AP3-MOE     11 non-null     object
#  47  PW.1        1097 non-null   object
#  48  MTL         1093 non-null   object
#  49  P/F         1097 non-null   object
#  50  RANK        1097 non-null   int64
#  51  %           1097 non-null   int64
#  52  MSG/GPA     1097 non-null   float64
#  53  PTS         1097 non-null   float64
#  54  NO OF CCA   1097 non-null   int64
#  55  CCA         1078 non-null   object
#  56  CLL3-MOE    0 non-null      float64
# dtypes: float64(3), int64(4), object(50)
# memory usage: 497.1+ KB
# None
# Batch 19
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1064 entries, 20190001 to 20191099
# Data columns (total 57 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GENDER      1064 non-null   object
#  1   PSLE        1064 non-null   int64
#  2   REPEAT      3 non-null      object
#  3   INTAKE      1064 non-null   object
#  4   SEC SCHOOL  1064 non-null   object
#  5   PW          1063 non-null   object
#  6   KI          26 non-null     object
#  7   GP          1032 non-null   object
#  8   KI (H)      6 non-null      object
#  9   MA2         1064 non-null   object
#  10  FM2         22 non-null     object
#  11  CP2         57 non-null     object
#  12  PH2         547 non-null    object
#  13  CH2         844 non-null    object
#  14  BY2         353 non-null    object
#  15  EL2         59 non-null     object
#  16  EL2 (H)     42 non-null     object
#  17  ELL2        16 non-null     object
#  18  EC2         782 non-null    object
#  19  EC2 (H)     32 non-null     object
#  20  EH2         59 non-null     object
#  21  EH2 (H)     22 non-null     object
#  22  EG2         33 non-null     object
#  23  EG2 (H)     13 non-null     object
#  24  AP2         10 non-null     object
#  25  MP2         8 non-null      object
#  26  CLL2        38 non-null     object
#  27  CSC2        69 non-null     object
#  28  TRC2        9 non-null      object
#  29  FR2         1 non-null      object
#  30  GM2         5 non-null      object
#  31  SP2         2 non-null      object
#  32  MA1         0 non-null      object
#  33  PH1         10 non-null     object
#  34  CH1         27 non-null     object
#  35  EL1         7 non-null      object
#  36  EC1         84 non-null     object
#  37  EH1         1 non-null      object
#  38  EG1         9 non-null      object
#  39  MA3-MOE     43 non-null     object
#  40  PH3-MOE     40 non-null     object
#  41  CH3-MOE     86 non-null     object
#  42  BY3-MOE     37 non-null     object
#  43  EC3-MOE     21 non-null     object
#  44  AP3-MOE     10 non-null     object
#  45  CLL3-MOE    3 non-null      object
#  46  PW.1        1064 non-null   object
#  47  MTL         1060 non-null   object
#  48  P/F         1064 non-null   object
#  49  RANK        1064 non-null   int64
#  50  %           1064 non-null   int64
#  51  MSG/GPA     1064 non-null   float64
#  52  PTS         1064 non-null   float64
#  53  NO OF CCA   1064 non-null   int64
#  54  CCA         1048 non-null   object
#  55  BY1         0 non-null      float64
#  56  JP2         0 non-null      float64
# dtypes: float64(4), int64(4), object(49)
# memory usage: 482.1+ KB
# None
# Batch 20
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 20200001 to 20201057
# Data columns (total 57 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GENDER      1025 non-null   object
#  1   PSLE        1025 non-null   int64
#  2   REPEAT      11 non-null     object
#  3   INTAKE      1025 non-null   object
#  4   SEC SCHOOL  1025 non-null   object
#  5   PW          1021 non-null   object
#  6   KI          25 non-null     object
#  7   GP          989 non-null    object
#  8   KI (H)      11 non-null     object
#  9   MA2         1025 non-null   object
#  10  FM2         14 non-null     object
#  11  CP2         58 non-null     object
#  12  PH2         507 non-null    object
#  13  CH2         846 non-null    object
#  14  BY2         359 non-null    object
#  15  EL2         58 non-null     object
#  16  EL2 (H)     42 non-null     object
#  17  ELL2        15 non-null     object
#  18  EC2         748 non-null    object
#  19  EC2 (H)     35 non-null     object
#  20  EH2         46 non-null     object
#  21  EH2 (H)     25 non-null     object
#  22  EG2         36 non-null     object
#  23  EG2 (H)     5 non-null      object
#  24  AP2         15 non-null     object
#  25  MP2         6 non-null      object
#  26  CLL2        38 non-null     object
#  27  CSC2        74 non-null     object
#  28  TRC2        9 non-null      object
#  29  FR2         5 non-null      object
#  30  GM2         8 non-null      object
#  31  JP2         3 non-null      object
#  32  SP2         2 non-null      object
#  33  MA1         0 non-null      object
#  34  PH1         3 non-null      object
#  35  CH1         10 non-null     object
#  36  EL1         9 non-null      object
#  37  EC1         53 non-null     object
#  38  EG1         4 non-null      object
#  39  MA3-MOE     32 non-null     object
#  40  PH3-MOE     35 non-null     object
#  41  CH3-MOE     84 non-null     object
#  42  BY3-MOE     25 non-null     object
#  43  EC3-MOE     22 non-null     object
#  44  AP3-MOE     14 non-null     object
#  45  CLL3-MOE    1 non-null      object
#  46  PW.1        1021 non-null   object
#  47  MTL         1020 non-null   object
#  48  P/F         1024 non-null   object
#  49  RANK        1025 non-null   int64
#  50  %           1025 non-null   int64
#  51  MSG/GPA     1025 non-null   float64
#  52  PTS         1025 non-null   float64
#  53  NO OF CCA   1025 non-null   int64
#  54  CCA         1011 non-null   object
#  55  EH1         0 non-null      float64
#  56  BY1         0 non-null      float64
# dtypes: float64(4), int64(4), object(49)
# memory usage: 464.5+ KB
# None

# %% [markdown]
# ### Project Work
# 'PW.1' looks like a duplicate of 'PW'. We check for differences between the columns and find that the missing values for 'PW' are related to students who repeated year 1. The Project Work grade of the repeat student in Batch 19 is reflected in 'PW.1' while those for Batch 20 are missing in both columns. We drop the 'PW' column for all 3 batches.

# %%
# display rows where 'PW' is different from 'PW.1'
for i in range(3):
    display(Prelim_Data[i][0][Prelim_Data[i][0]['PW'] != Prelim_Data[i][0]['PW.1']])
    print(f'Batch {batch[i]}')
# Out:
# Empty DataFrame
# Columns: [GENDER, PSLE, REPEAT, INTAKE, SEC SCHOOL, PW, GP, KI, KI (H), MA2, FM2, CP2, PH2, CH2, BY2, EL2, EL2 (H), ELL2, EC2, EC2 (H), EH2, EH2 (H), EG2, EG2 (H), AP2, MP2, CLL2, CSC2, TRC2, FR2, GM2, JP2, SP2, MA1, PH1, CH1, BY1, EL1, EC1, EH1, EG1, MA3-MOE, PH3-MOE, CH3-MOE, BY3-MOE, EC3-MOE, AP3-MOE, PW.1, MTL, P/F, RANK, %, MSG/GPA, PTS, NO OF CCA, CCA, CLL3-MOE]
# Index: []
#
# [0 rows x 57 columns]
# Batch 18
#          GENDER  PSLE      REPEAT     INTAKE                  SEC SCHOOL   PW  \
# NEWID
# 20190977      F   272  Repeat Yr1  IP (NYGH)  NANYANG GIRLS' HIGH SCHOOL  NaN
#
#            KI GP KI (H) MA2  ... MTL     P/F  RANK  % MSG/GPA    PTS  \
# NEWID                        ...
# 20190977  NaN  B    NaN   U  ...   B  Passed  1090  1     6.0  23.75
#
#          NO OF CCA                CCA BY1 JP2
# NEWID
# 20190977         1  ART CLUB (Member) NaN NaN
#
# [1 rows x 57 columns]
# Batch 19
#          GENDER  PSLE      REPEAT     INTAKE  \
# NEWID
# 20200357      M   259  Repeat Yr1   IP (HCI)
# 20200428      M   246  Repeat Yr1  DSA (CCA)
# 20200583      M   259  Repeat Yr1   IP (HCI)
# 20200907      F   212  Repeat Yr1  DSA (CCA)
#
#                                    SEC SCHOOL   PW   KI  GP KI (H) MA2  ...  \
# NEWID                                                                   ...
# 20200357  HWA CHONG INSTITUTION (HIGH SCHOOL)  NaN  NaN   B    NaN   U  ...
# 20200428                  RAFFLES INSTITUTION  NaN  NaN   C    NaN   C  ...
# 20200583  HWA CHONG INSTITUTION (HIGH SCHOOL)  NaN  NaN  EX    NaN  EX  ...
# 20200907      CHIJ ST. NICHOLAS GIRLS' SCHOOL  NaN  NaN   D    NaN   U  ...
#
#           MTL     P/F  RANK   % MSG/GPA    PTS NO OF CCA  \
# NEWID
# 20200357    A  Passed  1012   4     5.4  33.75         1
# 20200428    E  Passed   909  14     3.4  56.25         1
# 20200583    A  Failed  1062   0     0.0   0.00         1
# 20200907  NaN  Failed  1061   0     7.0   6.25         0
#
#                                 CCA EH1 BY1
# NEWID
# 20200357  HEALTH & FITNESS (Member) NaN NaN
# 20200428     TRACK & FIELD (Member) NaN NaN
# 20200583             CHOIR (Member) NaN NaN
# 20200907                        NaN NaN NaN
#
# [4 rows x 57 columns]
# Batch 20

# %% [markdown]
# ### Mother Tongue Language
# 'MTL' is mother tongue language, which students either take at the end of JC1 or use their higher mother tongue grade from O Level. A handful of students may have been exempted by (Ministry of Education) MOE from this subject requirement.
#
# The students with no 'MTL' grade are all not from the main feeder schools of the Integrated Programme where students must take Chinese as their mother tongue, hence it is reasonable to conclude that these students were indeed exempted by MOE from this subject requirement.

# %%
# check rows with no MTL grade
for i in range(3):
    display(Prelim_Data[i][0][Prelim_Data[i][0]['MTL'].isna()])
    print(f'Batch {batch[i]}')
# Out:
#          GENDER  PSLE REPEAT              INTAKE                   SEC SCHOOL  \
# NEWID
# 20180650      F   247    NaN  Appeals (Academic)       CRESCENT GIRLS' SCHOOL
# 20180703      M     0    NaN                 DSA    ZHONGHUA SECONDARY SCHOOL
# 20180833      M   207    NaN           DSA (CCA)  GREENRIDGE SECONDARY SCHOOL
# 20180954      M     0    NaN                 DSA     ST. JOSEPH'S INSTITUTION
#
#          PW GP   KI KI (H) MA2  ... PW.1  MTL     P/F  RANK   % MSG/GPA  \
# NEWID                           ...
# 20180650  B  D  NaN    NaN   E  ...    B  NaN  Passed   987  14     4.0
# 20180703  A  C  NaN    NaN   A  ...    A  NaN  Passed   144  87     1.2
# 20180833  B  S  NaN    NaN   C  ...    B  NaN  Passed  1051   9     3.9
# 20180954  A  B  NaN    NaN   A  ...    A  NaN  Passed   144  87     1.4
#
#             PTS NO OF CCA                                                CCA  \
# NEWID
# 20180650  57.50         2  ART CLUB (Member), ARTEMIS FACULTY COMMITTEE (...
# 20180703  86.25         2  INFOCOMM & ROBOTICS SOCIETY (Member), SCIENCE ...
# 20180833  51.25         1                          BASKETBALL (Vice-Captain)
# 20180954  86.25         2  INFOCOMM & ROBOTICS SOCIETY (Member), SCIENCE ...
#
#          CLL3-MOE
# NEWID
# 20180650      NaN
# 20180703      NaN
# 20180833      NaN
# 20180954      NaN
#
# [4 rows x 57 columns]
# Batch 18
#          GENDER  PSLE REPEAT     INTAKE  \
# NEWID
# 20190214      F     0    NaN        DSA
# 20190219      F   223    NaN  DSA (CCA)
# 20190769      M   243    NaN  DSA (CCA)
# 20190959      M   230    NaN  DSA (CCA)
#
#                                       SEC SCHOOL PW   KI GP KI (H) MA2  ...  \
# NEWID                                                                   ...
# 20190214         SINGAPORE CHINESE GIRLS' SCHOOL  A  NaN  B    NaN   B  ...
# 20190219     METHODIST GIRLS' SCHOOL (SECONDARY)  A  NaN  B    NaN   C  ...
# 20190769  FAIRFIELD METHODIST SCHOOL (SECONDARY)  B  NaN  C    NaN   D  ...
# 20190959      ANGLO-CHINESE SCHOOL (BARKER ROAD)  B  NaN  B    NaN   B  ...
#
#           MTL     P/F RANK   % MSG/GPA    PTS NO OF CCA  \
# NEWID
# 20190214  NaN  Passed  364  67     1.9  81.25         2
# 20190219  NaN  Passed  472  57     2.0  78.75         1
# 20190769  NaN  Passed  850  23     3.3  65.00         1
# 20190959  NaN  Passed  472  57     2.2  78.75         1
#
#                                                         CCA BY1 JP2
# NEWID
# 20190214  MIND SPORTS (CHESS, BRIDGE) (Member), SCIENCE ... NaN NaN
# 20190219                                 FOOTBALL (Captain) NaN NaN
# 20190769                                   SQUASH (Captain) NaN NaN
# 20190959           TRACK & FIELD (Sectional Leader - Jumps) NaN NaN
#
# [4 rows x 57 columns]
# Batch 19
#          GENDER  PSLE      REPEAT     INTAKE  \
# NEWID
# 20200175      F   251         NaN        DSA
# 20200233      F   242         NaN  DSA (CCA)
# 20200261      M   235  Repeat Yr1  DSA (CCA)
# 20200665      M     0         NaN        DSA
# 20200907      F   212  Repeat Yr1  DSA (CCA)
#
#                                    SEC SCHOOL   PW   KI GP KI (H) MA2  ...  \
# NEWID                                                                  ...
# 20200175      SINGAPORE CHINESE GIRLS' SCHOOL    B  NaN  A    NaN   B  ...
# 20200233  METHODIST GIRLS' SCHOOL (SECONDARY)    A  NaN  B    NaN   C  ...
# 20200261                  NAN HUA HIGH SCHOOL    B  NaN  E    NaN   U  ...
# 20200665             ST. JOSEPH'S INSTITUTION    A  NaN  C    NaN   A  ...
# 20200907      CHIJ ST. NICHOLAS GIRLS' SCHOOL  NaN  NaN  D    NaN   U  ...
#
#           MTL     P/F  RANK   % MSG/GPA    PTS NO OF CCA  \
# NEWID
# 20200175  NaN  Passed   429  59     2.0  80.00         2
# 20200233  NaN  Passed   636  40     2.6  73.75         1
# 20200261  NaN  Failed  1054   0     6.4  13.75         1
# 20200665  NaN  Passed   189  82     1.2  86.25         1
# 20200907  NaN  Failed  1061   0     7.0   6.25         0
#
#                                                         CCA EH1 BY1
# NEWID
# 20200175  CCA COUNCIL (Visual and Performing Arts Secret... NaN NaN
# 20200233                     FOOTBALL (Secretary-Treasurer) NaN NaN
# 20200261                              TABLE-TENNIS (Member) NaN NaN
# 20200665               MIND SPORTS (CHESS, BRIDGE) (Member) NaN NaN
# 20200907                                                NaN NaN NaN
#
# [5 rows x 57 columns]
# Batch 20

# %% [markdown]
# ## Observation
# We notice that some PSLE scores are 0, which is not possible and should be missing values instead. As the vast majority of PSLE scores are missing in Batch 20 (977/1025 = 95%), it will not be very useful in our modelling. Furthermore, the trend shows that more PSLE scores are missing, suggesting that this information is no longer collected and may soon be unavailable altogether in future batches, so the column will be dropped.

# %%
# check number of PSLE scores recorded as 0
print("Number of PSLE scores recorded as 0")
for i in range(3):
    print(f"Batch {batch[i]}: {Prelim_Data[i][0].value_counts('PSLE')[0]}")
# Out:
# Number of PSLE scores recorded as 0
# Batch 18: 81
# Batch 19: 338
# Batch 20: 977

# %% [markdown]
# ### Pass/Fail, Rank, Percentile, Mean Subject Grade, University Admission Points
# Pass/Fail is a binary column that indicates whether a student met the minimum passing criterion of 2 H2 passes (Grade E and above) or 1 H2 pass and 2 H2 subpasses (grade S and above, also equivalent to a H1 pass).
#
# Rank and Percentile both indicate the relative ranking of the students amongst their peers.
#
# MSG/GPA is Mean Subject Grade / Grade Point Average, where 1 corresponds to A, 2 corresponds to B and so on, so the lower the value, the better the score.
#
# PTS refers to the University Admission Points, which also summarizes how well a student does for all his subjects, with 90 as the maximum and best possible score.

# %%
# check for missing values
for i in range(3):
    print(f'Batch {batch[i]}')
    display(Prelim_Data[i][0][['P/F', 'RANK', '%', 'MSG/GPA', 'PTS']].isna().sum())
# Out:
# Batch 18
# P/F        0
# RANK       0
# %          0
# MSG/GPA    0
# PTS        0
# dtype: int64
# Batch 19
# P/F        0
# RANK       0
# %          0
# MSG/GPA    0
# PTS        0
# dtype: int64
# Batch 20
# P/F        1
# RANK       0
# %          0
# MSG/GPA    0
# PTS        0
# dtype: int64

# %%
# find row with missing 'P/F'
Prelim_Data[2][0][Prelim_Data[2][0]['P/F'].isna()]
# Out:
#          GENDER  PSLE      REPEAT    INTAKE  \
# NEWID
# 20200346      M   254  Repeat Yr2  IP (HCI)
#
#                                    SEC SCHOOL PW   KI  GP KI (H) MA2  ... MTL  \
# NEWID                                                                 ...
# 20200346  HWA CHONG INSTITUTION (HIGH SCHOOL)  C  NaN  MC    NaN  EX  ...   S
#
#           P/F  RANK  % MSG/GPA  PTS NO OF CCA  CCA EH1 BY1
# NEWID
# 20200346  NaN  1060  0     3.0  7.5         0  NaN NaN NaN
#
# [1 rows x 57 columns]

# %% [markdown]
# This student did not sit for the Prelim Exam, thus his 'P/F' status was missing. We update this to 'Failed'.

# %%
# update missing 'P/F' status to 'Failed'
Prelim_Data[2][0].loc[20200346, 'P/F'] = 'Failed' 

# check value counts for Prelim Overall Results
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('P/F'))
    print()
# Out:
# Batch 18
# P/F
# Passed    1077
# Failed      20
# dtype: int64
#
# Batch 19
# P/F
# Passed    1041
# Failed      23
# dtype: int64
#
# Batch 20
# P/F
# Passed    984
# Failed     41
# dtype: int64

# %%
# function to plot twin y histograms
def twin_hist(x1, x2, asc1=True, asc2=True):
    for i in range(3):
        fig, ax1 = plt.subplots()
        fig.suptitle(f'Distributions of {str(x1)} and {str(x2)} for Batch {i+18}', fontsize=24)
        ax1 = Prelim_Data[i][0].value_counts(x1).sort_index(ascending=asc1).plot(color='blue', kind='bar', 
                                                                                 alpha=.5, label=str(x1)
                                                                                )
        ax1.set_ylabel('Number of Students')
        ax1.legend(bbox_to_anchor=(1,1), facecolor='white', framealpha=1)
        ax2 = ax1.twiny()
        ax2 = Prelim_Data[i][0].value_counts(x2).sort_index(ascending=asc2).plot(color='orange', kind='bar',
                                                                                 alpha=.5, label=str(x2)
                                                                                )
        ax2.legend(bbox_to_anchor=(1,0.93), facecolor='white', framealpha=1)
        ax2.grid(False)
        plt.tight_layout();

# %%
# plot twin histograms for 'RANK' and 'PTS'
twin_hist('RANK', 'PTS', asc1=True, asc2=False)

# %% [markdown]
# The distributions are identical within the same batch (any differences would have been visible as blue and orange colours as seen in the other histograms below). This confirms our understanding that students were ranked according to their University Admission Points. We keep the 'PTS' column and drop the 'Rank' column.

# %%
# plot twin histograms for 'PTS' and '%'
twin_hist('PTS', '%', asc1=False, asc2=False)

# %%
# plot twin histograms for 'PTS' and 'MSG/GPA'
twin_hist('PTS', 'MSG/GPA', asc1=False, asc2=True)

# %% [markdown]
# The distributions of University Admission Points, Percentile within Cohort and Mean Subject Grade are not the same within each batch, though they are quite similar across the batches. We keep all 3 columns for now.

# %% [markdown]
# ## Check all non-grades related columns

# %%
# check number of empty cells in 'GENDER', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'NO OF CCA', 'CCA'
# these need to be imputed during preprocessing if they are to be used in modelling
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0][['GENDER', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'NO OF CCA', 'CCA']].isna().sum())
    print()
# Out:
# Batch 18
# GENDER           0
# REPEAT        1093
# INTAKE           0
# SEC SCHOOL       0
# NO OF CCA        0
# CCA             19
# dtype: int64
#
# Batch 19
# GENDER           0
# REPEAT        1061
# INTAKE           0
# SEC SCHOOL       0
# NO OF CCA        0
# CCA             16
# dtype: int64
#
# Batch 20
# GENDER           0
# REPEAT        1014
# INTAKE           0
# SEC SCHOOL       0
# NO OF CCA        0
# CCA             14
# dtype: int64

# %% [markdown]
# ### Gender

# %%
# check value counts for Gender
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('GENDER'))
    print()
# Out:
# Batch 18
# GENDER
# F    555
# M    542
# dtype: int64
#
# Batch 19
# GENDER
# F    541
# M    523
# dtype: int64
#
# Batch 20
# GENDER
# F    539
# M    486
# dtype: int64

# %% [markdown]
# ### Repeat Status

# %%
# check value counts for Repeat Status
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('REPEAT'))
    print()
# Out:
# Batch 18
# REPEAT
# Repeat Yr1    3
# Repeat Yr2    1
# dtype: int64
#
# Batch 19
# REPEAT
# Repeat Yr1    2
# Repeat Yr2    1
# dtype: int64
#
# Batch 20
# REPEAT
# Repeat Yr1    6
# Repeat Yr2    5
# dtype: int64

# %% [markdown]
# The number of repeat students are small but increased significantly in Batch 20. This may be related to the COVID-19 situation as these students entered Junior College in 2020 and underwent many disruptions to their schooling such as the circuit breaker in April 2020. We also impute the missing values with 'No Repeat'.

# %%
# impute missing values with 'No Repeat'
for i in range(3):
    Prelim_Data[i][0]['REPEAT'].fillna('No Repeat', inplace=True)

# %% [markdown]
# ### Intake Type

# %%
# check value counts for Intake Type
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('INTAKE'))
    print()
# Out:
# Batch 18
# INTAKE
# IP (HCI)                  351
# IP (NYGH)                 344
# JAE Ordinary Admission    325
# DSA (CCA)                  46
# DSA                        22
# Appeals (Academic)          9
# dtype: int64
#
# Batch 19
# INTAKE
# IP (HCI)                  359
# IP (NYGH)                 352
# JAE Ordinary Admission    280
# DSA (CCA)                  41
# DSA                        21
# Appeals (Academic)         11
# dtype: int64
#
# Batch 20
# INTAKE
# IP (HCI)                  360
# IP (NYGH)                 345
# JAE Ordinary Admission    260
# DSA (CCA)                  40
# DSA                        19
# Appeals (Academic)          1
# dtype: int64

# %% [markdown]
# There is only 1 Appeals (Academic) in Batch 20. As the numbers are small and may stay small in future, we wish to avoid having such a category for our production model. This group is actually almost identical to the JAE Ordinary Admission group as they enter based on their O Level L1R5 score being at the cut-off score, so we merge them together.

# %%
for i in range(3):
    Prelim_Data[i][0]['INTAKE'] = Prelim_Data[i][0]['INTAKE'].map(
        lambda i: 'JAE Ordinary Admission' if i == 'Appeals (Academic)' else i)

# %% [markdown]
# ### Secondary Schools

# %%
# check value counts for Secondary School
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('SEC SCHOOL'))
    print()
# Out:
# Batch 18
# SEC SCHOOL
# HWA CHONG INSTITUTION (HIGH SCHOOL)    362
# NANYANG GIRLS' HIGH SCHOOL             345
# NAN HUA HIGH SCHOOL                     71
# CHUNG CHENG HIGH SCHOOL (MAIN)          37
# CATHOLIC HIGH SCHOOL                    30
#                                       ...
# BEDOK NORTH SECONDARY SCHOOL             1
# BEATTY SECONDARY SCHOOL                  1
# NATIONAL JUNIOR COLLEGE (IP)             1
# NEW TOWN SECONDARY SCHOOL                1
# ADMIRALTY SECONDARY SCHOOL               1
# Length: 63, dtype: int64
#
# Batch 19
# SEC SCHOOL
# HWA CHONG INSTITUTION (HIGH SCHOOL)    365
# NANYANG GIRLS' HIGH SCHOOL             352
# NAN HUA HIGH SCHOOL                     50
# CATHOLIC HIGH SCHOOL                    31
# CHIJ ST. NICHOLAS GIRLS' SCHOOL         25
#                                       ...
# ANG MO KIO SECONDARY SCHOOL              1
# MARSILING SECONDARY SCHOOL               1
# BARTLEY SECONDARY SCHOOL                 1
# BEATTY SECONDARY SCHOOL                  1
# NAVAL BASE SECONDARY SCHOOL              1
# Length: 68, dtype: int64
#
# Batch 20
# SEC SCHOOL
# HWA CHONG INSTITUTION (HIGH SCHOOL)    364
# NANYANG GIRLS' HIGH SCHOOL             348
# NAN HUA HIGH SCHOOL                     53
# CHUNG CHENG HIGH SCHOOL (MAIN)          29
# CHIJ ST. NICHOLAS GIRLS' SCHOOL         24
#                                       ...
# BOON LAY SECONDARY SCHOOL                1
# BOWEN SECONDARY SCHOOL                   1
# BUKIT MERAH SECONDARY SCHOOL             1
# MONTFORT SECONDARY SCHOOL                1
# MERIDIAN SECONDARY SCHOOL                1
# Length: 64, dtype: int64

# %% [markdown]
# As there are many secondary schools with only 1 student, we do not wish to overtrain our model with such fine details. For example, a particular secondary school might have had a brilliant student who did extremely well but this does not guarantee that future students from the same school will also perform as well. Hence we group schools with small number of students into a combined category.

# %%
# investigate Secondary Schools further
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('SEC SCHOOL')[:15])
    print()
# Out:
# Batch 18
# SEC SCHOOL
# HWA CHONG INSTITUTION (HIGH SCHOOL)    362
# NANYANG GIRLS' HIGH SCHOOL             345
# NAN HUA HIGH SCHOOL                     71
# CHUNG CHENG HIGH SCHOOL (MAIN)          37
# CATHOLIC HIGH SCHOOL                    30
# CRESCENT GIRLS' SCHOOL                  28
# NAN CHIAU HIGH SCHOOL                   21
# CHIJ ST. NICHOLAS GIRLS' SCHOOL         18
# BUKIT PANJANG GOVT. HIGH SCHOOL         18
# ANGLICAN HIGH SCHOOL                    16
# METHODIST GIRLS' SCHOOL (SECONDARY)     16
# MARIS STELLA HIGH SCHOOL                15
# SINGAPORE CHINESE GIRLS' SCHOOL         14
# CEDAR GIRLS' SECONDARY SCHOOL           11
# ST. JOSEPH'S INSTITUTION                 9
# dtype: int64
#
# Batch 19
# SEC SCHOOL
# HWA CHONG INSTITUTION (HIGH SCHOOL)       365
# NANYANG GIRLS' HIGH SCHOOL                352
# NAN HUA HIGH SCHOOL                        50
# CATHOLIC HIGH SCHOOL                       31
# CHIJ ST. NICHOLAS GIRLS' SCHOOL            25
# BUKIT PANJANG GOVT. HIGH SCHOOL            24
# MARIS STELLA HIGH SCHOOL                   18
# CHUNG CHENG HIGH SCHOOL (MAIN)             17
# METHODIST GIRLS' SCHOOL (SECONDARY)        15
# ANGLICAN HIGH SCHOOL                       14
# SINGAPORE CHINESE GIRLS' SCHOOL            11
# CRESCENT GIRLS' SCHOOL                     10
# NAN CHIAU HIGH SCHOOL                       8
# CEDAR GIRLS' SECONDARY SCHOOL               8
# FAIRFIELD METHODIST SCHOOL (SECONDARY)      7
# dtype: int64
#
# Batch 20
# SEC SCHOOL
# HWA CHONG INSTITUTION (HIGH SCHOOL)    364
# NANYANG GIRLS' HIGH SCHOOL             348
# NAN HUA HIGH SCHOOL                     53
# CHUNG CHENG HIGH SCHOOL (MAIN)          29
# CHIJ ST. NICHOLAS GIRLS' SCHOOL         24
# CATHOLIC HIGH SCHOOL                    21
# BUKIT PANJANG GOVT. HIGH SCHOOL         17
# METHODIST GIRLS' SCHOOL (SECONDARY)     17
# NAN CHIAU HIGH SCHOOL                   16
# CRESCENT GIRLS' SCHOOL                  16
# CEDAR GIRLS' SECONDARY SCHOOL           10
# SINGAPORE CHINESE GIRLS' SCHOOL          8
# SWISS COTTAGE SECONDARY SCHOOL           6
# ST. JOSEPH'S INSTITUTION                 6
# VICTORIA SCHOOL                          5
# dtype: int64

# %% [markdown]
# The majority of secondary schools have less than 10 students entering this JC (49/63 schools in Batch 18, 56/68 in Batch 19 and 53/64 in Batch 20).
#
# The top 3 feeder schools remained the same across the 3 years. We use the intersection of schools with at least 10 students for all three batches and keep this list, and then combine the rest of the schools into a new category 'minority schools'.

# %%
# create set of common schools
common_schools = set(Prelim_Data[0][0].value_counts('SEC SCHOOL')[:14].index).\
    intersection(set(Prelim_Data[1][0].value_counts('SEC SCHOOL')[:12].index)).\
    intersection(set(Prelim_Data[2][0].value_counts('SEC SCHOOL')[:11].index))

# merge other schools into combined category '_Minority_Sch'
for i in range(3):
    Prelim_Data[i][0]['SEC SCHOOL'] = Prelim_Data[i][0]['SEC SCHOOL'].\
        map(lambda sch: sch if sch in common_schools else "_Minority_Sch")

# %%
# check value counts for Secondary School
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('SEC SCHOOL').sort_index())
    print()
# Out:
# Batch 18
# SEC SCHOOL
# BUKIT PANJANG GOVT. HIGH SCHOOL         18
# CATHOLIC HIGH SCHOOL                    30
# CHIJ ST. NICHOLAS GIRLS' SCHOOL         18
# CHUNG CHENG HIGH SCHOOL (MAIN)          37
# CRESCENT GIRLS' SCHOOL                  28
# HWA CHONG INSTITUTION (HIGH SCHOOL)    362
# METHODIST GIRLS' SCHOOL (SECONDARY)     16
# NAN HUA HIGH SCHOOL                     71
# NANYANG GIRLS' HIGH SCHOOL             345
# _Minority_Sch                          172
# dtype: int64
#
# Batch 19
# SEC SCHOOL
# BUKIT PANJANG GOVT. HIGH SCHOOL         24
# CATHOLIC HIGH SCHOOL                    31
# CHIJ ST. NICHOLAS GIRLS' SCHOOL         25
# CHUNG CHENG HIGH SCHOOL (MAIN)          17
# CRESCENT GIRLS' SCHOOL                  10
# HWA CHONG INSTITUTION (HIGH SCHOOL)    365
# METHODIST GIRLS' SCHOOL (SECONDARY)     15
# NAN HUA HIGH SCHOOL                     50
# NANYANG GIRLS' HIGH SCHOOL             352
# _Minority_Sch                          175
# dtype: int64
#
# Batch 20
# SEC SCHOOL
# BUKIT PANJANG GOVT. HIGH SCHOOL         17
# CATHOLIC HIGH SCHOOL                    21
# CHIJ ST. NICHOLAS GIRLS' SCHOOL         24
# CHUNG CHENG HIGH SCHOOL (MAIN)          29
# CRESCENT GIRLS' SCHOOL                  16
# HWA CHONG INSTITUTION (HIGH SCHOOL)    364
# METHODIST GIRLS' SCHOOL (SECONDARY)     17
# NAN HUA HIGH SCHOOL                     53
# NANYANG GIRLS' HIGH SCHOOL             348
# _Minority_Sch                          136
# dtype: int64

# %% [markdown]
# ### CCA

# %%
# check value counts for CCA
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('NO OF CCA').sort_index())
    print()
# Out:
# Batch 18
# NO OF CCA
# 0     19
# 1    873
# 2    198
# 3      7
# dtype: int64
#
# Batch 19
# NO OF CCA
# 0     16
# 1    826
# 2    216
# 3      6
# dtype: int64
#
# Batch 20
# NO OF CCA
# 0     14
# 1    858
# 2    148
# 3      5
# dtype: int64

# %%
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].value_counts('CCA'))
    print()
# Out:
# Batch 18
# CCA
# CHINESE SOCIETY (Member)                                                                                               36
# TRACK & FIELD (Member)                                                                                                 27
# TAEKWONDO CLUB (Member)                                                                                                25
# STUDIO ARDENT (AUDIO-VISUAL, VIDEO & PHOTOGRAPHY) (Member)                                                             24
# GUITAR (Member)                                                                                                        20
#                                                                                                                        ..
# ELDDFS (Member), SCIENCE STUDENTS' RESEARCH CLUB (Member)                                                               1
# ELDDFS (Member), HWA CHONG PUBLICATIONS SOCIETY (HCPS) (Member)                                                         1
# ELDDFS (Member), HUMANITIES AND CURRENT AFFAIRS SOCIETY (HACAS) (Member)                                                1
# ELDDFS (Member), HUMANITIES AND CURRENT AFFAIRS SOCIETY (HACAS) (Assistant Sectional Leader - Model United Nations)     1
# WUSHU (Welfare I/C)                                                                                                     1
# Length: 491, dtype: int64
#
# Batch 19
# CCA
# CHINESE SOCIETY (Member - Chinese Drama Wing ??)                                                                                 29
# GUITAR (Member)                                                                                                                  27
# TAEKWONDO CLUB (Member)                                                                                                          25
# INTERACT CLUB (Member)                                                                                                           22
# MUSIC & DANCE SOCIETY (Member - Street Dance)                                                                                    18
#                                                                                                                                  ..
# HUMANITIES AND CURRENT AFFAIRS SOCIETY (HACAS) (Member), STUDENT NATIONAL EDUCATION COUNCIL (SNEC) (Outreach Director)            1
# HUMANITIES AND CURRENT AFFAIRS SOCIETY (HACAS) (Member), SINGAPORE NATIONAL DEBATE TEAM (Captain)                                 1
# HUMANITIES AND CURRENT AFFAIRS SOCIETY (HACAS) (Member), HWA CHONG PUBLICATIONS SOCIETY (HCPS) (Member)                           1
# APOLLO FACULTY COMMITTEE (Activities I/C), BOYS' BRIGADE (Senior Cadet Lieutenant), INTERNATIONAL CULTURAL CLUB (Welfare I/C)     1
# APOLLO FACULTY COMMITTEE (Activities I/C)                                                                                         1
# Length: 473, dtype: int64
#
# Batch 20
# CCA
# CHINESE SOCIETY (Member - Chinese Drama Wing ??)                                         34
# TAEKWONDO CLUB (Member)                                                                  28
# MIND SPORTS (CHESS, BRIDGE) (Member)                                                     28
# GUITAR (Member)                                                                          27
# CHINESE ORCHESTRA (Member)                                                               24
#                                                                                          ..
# CIP COUNCIL (CIP Councillor), MUSIC & DANCE SOCIETY (Member - Modern)                     1
# CIP COUNCIL (CIP Councillor), HUMANITIES AND CURRENT AFFAIRS SOCIETY (HACAS) (Member)     1
# CHOIR (Welfare I/C)                                                                       1
# CHOIR (Vice-President)                                                                    1
# GUITAR (Sectional Leader - Prime Guitar)                                                  1
# Length: 446, dtype: int64

# %% [markdown]
# There are over 400 different values recorded under CCA. This is way too many for meaningful modelling. In addition, some students had multiple CCA. There is a separate csv file on CCA/CIP details, so we will drop this column.

# %% [markdown]
# ## Clean up subjects

# %%
# check column names of each batch for list of subjects
for i in range(3):
    print(f'Batch {batch[i]}')
    print(Prelim_Data[i][0].columns)
    print()
# Out:
# Batch 18
# Index(['GENDER', 'PSLE', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'PW', 'GP', 'KI',
#        'KI (H)', 'MA2', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'EL2 (H)',
#        'ELL2', 'EC2', 'EC2 (H)', 'EH2', 'EH2 (H)', 'EG2', 'EG2 (H)', 'AP2',
#        'MP2', 'CLL2', 'CSC2', 'TRC2', 'FR2', 'GM2', 'JP2', 'SP2', 'MA1', 'PH1',
#        'CH1', 'BY1', 'EL1', 'EC1', 'EH1', 'EG1', 'MA3-MOE', 'PH3-MOE',
#        'CH3-MOE', 'BY3-MOE', 'EC3-MOE', 'AP3-MOE', 'PW.1', 'MTL', 'P/F',
#        'RANK', '%', 'MSG/GPA', 'PTS', 'NO OF CCA', 'CCA', 'CLL3-MOE'],
#       dtype='object')
#
# Batch 19
# Index(['GENDER', 'PSLE', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'PW', 'KI', 'GP',
#        'KI (H)', 'MA2', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'EL2 (H)',
#        'ELL2', 'EC2', 'EC2 (H)', 'EH2', 'EH2 (H)', 'EG2', 'EG2 (H)', 'AP2',
#        'MP2', 'CLL2', 'CSC2', 'TRC2', 'FR2', 'GM2', 'SP2', 'MA1', 'PH1', 'CH1',
#        'EL1', 'EC1', 'EH1', 'EG1', 'MA3-MOE', 'PH3-MOE', 'CH3-MOE', 'BY3-MOE',
#        'EC3-MOE', 'AP3-MOE', 'CLL3-MOE', 'PW.1', 'MTL', 'P/F', 'RANK', '%',
#        'MSG/GPA', 'PTS', 'NO OF CCA', 'CCA', 'BY1', 'JP2'],
#       dtype='object')
#
# Batch 20
# Index(['GENDER', 'PSLE', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'PW', 'KI', 'GP',
#        'KI (H)', 'MA2', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'EL2 (H)',
#        'ELL2', 'EC2', 'EC2 (H)', 'EH2', 'EH2 (H)', 'EG2', 'EG2 (H)', 'AP2',
#        'MP2', 'CLL2', 'CSC2', 'TRC2', 'FR2', 'GM2', 'JP2', 'SP2', 'MA1', 'PH1',
#        'CH1', 'EL1', 'EC1', 'EG1', 'MA3-MOE', 'PH3-MOE', 'CH3-MOE', 'BY3-MOE',
#        'EC3-MOE', 'AP3-MOE', 'CLL3-MOE', 'PW.1', 'MTL', 'P/F', 'RANK', '%',
#        'MSG/GPA', 'PTS', 'NO OF CCA', 'CCA', 'EH1', 'BY1'],
#       dtype='object')

# %% [markdown]
# Some subjects have an additional version tagged with '(H)', which are essentially the same subjects (students take the same major exams in school) but are in a special programme. We merge those subjects into the same column.

# %%
# merge columns with (H) for Prelim Grades datasets
subj_H = ['KI', 'EL2', 'EC2', 'EH2', 'EG2']
for i in range(3):
    for subj in subj_H:
        Prelim_Data[i][0][subj].fillna(Prelim_Data[i][0][subj+' (H)'], inplace=True)

# %% [markdown]
# Students must take either General Paper (GP) or Knowledge and Inquiry (KI). We merge these 2 columns as well.

# %%
# merge 'GP' and 'KI'
for i in range(3):
    Prelim_Data[i][0]['GP'].fillna(Prelim_Data[i][0]['KI'], inplace=True) 
    Prelim_Data[i][0].rename(columns={'GP': 'GP/KI'}, inplace=True)

# %%
# look for subjects with small candidature
for i in range(3):
    print(f'Batch {batch[i]}')
    display(Prelim_Data[i][0].info())
# Out:
# Batch 18
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1097 entries, 20180001 to 20181154
# Data columns (total 57 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GENDER      1097 non-null   object
#  1   PSLE        1097 non-null   int64
#  2   REPEAT      1097 non-null   object
#  3   INTAKE      1097 non-null   object
#  4   SEC SCHOOL  1097 non-null   object
#  5   PW          1097 non-null   object
#  6   GP/KI       1097 non-null   object
#  7   KI          42 non-null     object
#  8   KI (H)      15 non-null     object
#  9   MA2         1097 non-null   object
#  10  FM2         12 non-null     object
#  11  CP2         53 non-null     object
#  12  PH2         496 non-null    object
#  13  CH2         898 non-null    object
#  14  BY2         441 non-null    object
#  15  EL2         103 non-null    object
#  16  EL2 (H)     44 non-null     object
#  17  ELL2        9 non-null      object
#  18  EC2         793 non-null    object
#  19  EC2 (H)     35 non-null     object
#  20  EH2         74 non-null     object
#  21  EH2 (H)     21 non-null     object
#  22  EG2         61 non-null     object
#  23  EG2 (H)     9 non-null      object
#  24  AP2         11 non-null     object
#  25  MP2         4 non-null      object
#  26  CLL2        32 non-null     object
#  27  CSC2        73 non-null     object
#  28  TRC2        7 non-null      object
#  29  FR2         2 non-null      object
#  30  GM2         6 non-null      object
#  31  JP2         2 non-null      object
#  32  SP2         2 non-null      object
#  33  MA1         0 non-null      object
#  34  PH1         3 non-null      object
#  35  CH1         24 non-null     object
#  36  BY1         2 non-null      object
#  37  EL1         14 non-null     object
#  38  EC1         120 non-null    object
#  39  EH1         1 non-null      object
#  40  EG1         2 non-null      object
#  41  MA3-MOE     34 non-null     object
#  42  PH3-MOE     14 non-null     object
#  43  CH3-MOE     58 non-null     object
#  44  BY3-MOE     22 non-null     object
#  45  EC3-MOE     23 non-null     object
#  46  AP3-MOE     11 non-null     object
#  47  PW.1        1097 non-null   object
#  48  MTL         1093 non-null   object
#  49  P/F         1097 non-null   object
#  50  RANK        1097 non-null   int64
#  51  %           1097 non-null   int64
#  52  MSG/GPA     1097 non-null   float64
#  53  PTS         1097 non-null   float64
#  54  NO OF CCA   1097 non-null   int64
#  55  CCA         1078 non-null   object
#  56  CLL3-MOE    0 non-null      float64
# dtypes: float64(3), int64(4), object(50)
# memory usage: 497.1+ KB
# None
# Batch 19
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1064 entries, 20190001 to 20191099
# Data columns (total 57 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GENDER      1064 non-null   object
#  1   PSLE        1064 non-null   int64
#  2   REPEAT      1064 non-null   object
#  3   INTAKE      1064 non-null   object
#  4   SEC SCHOOL  1064 non-null   object
#  5   PW          1063 non-null   object
#  6   KI          32 non-null     object
#  7   GP/KI       1064 non-null   object
#  8   KI (H)      6 non-null      object
#  9   MA2         1064 non-null   object
#  10  FM2         22 non-null     object
#  11  CP2         57 non-null     object
#  12  PH2         547 non-null    object
#  13  CH2         844 non-null    object
#  14  BY2         353 non-null    object
#  15  EL2         101 non-null    object
#  16  EL2 (H)     42 non-null     object
#  17  ELL2        16 non-null     object
#  18  EC2         814 non-null    object
#  19  EC2 (H)     32 non-null     object
#  20  EH2         81 non-null     object
#  21  EH2 (H)     22 non-null     object
#  22  EG2         46 non-null     object
#  23  EG2 (H)     13 non-null     object
#  24  AP2         10 non-null     object
#  25  MP2         8 non-null      object
#  26  CLL2        38 non-null     object
#  27  CSC2        69 non-null     object
#  28  TRC2        9 non-null      object
#  29  FR2         1 non-null      object
#  30  GM2         5 non-null      object
#  31  SP2         2 non-null      object
#  32  MA1         0 non-null      object
#  33  PH1         10 non-null     object
#  34  CH1         27 non-null     object
#  35  EL1         7 non-null      object
#  36  EC1         84 non-null     object
#  37  EH1         1 non-null      object
#  38  EG1         9 non-null      object
#  39  MA3-MOE     43 non-null     object
#  40  PH3-MOE     40 non-null     object
#  41  CH3-MOE     86 non-null     object
#  42  BY3-MOE     37 non-null     object
#  43  EC3-MOE     21 non-null     object
#  44  AP3-MOE     10 non-null     object
#  45  CLL3-MOE    3 non-null      object
#  46  PW.1        1064 non-null   object
#  47  MTL         1060 non-null   object
#  48  P/F         1064 non-null   object
#  49  RANK        1064 non-null   int64
#  50  %           1064 non-null   int64
#  51  MSG/GPA     1064 non-null   float64
#  52  PTS         1064 non-null   float64
#  53  NO OF CCA   1064 non-null   int64
#  54  CCA         1048 non-null   object
#  55  BY1         0 non-null      float64
#  56  JP2         0 non-null      float64
# dtypes: float64(4), int64(4), object(49)
# memory usage: 482.1+ KB
# None
# Batch 20
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 20200001 to 20201057
# Data columns (total 57 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GENDER      1025 non-null   object
#  1   PSLE        1025 non-null   int64
#  2   REPEAT      1025 non-null   object
#  3   INTAKE      1025 non-null   object
#  4   SEC SCHOOL  1025 non-null   object
#  5   PW          1021 non-null   object
#  6   KI          36 non-null     object
#  7   GP/KI       1025 non-null   object
#  8   KI (H)      11 non-null     object
#  9   MA2         1025 non-null   object
#  10  FM2         14 non-null     object
#  11  CP2         58 non-null     object
#  12  PH2         507 non-null    object
#  13  CH2         846 non-null    object
#  14  BY2         359 non-null    object
#  15  EL2         100 non-null    object
#  16  EL2 (H)     42 non-null     object
#  17  ELL2        15 non-null     object
#  18  EC2         783 non-null    object
#  19  EC2 (H)     35 non-null     object
#  20  EH2         71 non-null     object
#  21  EH2 (H)     25 non-null     object
#  22  EG2         41 non-null     object
#  23  EG2 (H)     5 non-null      object
#  24  AP2         15 non-null     object
#  25  MP2         6 non-null      object
#  26  CLL2        38 non-null     object
#  27  CSC2        74 non-null     object
#  28  TRC2        9 non-null      object
#  29  FR2         5 non-null      object
#  30  GM2         8 non-null      object
#  31  JP2         3 non-null      object
#  32  SP2         2 non-null      object
#  33  MA1         0 non-null      object
#  34  PH1         3 non-null      object
#  35  CH1         10 non-null     object
#  36  EL1         9 non-null      object
#  37  EC1         53 non-null     object
#  38  EG1         4 non-null      object
#  39  MA3-MOE     32 non-null     object
#  40  PH3-MOE     35 non-null     object
#  41  CH3-MOE     84 non-null     object
#  42  BY3-MOE     25 non-null     object
#  43  EC3-MOE     22 non-null     object
#  44  AP3-MOE     14 non-null     object
#  45  CLL3-MOE    1 non-null      object
#  46  PW.1        1021 non-null   object
#  47  MTL         1020 non-null   object
#  48  P/F         1025 non-null   object
#  49  RANK        1025 non-null   int64
#  50  %           1025 non-null   int64
#  51  MSG/GPA     1025 non-null   float64
#  52  PTS         1025 non-null   float64
#  53  NO OF CCA   1025 non-null   int64
#  54  CCA         1011 non-null   object
#  55  EH1         0 non-null      float64
#  56  BY1         0 non-null      float64
# dtypes: float64(4), int64(4), object(49)
# memory usage: 496.7+ KB
# None

# %%
# classify subjects to analyze in groups

# large candidature subjects
subj_large = ['GP/KI', 'MA2', 'PH2', 'CH2', 'BY2', 'EC2', 'PW.1', 'MTL']

# small candidature H2 subjects
subj_small = ['FM2', 'CP2', 'EL2', 'ELL2', 'EH2', 'EG2', 'AP2', 'MP2', 'CLL2', 'CSC2', 'TRC2', 
              'FR2', 'GM2', 'JP2', 'SP2']

# H1 subjects, exclude MA1 as MA2 students cannot take MA1
subj_H1 = ['PH1', 'CH1', 'BY1', 'EL1', 'EC1', 'EG1', 'EH1']

# H3 subjects with different grading scheme
subj_H3 = ['MA3-MOE', 'PH3-MOE', 'CH3-MOE', 'BY3-MOE', 'EC3-MOE', 'AP3-MOE', 'CLL3-MOE']

subj_all = subj_large + subj_small + subj_H1 + subj_H3

# %%
# explore unique values in Grades dataset for Batch 18
for subj in subj_all:
    print(subj, Prelim_Data[0][0][subj].unique())
# Out:
# GP/KI ['B' 'C' 'D' 'A' 'S' 'E' 'MC' 'EX']
# MA2 ['A' 'B' 'C' 'S' 'E' 'D' 'U' 'MC']
# PH2 ['B' 'S' 'D' nan 'C' 'A' 'U' 'E' 'MC']
# CH2 ['A' 'E' 'B' 'C' 'D' nan 'S' 'U' 'MC']
# BY2 [nan 'A' 'B' 'E' 'C' 'MC' 'D' 'U' 'S']
# EC2 ['B' 'E' nan 'C' 'D' 'A' 'U' 'S' 'MC' 'EX']
# PW.1 ['A' 'B']
# MTL ['A' 'B' 'D' 'C' 'E' 'S' nan]
# FM2 [nan 'A' 'B' 'E']
# CP2 [nan 'B' 'D' 'A' 'E' 'S' 'C']
# EL2 [nan 'D' 'B' 'C' 'A']
# ELL2 [nan 'C' 'D' 'B' 'U' 'E']
# EH2 [nan 'E' 'B' 'A' 'D' 'C']
# EG2 [nan 'C' 'B' 'D' 'E' 'A' 'S' 'EX']
# AP2 [nan 'B' 'A']
# MP2 [nan 'A' 'B']
# CLL2 [nan 'A' 'B' 'D' 'C']
# CSC2 [nan 'B' 'A' 'D' 'C' 'S' 'MC' 'E']
# TRC2 [nan 'B' 'A']
# FR2 [nan 'B' 'A']
# GM2 [nan 'A' 'MC' 'B']
# JP2 [nan 'B' 'A']
# SP2 [nan 'A']
# PH1 [nan 'C' 'D' 'B']
# CH1 [nan 'A' 'C' 'E' 'U' 'B' 'D' 'MC']
# BY1 [nan 'B' 'A']
# EL1 [nan 'C' 'B' 'D' 'A']
# EC1 [nan 'B' 'C' 'A' 'D' 'E' 'S']
# EG1 [nan 'B' 'A']
# EH1 [nan 'MC']
# MA3-MOE [nan 'PA' 'ME' 'DI' 'UC']
# PH3-MOE [nan 'ME' 'UC' 'DI']
# CH3-MOE [nan 'ME' 'PA' 'UC' 'DI']
# BY3-MOE [nan 'ME' 'PA' 'DI']
# EC3-MOE [nan 'DI' 'PA' 'ME']
# AP3-MOE [nan 'ME' 'PA' 'DI']
# CLL3-MOE [nan]

# %%
# change 'EX' and 'MC' to 'missed' for all Prelim Grades datasets
for i in range(3):
    for subj in subj_all:
        Prelim_Data[i][0][subj] = Prelim_Data[i][0][subj].map(lambda g: 'missed' if g in ['EX','MC']
                                                              else g)

# %%
def plot_subj(subj_list, title):
    df = pd.DataFrame()
    for i in range(3):
        df_add = Prelim_Data[i][0][subj_list].melt(var_name='Subject', value_name='Grade')
        df_add['Batch'] = i + 18
        df = pd.concat([df, df_add])        
    df.reset_index(inplace=True)

    hist = sns.displot(df.sort_values(['Subject', 'Grade']), x='Grade', col='Subject', col_wrap=4, hue='Batch', palette='Dark2')
    hist.fig.suptitle(f'Distribution of Prelim Grades for '+title, fontsize=24)
    sns.move_legend(hist, 'upper right')
    plt.tight_layout();

# %% [markdown]
# ## Subjects with Large Candidature

# %%
# plot subjects with large candidature
plot_subj(subj_large, "Subjects with Large Candidature")

# %% [markdown]
# The distributions are quite consistent across the 3 batches for subjects with large candidature.

# %% [markdown]
# ## Subjects with Small Candidature
# Some subjects have really small candidatures which we will wish to merge. In particular, we want to find a group for 'JP2' that did not appear in Batch 19.

# %%
# check number of students taking each of the small subjects
for i in range(3):
    print(f'Batch {batch[i]}')
    display(Prelim_Data[i][0][subj_small].info())
# Out:
# Batch 18
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1097 entries, 20180001 to 20181154
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FM2     12 non-null     object
#  1   CP2     53 non-null     object
#  2   EL2     103 non-null    object
#  3   ELL2    9 non-null      object
#  4   EH2     74 non-null     object
#  5   EG2     61 non-null     object
#  6   AP2     11 non-null     object
#  7   MP2     4 non-null      object
#  8   CLL2    32 non-null     object
#  9   CSC2    73 non-null     object
#  10  TRC2    7 non-null      object
#  11  FR2     2 non-null      object
#  12  GM2     6 non-null      object
#  13  JP2     2 non-null      object
#  14  SP2     2 non-null      object
# dtypes: object(15)
# memory usage: 137.1+ KB
# None
# Batch 19
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1064 entries, 20190001 to 20191099
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FM2     22 non-null     object
#  1   CP2     57 non-null     object
#  2   EL2     101 non-null    object
#  3   ELL2    16 non-null     object
#  4   EH2     81 non-null     object
#  5   EG2     46 non-null     object
#  6   AP2     10 non-null     object
#  7   MP2     8 non-null      object
#  8   CLL2    38 non-null     object
#  9   CSC2    69 non-null     object
#  10  TRC2    9 non-null      object
#  11  FR2     1 non-null      object
#  12  GM2     5 non-null      object
#  13  JP2     0 non-null      float64
#  14  SP2     2 non-null      object
# dtypes: float64(1), object(14)
# memory usage: 133.0+ KB
# None
# Batch 20
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 20200001 to 20201057
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FM2     14 non-null     object
#  1   CP2     58 non-null     object
#  2   EL2     100 non-null    object
#  3   ELL2    15 non-null     object
#  4   EH2     71 non-null     object
#  5   EG2     41 non-null     object
#  6   AP2     15 non-null     object
#  7   MP2     6 non-null      object
#  8   CLL2    38 non-null     object
#  9   CSC2    74 non-null     object
#  10  TRC2    9 non-null      object
#  11  FR2     5 non-null      object
#  12  GM2     8 non-null      object
#  13  JP2     3 non-null      object
#  14  SP2     2 non-null      object
# dtypes: object(15)
# memory usage: 160.4+ KB
# None

# %% [markdown]
# By nature of the subjects, the foreign language subjects are most similar and each student can at most take 1 foreign language. We decide to combine French, German, Spanish and Japanese into a new category 'Foreign_Lang'.

# %%
# combine 'FR2','GM2','SP2','JP2' into new column 'Foreign_Lang'
for i in range(3):
    Prelim_Data[i][0]['Foreign_Lang'] = np.nan
    for lang in ['FR2','GM2','SP2','JP2']:
        Prelim_Data[i][0]['Foreign_Lang'].fillna(Prelim_Data[i][0][lang], inplace=True)

# %%
# update list of subjects with small candidature
subj_small = ['FM2', 'CP2', 'EL2', 'ELL2', 'EH2', 'EG2', 'AP2', 'MP2', 'CLL2', 'CSC2', 'TRC2', 
              'Foreign_Lang']

# plot subjects with small candidature
plot_subj(subj_small, "Subjects with Small Candidature")

# %% [markdown]
# There is more variation in the distribution across the batches for subjects with small candidature. H2 Music ('MP2') has the smallest candidature after merging the foreign languages, but we decided not to merge this with any other subject as this subject is no longer offered in this JC from Batch 21 onwards.

# %% [markdown]
# ## H1 Subjects
# Each student can only read one H1 content subject, so we can consider merging any of these into a single column. In particular, we wish to find a group for 'BY1' and 'EH1'.

# %%
# check number of students taking each of the H1 subjects
for i in range(3):
    print(f'Batch {batch[i]}')
    display(Prelim_Data[i][0][subj_H1].info())
# Out:
# Batch 18
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1097 entries, 20180001 to 20181154
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PH1     3 non-null      object
#  1   CH1     24 non-null     object
#  2   BY1     2 non-null      object
#  3   EL1     14 non-null     object
#  4   EC1     120 non-null    object
#  5   EG1     2 non-null      object
#  6   EH1     1 non-null      object
# dtypes: object(7)
# memory usage: 68.6+ KB
# None
# Batch 19
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1064 entries, 20190001 to 20191099
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PH1     10 non-null     object
#  1   CH1     27 non-null     object
#  2   BY1     0 non-null      float64
#  3   EL1     7 non-null      object
#  4   EC1     84 non-null     object
#  5   EG1     9 non-null      object
#  6   EH1     1 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 66.5+ KB
# None
# Batch 20
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 20200001 to 20201057
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PH1     3 non-null      object
#  1   CH1     10 non-null     object
#  2   BY1     0 non-null      float64
#  3   EL1     9 non-null      object
#  4   EC1     53 non-null     object
#  5   EG1     4 non-null      object
#  6   EH1     0 non-null      float64
# dtypes: float64(2), object(5)
# memory usage: 96.4+ KB
# None

# %%
# plot H1 subjects
plot_subj(subj_H1, "H1 Subjects")

# %% [markdown]
# H1 Economics ('EC1') has the largest candidature but in Batch 20 it has decreased to 53 only. As the numbers are small, we decide to merge all H1 subjects into one column.

# %%
# combine all H1 subjects into new column 'H1'
for i in range(3):
    Prelim_Data[i][0]['H1'] = np.nan
    for h1 in subj_H1:
        Prelim_Data[i][0]['H1'].fillna(Prelim_Data[i][0][h1], inplace=True)

# %% [markdown]
# ## H3 Subjects
# Most students can only take at most one H3 subject. On the very rare occasions where students are allowed 2 H3 subjects (usually need approval from MOE), these students typically choose to take a university H3 and not both MOE H3. We consider merging some columns. In particular, we wish to find a group for 'CLL3-MOE'.

# %%
# check number of students taking each of the H3 subjects
for i in range(3):
    print(f'Batch {batch[i]}')
    display(Prelim_Data[i][0][subj_H3].info())
# Out:
# Batch 18
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1097 entries, 20180001 to 20181154
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MA3-MOE   34 non-null     object
#  1   PH3-MOE   14 non-null     object
#  2   CH3-MOE   58 non-null     object
#  3   BY3-MOE   22 non-null     object
#  4   EC3-MOE   23 non-null     object
#  5   AP3-MOE   11 non-null     object
#  6   CLL3-MOE  0 non-null      float64
# dtypes: float64(1), object(6)
# memory usage: 68.6+ KB
# None
# Batch 19
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1064 entries, 20190001 to 20191099
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MA3-MOE   43 non-null     object
#  1   PH3-MOE   40 non-null     object
#  2   CH3-MOE   86 non-null     object
#  3   BY3-MOE   37 non-null     object
#  4   EC3-MOE   21 non-null     object
#  5   AP3-MOE   10 non-null     object
#  6   CLL3-MOE  3 non-null      object
# dtypes: object(7)
# memory usage: 66.5+ KB
# None
# Batch 20
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 20200001 to 20201057
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MA3-MOE   32 non-null     object
#  1   PH3-MOE   35 non-null     object
#  2   CH3-MOE   84 non-null     object
#  3   BY3-MOE   25 non-null     object
#  4   EC3-MOE   22 non-null     object
#  5   AP3-MOE   14 non-null     object
#  6   CLL3-MOE  1 non-null      object
# dtypes: object(7)
# memory usage: 96.4+ KB
# None

# %%
# plot H3 subjects
plot_subj(subj_H3, "H3 Subjects")

# %% [markdown]
# We decide to merge all H3 subjects into one column as these are all academically strong students who meet the criteria to take H3 in JC2.

# %%
# combine all H3 subjects into new column 'H3'
for i in range(3):
    Prelim_Data[i][0]['H3'] = np.nan
    for h3 in subj_H3:
        Prelim_Data[i][0]['H3'].fillna(Prelim_Data[i][0][h3], inplace=True)

# %% [markdown]
# ## Finding columns with high correlation to Target
# We map the grades to numbers so that we can calculate the correlation coefficients, giving the smallest number 1 for the best grade of A or Distinction.
#
# For H1, we handle the missing values by assigning them to 0 as these students did not have to downgrade to H1 and take the more challenging syllabus of H2, so they are likely better than students who scored A (or 1) in the corresponding H1 subject.
#
# For H3, we do it the other way round, assiging the largest number of 5 as H3 is an additional subject taken by academically strong students, so students who take H3, regardless of their Prelim grade in the subject, are generally better than those who do not.

# %%
Prelim_Data[0][0].columns
# Out:
# Index(['GENDER', 'PSLE', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'PW', 'GP/KI', 'KI',
#        'KI (H)', 'MA2', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'EL2 (H)',
#        'ELL2', 'EC2', 'EC2 (H)', 'EH2', 'EH2 (H)', 'EG2', 'EG2 (H)', 'AP2',
#        'MP2', 'CLL2', 'CSC2', 'TRC2', 'FR2', 'GM2', 'JP2', 'SP2', 'MA1', 'PH1',
#        'CH1', 'BY1', 'EL1', 'EC1', 'EH1', 'EG1', 'MA3-MOE', 'PH3-MOE',
#        'CH3-MOE', 'BY3-MOE', 'EC3-MOE', 'AP3-MOE', 'PW.1', 'MTL', 'P/F',
#        'RANK', '%', 'MSG/GPA', 'PTS', 'NO OF CCA', 'CCA', 'CLL3-MOE',
#        'Foreign_Lang', 'H1', 'H3'],
#       dtype='object')

# %%
features_subj = ['GP/KI', 'MA2', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'ELL2', 
                 'EC2', 'EH2', 'EG2', 'AP2', 'MP2', 'CLL2', 'CSC2', 'TRC2',
                 'PW.1', 'MTL', 'Foreign_Lang'
                ]
features_test = features_subj + ['H1', 'H3', '%', 'MSG/GPA', 'PTS', 'NO OF CCA']

# %%
# create dataframes with prelim grades and targets for Batches 18 and 19
test_18 = pd.concat([Prelim_Data[0][0][features_test], y_18], axis=1)
test_19 = pd.concat([Prelim_Data[1][0][features_test], y_19], axis=1)

# map Prelim grades to numbers, changing 'missed' to NaN for calculating correlation
grade_dict = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'S': 6, 'U': 7, 
              'missed': np.nan, np.nan: np.nan
             }

grade_dict_H1 = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'S': 6, 'U': 7, 
                 'missed': np.nan, np.nan: 0
                }

grade_dict_H3 = {'DI': 1, 'ME': 2, 'PA': 3, 'UC': 4, 'missed': np.nan, np.nan: 5}

for subj in features_subj:
    test_18[subj] = test_18[subj].map(grade_dict)
    test_19[subj] = test_19[subj].map(grade_dict)
    
test_18['H1'] = test_18['H1'].map(grade_dict_H1)
test_19['H1'] = test_19['H1'].map(grade_dict_H1)
test_18['H3'] = test_18['H3'].map(grade_dict_H3)
test_19['H3'] = test_19['H3'].map(grade_dict_H3)

# %%
# features ranked by magnitude of correlation to Target
corr_18 = test_18.corr().tail(1).T.sort_values('Target', key=abs, ascending=False)
corr_19 = test_19.corr().tail(1).T.sort_values('Target', key=abs, ascending=False)
corr_18.rename(columns={'Target': 'Correlation with Target'}, inplace=True)
corr_19.rename(columns={'Target': 'Correlation with Target'}, inplace=True)

display(corr_18)
print('Batch 18')
display(corr_19)
print('Batch 19')
# Out:
#               Correlation with Target
# Target                       1.000000
# CP2                          0.774584
# MA2                          0.725708
# ELL2                         0.695701
# PTS                         -0.682699
# AP2                          0.652753
# MSG/GPA                      0.646510
# CH2                          0.600251
# BY2                          0.578643
# %                           -0.562441
# PH2                          0.542085
# EG2                          0.512297
# H1                           0.494982
# EH2                          0.471497
# EL2                          0.371311
# EC2                          0.332787
# CSC2                         0.248970
# GP/KI                        0.238972
# Foreign_Lang                -0.193649
# CLL2                         0.171666
# PW.1                         0.169326
# H3                           0.153096
# NO OF CCA                   -0.116975
# MTL                          0.109764
# TRC2                        -0.091287
# FM2                               NaN
# MP2                               NaN
# Batch 18
#               Correlation with Target
# Target                       1.000000
# MA2                          0.670474
# PTS                         -0.662472
# MSG/GPA                      0.643349
# BY2                          0.601598
# CH2                          0.585979
# PH2                          0.581540
# CP2                          0.577308
# ELL2                         0.571945
# %                           -0.553035
# EG2                          0.532184
# AP2                          0.500000
# H1                           0.497503
# TRC2                         0.497291
# EH2                          0.442295
# CSC2                         0.382931
# EC2                          0.349645
# Foreign_Lang                 0.333333
# H3                           0.213899
# GP/KI                        0.207205
# EL2                          0.199569
# CLL2                         0.176379
# NO OF CCA                   -0.135955
# MTL                          0.066710
# PW.1                         0.010228
# FM2                               NaN
# MP2                               NaN
# Batch 19

# %%
# investigate why correlation with 'FM2' and 'MP2' is NaN
print(' FM2 '.center(25, "="))
print('Batch 18')
print(test_18[test_18['FM2'].notna()][['FM2','Target']].value_counts())
print()
print('Batch 19')
print(test_19[test_19['FM2'].notna()][['FM2','Target']].value_counts())
print()
print(' MP2 '.center(25, "="))
print('Batch 18')
print(test_18[test_18['MP2'].notna()][['MP2','Target']].value_counts())
print()
print('Batch 19')
print(test_19[test_19['MP2'].notna()][['MP2','Target']].value_counts())
print()
# Out:
# ========== FM2 ==========
# Batch 18
# FM2  Target
# 2.0  1         6
# 1.0  1         5
# 5.0  1         1
# dtype: int64
#
# Batch 19
# FM2  Target
# 1.0  1         8
# 4.0  1         5
# 2.0  1         3
# 6.0  1         3
# 3.0  1         2
# 5.0  1         1
# dtype: int64
#
# ========== MP2 ==========
# Batch 18
# MP2  Target
# 1.0  1         2
# 2.0  1         2
# dtype: int64
#
# Batch 19
# MP2  Target
# 1.0  1         6
#      2         1
#      3         1
# dtype: int64

# %% [markdown]
# Correlation coefficients with 'FM2' and 'MP2' cannot be calculated as there is zero variation in either the subject or the target.

# %%
# plot heatmap of correlations for Batch 18, remove 'FM2' and 'MP2'
sns.heatmap(test_18[corr_18.index[:-2]].corr(), cmap='coolwarm', annot=True, annot_kws={'size': 10});

# %%
# plot heatmap of correlations for Batch 19, remove 'FM2' and 'MP2'
sns.heatmap(test_19[corr_19.index[:-2]].corr(), cmap='coolwarm', annot=True, annot_kws={'size': 10});

# %% [markdown]
# The 3 features for overall results, 'PTS', 'MSG/GPA' and '%', are very highly inter-correlated (magnitude more than 0.9), so we decide to use only the feature with the highest correlation with our Target, which is 'PTS' and drop 'MSG/GPA' and '%'.
#
# Many of the subjects are also highly inter-correlated. For example, if we look at the row for 'PTS', we see that many of the subjects have a strong linear correlation with PTS with a magnitude of more than 0.8.
#
# Some features have very low correlation (less than 0.2) with the target, such as 'PW.1', 'MTL', 'NO OF CCA' so we will remove them.
#
# To minimize the problem of imputing missing values (thus creating fictitious data), we will only keep the subjects with minimal missing values, which are 'GP/KI', 'MA2', 'H1' and 'H3'. The null entries of 'H1' and 'H3' will be converted to level 0 and level 5 as before. The 'missed' entries will have to be imputed after more data exploration as we will need to predict an A Level grade for every single student, so we cannot drop any row.
#
# We will also drop 'REPEAT' and 'P/F' as these columns have very low variability (almost all the values are the same).

# %% [markdown]
# ## Choosing 'MA2' Grades, Marks or Percentiles to use
# We note from above that the correlation of 'MA2' Grades with the Target is around 0.7 (0.73 for Batch 18 and 0.67 for Batch 19). We find the correlation of 'MA2' Marks and Percentiles with the Target to see if we should use any of them in place of Grades.

# %%
# calculate correlation coefficients witht Target
for j in range (1,3):
    print(f' {dataset_type[j]} '.center(17, "="))
    df = pd.to_numeric(Prelim_Data[0][j]['MA2'], errors='coerce')
    print(f"Batch 18: {round(df.corr(test_18['Target']),4)}")
    df = pd.to_numeric(Prelim_Data[1][j]['MA2'], errors='coerce')
    print(f"Batch 19: {round(df.corr(test_19['Target']),4)}")
    print()
# Out:
# ===== Marks =====
# Batch 18: -0.6731
# Batch 19: -0.6578
#
# == Percentiles ==
# Batch 18: -0.6008
# Batch 19: -0.5852

# %%
# proportion of students in lowest grade category of 'U'
print(" Proportion of U ".center(23, "="))
for i in range(3):
    print(f"Batch {batch[i]}: {round(Prelim_Data[i][0]['MA2'].value_counts(normalize=True)['U'],2)*100}%")
# Out:
# === Proportion of U ===
# Batch 18: 6.0%
# Batch 19: 9.0%
# Batch 20: 9.0%

# %% [markdown]
# The correlations with Marks and Percentiles are weaker than with Grades. However, the proportion of Targets in the category we are most interested in (less than 0.8% of students score E, S or U in A levels and need more attention) is much lower than the number of students in the lowest grade category of U in Prelims (around 6%-9%), we would be unable to capture the Target 'ESU' group well with just grade information.
#
# Between Marks and Percentiles, Marks has a higher linear correlation with our Target. Hence we will use 'MA2' Marks in our modelling.

# %% [markdown]
# ## Create new dataframes with information for modelling
# We will create new dataframes to contain the final features that we will use for modelling. We One-Hot Encode nominal features 'GENDER', 'INTAKE', 'SEC SCHOOL' and keep the information of content subjects taken through One-Hot Encoding as well. The numerical features remaining are transformed from the grades of 'GP/KI', 'H1' and 'H3', the overall performance indicator 'PTS', as well as the marks of 'MA2'.

# %%
# Create datasets of feature list with 'MA2' Marks
Prelim_Features_18 = pd.DataFrame()
Prelim_Features_19 = pd.DataFrame()
Prelim_Features_20 = pd.DataFrame()
Prelim_Features = [Prelim_Features_18, Prelim_Features_19, Prelim_Features_20]

# list of subjects to one-hot encode, exclude MA2, MA1, versions of subjects with (H)
# keep 'Foreign_Lang' instead of 'FR2', 'GM2', 'JP2', 'SP2'

# for H1, keep only 'EC1' with largest candidature and merge the rest into 'H1_Arts' or 'H1_Sci'

# for H3, merge 'CLL3-MOE' and 'EC3-MOE' into 'CLL3_EC3-MOE'

subj_to_encode = ['KI', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'ELL2', 'EC2', 
                  'EH2', 'EG2', 'AP2', 'MP2', 'CLL2', 'CSC2', 'TRC2', 'EC1', 
                  'MA3-MOE', 'PH3-MOE', 'CH3-MOE', 'BY3-MOE', 'AP3-MOE', 'Foreign_Lang']

for i in range(3): 
    # One-Hot Encode Gender, Intake and Sec School
    Prelim_Features[i] = pd.get_dummies(Prelim_Data[i][0][['GENDER', 'INTAKE', 'SEC SCHOOL']])
    
    # One-Hot Encode subjects taken
    for subj in subj_to_encode:
        Prelim_Features[i][subj] = Prelim_Data[i][0][subj].notna().astype('int')
    
    # Merge 'EL1', 'EH1', 'EG1' into 'H1_Arts'
    Prelim_Features[i]['H1_Arts'] = (Prelim_Data[i][0]['EL1'].notna()|\
                                     Prelim_Data[i][0]['EH1'].notna()|\
                                     Prelim_Data[i][0]['EG1'].notna()).astype('int')
    # Merge 'PH1', 'CH1', 'BY1' into 'H1_Sci'
    Prelim_Features[i]['H1_Sci'] = (Prelim_Data[i][0]['PH1'].notna()|\
                                    Prelim_Data[i][0]['CH1'].notna()|\
                                    Prelim_Data[i][0]['BY1'].notna()).astype('int')
    # merge 'CLL3-MOE' and 'EC3-MOE' into 'CLL3_EC3-MOE'
    Prelim_Features[i]['CLL3_EC3-MOE'] = (Prelim_Data[i][0]['CLL3-MOE'].notna()|\
                                          Prelim_Data[i][0]['EC3-MOE'].notna()).astype('int')
    
    # MA2 marks with 'EX'/'MC' mapped to 'missed'
    Prelim_Features[i]['MA2'] = Prelim_Data[i][1]['MA2'].map(lambda m: 'missed' if m in ['EX','MC']
                                                              else m)
    # PTS
    Prelim_Features[i]['PTS'] = Prelim_Data[i][0]['PTS']
    
    # Grades (keeping NaN until all 'missed' values are imputed)
    for subj in ['GP/KI', 'H1', 'H3']:
        Prelim_Features[i][subj] = Prelim_Data[i][0][subj]
    
    # check dataframes
    display(Prelim_Features[i].head())
    print(f'Batch {batch[i]}')
# Out:
#           GENDER_F  GENDER_M  INTAKE_DSA  INTAKE_DSA (CCA)  INTAKE_IP (HCI)  \
# NEWID
# 20180001         0         1           0                 0                1
# 20180002         1         0           0                 0                0
# 20180003         1         0           0                 0                0
# 20180005         0         1           0                 0                0
# 20180006         0         1           0                 0                0
#
#           INTAKE_IP (NYGH)  INTAKE_JAE Ordinary Admission  \
# NEWID
# 20180001                 0                              0
# 20180002                 0                              1
# 20180003                 1                              0
# 20180005                 0                              1
# 20180006                 0                              1
#
#           SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL  \
# NEWID
# 20180001                                           0
# 20180002                                           0
# 20180003                                           0
# 20180005                                           0
# 20180006                                           0
#
#           SEC SCHOOL_CATHOLIC HIGH SCHOOL  \
# NEWID
# 20180001                                0
# 20180002                                0
# 20180003                                0
# 20180005                                0
# 20180006                                1
#
#           SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL  ...  AP3-MOE  \
# NEWID                                                 ...
# 20180001                                           0  ...        0
# 20180002                                           0  ...        0
# 20180003                                           0  ...        0
# 20180005                                           0  ...        0
# 20180006                                           0  ...        0
#
#           Foreign_Lang  H1_Arts  H1_Sci  CLL3_EC3-MOE   MA2   PTS  GP/KI   H1  \
# NEWID
# 20180001             0        0       0             0  69.5  85.0      B  NaN
# 20180002             0        0       0             0    84  80.0      C  NaN
# 20180003             0        0       0             0  61.5  57.5      C  NaN
# 20180005             0        0       0             0  56.5  65.0      D  NaN
# 20180006             0        0       0             0  66.5  87.5      A  NaN
#
#            H3
# NEWID
# 20180001  NaN
# 20180002  NaN
# 20180003  NaN
# 20180005  NaN
# 20180006   ME
#
# [5 rows x 48 columns]
# Batch 18
#           GENDER_F  GENDER_M  INTAKE_DSA  INTAKE_DSA (CCA)  INTAKE_IP (HCI)  \
# NEWID
# 20190001         0         1           0                 1                0
# 20190002         0         1           0                 0                1
# 20190003         0         1           0                 0                1
# 20190004         0         1           0                 0                1
# 20190005         0         1           0                 0                0
#
#           INTAKE_IP (NYGH)  INTAKE_JAE Ordinary Admission  \
# NEWID
# 20190001                 0                              0
# 20190002                 0                              0
# 20190003                 0                              0
# 20190004                 0                              0
# 20190005                 0                              1
#
#           SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL  \
# NEWID
# 20190001                                           0
# 20190002                                           0
# 20190003                                           0
# 20190004                                           0
# 20190005                                           0
#
#           SEC SCHOOL_CATHOLIC HIGH SCHOOL  \
# NEWID
# 20190001                                1
# 20190002                                0
# 20190003                                0
# 20190004                                0
# 20190005                                0
#
#           SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL  ...  AP3-MOE  \
# NEWID                                                 ...
# 20190001                                           0  ...        0
# 20190002                                           0  ...        0
# 20190003                                           0  ...        0
# 20190004                                           0  ...        0
# 20190005                                           0  ...        0
#
#           Foreign_Lang  H1_Arts  H1_Sci  CLL3_EC3-MOE   MA2    PTS  GP/KI  \
# NEWID
# 20190001             0        0       0             0    41  47.50      S
# 20190002             0        0       0             0  71.5  88.75      A
# 20190003             0        0       0             0    63  81.25      B
# 20190004             0        0       0             0    49  58.75      C
# 20190005             0        0       0             0  37.5  50.00      C
#
#            H1   H3
# NEWID
# 20190001    E  NaN
# 20190002  NaN   DI
# 20190003  NaN  NaN
# 20190004  NaN  NaN
# 20190005  NaN  NaN
#
# [5 rows x 48 columns]
# Batch 19
#           GENDER_F  GENDER_M  INTAKE_DSA  INTAKE_DSA (CCA)  INTAKE_IP (HCI)  \
# NEWID
# 20200001         1         0           0                 0                0
# 20200002         1         0           0                 0                0
# 20200003         1         0           0                 0                0
# 20200004         0         1           0                 0                1
# 20200005         1         0           0                 0                0
#
#           INTAKE_IP (NYGH)  INTAKE_JAE Ordinary Admission  \
# NEWID
# 20200001                 0                              1
# 20200002                 1                              0
# 20200003                 0                              1
# 20200004                 0                              0
# 20200005                 1                              0
#
#           SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL  \
# NEWID
# 20200001                                           0
# 20200002                                           0
# 20200003                                           0
# 20200004                                           0
# 20200005                                           0
#
#           SEC SCHOOL_CATHOLIC HIGH SCHOOL  \
# NEWID
# 20200001                                0
# 20200002                                0
# 20200003                                0
# 20200004                                0
# 20200005                                0
#
#           SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL  ...  AP3-MOE  \
# NEWID                                                 ...
# 20200001                                           0  ...        0
# 20200002                                           0  ...        0
# 20200003                                           0  ...        0
# 20200004                                           0  ...        0
# 20200005                                           0  ...        0
#
#           Foreign_Lang  H1_Arts  H1_Sci  CLL3_EC3-MOE   MA2    PTS  GP/KI  \
# NEWID
# 20200001             0        0       0             0    68  85.00      B
# 20200002             0        0       0             0  62.8  78.75      B
# 20200003             0        0       0             0  64.2  66.25      B
# 20200004             0        0       0             0    50  52.50      C
# 20200005             0        0       0             0  40.2  43.75      D
#
#            H1   H3
# NEWID
# 20200001  NaN  NaN
# 20200002  NaN  NaN
# 20200003  NaN  NaN
# 20200004  NaN  NaN
# 20200005  NaN  NaN
#
# [5 rows x 48 columns]
# Batch 20

# %% [markdown]
# # (3) C1 Grades, Marks and Percentiles

# %%
# load Batch 18 datasets on C1 Results
C1_Grades_18 = pd.read_csv('../data_raw/18 Batch C1 Grades.csv', index_col='NEWID')
C1_Marks_18 = pd.read_csv('../data_raw/18 Batch C1 Marks.csv', index_col='NEWID')
C1_Perc_18 = pd.read_csv('../data_raw/18 Batch C1 Percentiles.csv', index_col='NEWID')

# load Batch 19 datasets on C1 Results
C1_Grades_19 = pd.read_csv('../data_raw/19 Batch C1 Grades.csv', index_col='NEWID')
C1_Marks_19 = pd.read_csv('../data_raw/19 Batch C1 Marks.csv', index_col='NEWID')
C1_Perc_19 = pd.read_csv('../data_raw/19 Batch C1 Percentiles.csv', index_col='NEWID')

# load Batch 20 datasets on C1 Results
C1_Grades_20 = pd.read_csv('../data_raw/20 Batch C1 Grades.csv', index_col='NEWID')
C1_Marks_20 = pd.read_csv('../data_raw/20 Batch C1 Marks.csv', index_col='NEWID')
C1_Perc_20 = pd.read_csv('../data_raw/20 Batch C1 Percentiles.csv', index_col='NEWID')

# %%
# for looping purposes
C1_Data = [[C1_Grades_18, C1_Marks_18, C1_Perc_18, C1_Grades_18],
           [C1_Grades_19, C1_Marks_19, C1_Perc_19, C1_Grades_19],
           [C1_Grades_20, C1_Marks_20, C1_Perc_20, C1_Grades_20],
           [C1_Grades_18, C1_Marks_18, C1_Perc_18, C1_Grades_18]
          ]

# drop students who did not take MA2 and print shape
for i in range(3):
    print(f' Batch {batch[i]} '.center(30, "="))
    for j in range(3):
        C1_Data[i][j].drop(index=ind_list[i], inplace=True)
        print(f"{dataset_type[j]}: {C1_Data[i][j].shape}")
    print()
# Out:
# ========== Batch 18 ==========
# Grades: (1097, 50)
# Marks: (1097, 44)
# Percentiles: (1097, 44)
#
# ========== Batch 19 ==========
# Grades: (1064, 51)
# Marks: (1064, 45)
# Percentiles: (1064, 45)
#
# ========== Batch 20 ==========
# Grades: (1025, 50)
# Marks: (1025, 44)
# Percentiles: (1025, 44)

# %% [markdown]
# The number of rows match with the Prelim datasets. We look into the differences in column names.

# %%
for i in range(3):
    print(f" Batch {batch[i]} ".center(50, "="))
    for j in range(3):
        print(f"In {dataset_type[j]} dataset but not in {dataset_type[j+1]} dataset:")
        print_diff(C1_Data[i][j],C1_Data[i][j+1])
    print()
    
print(" Differences between Batches ".center(50, "="))
for i in range(3): 
    print(f"In Batch {batch[i]} dataset but not in Batch {batch[i+1]} dataset:")
    print_diff(C1_Data[i][0],C1_Data[i+1][0])
    print(f"In Batch {batch[i+1]} dataset but not in Batch {batch[i]} dataset:")
    print_diff(C1_Data[i+1][0],C1_Data[i][0])
    print()
# Out:
# ==================== Batch 18 ====================
# In Grades dataset but not in Marks dataset:
# ['%' 'MSG/GPA' 'MTL' 'P/F' 'PTS' 'PW' 'RANK']
# In Marks dataset but not in Percentiles dataset:
# []
# In Percentiles dataset but not in Grades dataset:
# ['SN']
#
# ==================== Batch 19 ====================
# In Grades dataset but not in Marks dataset:
# ['%' 'MSG/GPA' 'MTL' 'P/F' 'PTS' 'PW' 'RANK']
# In Marks dataset but not in Percentiles dataset:
# []
# In Percentiles dataset but not in Grades dataset:
# ['SN']
#
# ==================== Batch 20 ====================
# In Grades dataset but not in Marks dataset:
# ['%' 'MSG/GPA' 'MTL' 'P/F' 'PTS' 'PW' 'RANK']
# In Marks dataset but not in Percentiles dataset:
# []
# In Percentiles dataset but not in Grades dataset:
# ['SN']
#
# ========== Differences between Batches ===========
# In Batch 18 dataset but not in Batch 19 dataset:
# ['GSC' 'JP2']
# In Batch 19 dataset but not in Batch 18 dataset:
# ['JP1' 'PH1' 'TL']
#
# In Batch 19 dataset but not in Batch 20 dataset:
# ['EH1' 'HIL' 'JP1']
# In Batch 20 dataset but not in Batch 19 dataset:
# ['GSC' 'JP2']
#
# In Batch 20 dataset but not in Batch 18 dataset:
# ['PH1' 'TL']
# In Batch 18 dataset but not in Batch 20 dataset:
# ['EH1' 'HIL']

# %% [markdown]
# ## Differences in columns
# The differences within the same batch are similar to those for the Prelim datasets. There are some additional subjects that are different for C1 datasets.
#
# For the Prelim datasets, there are H3 subjects (including the missing 'CLL3-MOE' in Batch 18) that do not appear in the C1 datasets as these subjects are only taken up in JC2.
#
# For the C1 datasets, there are some H1 subjects that are examined at the end of JC1, such as 'GSC', 'JP1, 'TL', 'HIL' so they do not appear in the Prelim datasets. We ignore them and do not include them under the 'H1' column.
#
# 'BY1' is not in the C1 datasets but in the Prelim datasets because the student(s) only downgraded from H2 Biology to H1 Biology in JC2. Similarly, 'PH1' is not in the C1 Batch 18 datasets, because the student(s) only downgraded from H2 Physics to H1 Physics in JC2.

# %%
# create columns of NaN in dataframes where H1 subjects were missing
C1_Data[0][0]['PH1'] = np.nan
C1_Data[2][0]['EH1'] = np.nan

# display grades dataframe head
for i in range(3):
    display(C1_Data[i][0].head())
    print(f'Batch {batch[i]}')
# Out:
#          GENDER  PSLE REPEAT                  INTAKE  \
# NEWID
# 20180001      M   260    NaN                IP (HCI)
# 20180002      F   253    NaN  JAE Ordinary Admission
# 20180003      F   262    NaN               IP (NYGH)
# 20180005      M   237    NaN  JAE Ordinary Admission
# 20180006      M   246    NaN  JAE Ordinary Admission
#
#                                    SEC SCHOOL   GP   KI KI (H) MA2  FM2  ...  \
# NEWID                                                                    ...
# 20180001  HWA CHONG INSTITUTION (HIGH SCHOOL)    C  NaN    NaN   B  NaN  ...
# 20180002  METHODIST GIRLS' SCHOOL (SECONDARY)    D  NaN    NaN   A  NaN  ...
# 20180003           NANYANG GIRLS' HIGH SCHOOL    C  NaN    NaN   S  NaN  ...
# 20180005             MARIS STELLA HIGH SCHOOL    D  NaN    NaN   A  NaN  ...
# 20180006                 CATHOLIC HIGH SCHOOL  NaN    A    NaN   B  NaN  ...
#
#          PW MTL     P/F   RANK     % MSG/GPA    PTS NO OF CCA  \
# NEWID
# 20180001  A   A  Passed  256.0  78.0     2.0  70.00         1
# 20180002  A   B  Passed  185.0  84.0     1.5  72.50         1
# 20180003  A   B  Passed  940.0  19.0     4.8  45.00         1
# 20180005  B   B  Passed  624.0  46.0     3.3  58.75         1
# 20180006  A   B  Passed  125.0  89.0     1.5  75.00         1
#
#                                                      CCA PH1
# NEWID
# 20180001                                 SQUASH (Member) NaN
# 20180002                         SYMPHONIC BAND (Member) NaN
# 20180003                         BADMINTON (Welfare I/C) NaN
# 20180005                                LIBRARY (Member) NaN
# 20180006  HWA CHONG PUBLICATIONS SOCIETY (HCPS) (Editor) NaN
#
# [5 rows x 51 columns]
# Batch 18
#          GENDER  PSLE REPEAT                  INTAKE  \
# NEWID
# 20190001      M   189    NaN               DSA (CCA)
# 20190002      M   256    NaN                IP (HCI)
# 20190003      M   231    NaN                IP (HCI)
# 20190004      M   255    NaN                IP (HCI)
# 20190005      M     0    NaN  JAE Ordinary Admission
#
#                                    SEC SCHOOL GP   KI KI (H) MA2  FM2  ...  \
# NEWID                                                                  ...
# 20190001                 CATHOLIC HIGH SCHOOL  E  NaN    NaN   D  NaN  ...
# 20190002  HWA CHONG INSTITUTION (HIGH SCHOOL)  A  NaN    NaN   A  NaN  ...
# 20190003  HWA CHONG INSTITUTION (HIGH SCHOOL)  C  NaN    NaN   D  NaN  ...
# 20190004  HWA CHONG INSTITUTION (HIGH SCHOOL)  C  NaN    NaN   C  NaN  ...
# 20190005             MARIS STELLA HIGH SCHOOL  D  NaN    NaN   D  NaN  ...
#
#           HIL PW MTL     P/F    RANK      % MSG/GPA    PTS NO OF CCA  \
# NEWID
# 20190001  NaN  A   E  Passed  1078.0    3.0     5.9  22.50         1
# 20190002  NaN  A   B  Passed     1.0  100.0     1.0  80.00         1
# 20190003  NaN  A   A  Passed   569.0   48.0     3.0  61.25         1
# 20190004  NaN  B   B  Passed  1007.0    9.0     5.3  37.50         1
# 20190005  NaN  A   A  Passed   803.0   27.0     4.0  51.25         1
#
#                                                      CCA
# NEWID
# 20190001                               SOFTBALL (Member)
# 20190002  HWA CHONG PUBLICATIONS SOCIETY (HCPS) (Member)
# 20190003                              BADMINTON (Member)
# 20190004                               FOOTBALL (Member)
# 20190005      INTERACT CLUB (Community Service Director)
#
# [5 rows x 51 columns]
# Batch 19
#          GENDER  PSLE REPEAT                  INTAKE  \
# NEWID
# 20200001      F     0    NaN  JAE Ordinary Admission
# 20200002      F     0    NaN               IP (NYGH)
# 20200003      F     0    NaN  JAE Ordinary Admission
# 20200004      M     0    NaN                IP (HCI)
# 20200005      F     0    NaN               IP (NYGH)
#
#                                            SEC SCHOOL   KI GP KI (H) MA2  FM2  \
# NEWID
# 20200001  SCHOOL OF SCIENCE AND TECHNOLOGY, SINGAPORE  NaN  B    NaN   B  NaN
# 20200002                   NANYANG GIRLS' HIGH SCHOOL  NaN  C    NaN   B  NaN
# 20200003                        NAN CHIAU HIGH SCHOOL  NaN  C    NaN   B  NaN
# 20200004          HWA CHONG INSTITUTION (HIGH SCHOOL)  NaN  D    NaN   C  NaN
# 20200005                   NANYANG GIRLS' HIGH SCHOOL  NaN  C    NaN   S  NaN
#
#           ... PW MTL     P/F   RANK     % MSG/GPA    PTS NO OF CCA  \
# NEWID     ...
# 20200001  ...  A   E  Passed  324.0  69.0     1.8  72.50         1
# 20200002  ...  A   A  Passed  580.0  45.0     2.5  66.25         1
# 20200003  ...  A   A  Passed  841.0  21.0     3.8  55.00         1
# 20200004  ...  A   B  Passed  772.0  27.0     3.3  58.75         2
# 20200005  ...  A   A  Passed  895.0  16.0     4.3  50.00         1
#
#                                                       CCA EH1
# NEWID
# 20200001                              LIBRARY (President) NaN
# 20200002        TRACK & FIELD (Sectional Leader - Throws) NaN
# 20200003                          SYMPHONIC BAND (Member) NaN
# 20200004  CROSS-COUNTRY (Captain), TRACK & FIELD (Member) NaN
# 20200005             CHINESE CALLIGRAPHY SOCIETY (Member) NaN
#
# [5 rows x 51 columns]
# Batch 20

# %%
# print grades columns
for i in range(3):
    print(f'Batch {batch[i]}')
    print(C1_Data[i][0].columns)
    print()
# Out:
# Batch 18
# Index(['GENDER', 'PSLE', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'GP', 'KI',
#        'KI (H)', 'MA2', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'EL2 (H)',
#        'ELL2', 'EC2', 'EC2 (H)', 'EH2', 'EH2 (H)', 'EG2', 'EG2 (H)', 'AP2',
#        'MP2', 'CLL2', 'CSC2', 'TRC2', 'FR2', 'GM2', 'JP2', 'SP2', 'MA1', 'CH1',
#        'EL1', 'EC1', 'EH1', 'EG1', 'CL', 'GSC', 'HIL', 'PW', 'MTL', 'P/F',
#        'RANK', '%', 'MSG/GPA', 'PTS', 'NO OF CCA', 'CCA', 'PH1'],
#       dtype='object')
#
# Batch 19
# Index(['GENDER', 'PSLE', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'GP', 'KI',
#        'KI (H)', 'MA2', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'EL2 (H)',
#        'ELL2', 'EC2', 'EC2 (H)', 'EH2', 'EH2 (H)', 'EG2', 'EG2 (H)', 'AP2',
#        'MP2', 'CLL2', 'CSC2', 'TRC2', 'FR2', 'GM2', 'SP2', 'MA1', 'PH1', 'CH1',
#        'EL1', 'EC1', 'EH1', 'EG1', 'CL', 'TL', 'JP1', 'HIL', 'PW', 'MTL',
#        'P/F', 'RANK', '%', 'MSG/GPA', 'PTS', 'NO OF CCA', 'CCA'],
#       dtype='object')
#
# Batch 20
# Index(['GENDER', 'PSLE', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'KI', 'GP',
#        'KI (H)', 'MA2', 'FM2', 'CP2', 'PH2', 'CH2', 'BY2', 'EL2', 'EL2 (H)',
#        'ELL2', 'EC2', 'EC2 (H)', 'EH2', 'EH2 (H)', 'EG2', 'EG2 (H)', 'AP2',
#        'MP2', 'CLL2', 'CSC2', 'TRC2', 'FR2', 'GM2', 'JP2', 'SP2', 'MA1', 'PH1',
#        'CH1', 'EL1', 'EC1', 'EG1', 'CL', 'GSC', 'TL', 'PW', 'MTL', 'P/F',
#        'RANK', '%', 'MSG/GPA', 'PTS', 'NO OF CCA', 'CCA', 'EH1'],
#       dtype='object')

# %% [markdown]
# We note that the columns not related to subjects and overall results are identical to information already captured in the Prelim datasets, hence we will only focus on the subjects. We will zoom in on the corresponding features selected in the Prelim datasets.

# %% [markdown]
# ### Transform to align with Prelim datasets
# The final feature list in the Prelim datasets is 'GENDER', 'INTAKE', 'SEC SCHOOL', 'GP/KI', 'MA2', 'H1', 'H3', 'PTS'. We will create the 'GP/KI' and 'H1' columns in the C1 datasets ('H3' not taken in C1).

# %%
# create 'H1' column
subj_H1 = ['PH1', 'CH1', 'EL1', 'EC1', 'EH1', 'EG1']

for i in range(3):
    
    # merge 'GP', 'KI' and 'KI(H)' into new column 'GP/KI'
    C1_Data[i][0]['GP'].fillna(C1_Data[i][0]['KI'], inplace=True)
    C1_Data[i][0]['GP'].fillna(C1_Data[i][0]['KI (H)'], inplace=True)
    C1_Data[i][0].rename(columns={'GP': 'GP/KI'}, inplace=True)
    
    # merge H1 subjects into new column 'H1'
    C1_Data[i][0]['H1'] = np.nan
    for h1 in subj_H1:
        C1_Data[i][0]['H1'].fillna(C1_Data[i][0][h1], inplace=True)

# %%
# change 'EX' and 'MC' to 'missed'
for i in range(3):
    for subj in ['GP/KI', 'H1']:
        C1_Data[i][0][subj] = C1_Data[i][0][subj].map(lambda g: 'missed' if g in ['EX','MC']
                                                      else g)
        
    # replace grades of 'MA2' with marks
    C1_Data[i][0]['MA2'] = C1_Data[i][1]['MA2'].map(lambda m: 'missed' if m in ['EX','MC']
                                                    else m)

# %%
# merge to Prelim Numerical Features
features_C1 = ['GP/KI', 'MA2', 'H1', 'PTS']
features_Prelim = features_C1 + ['H3']
merged_18 = Prelim_Features[0][features_Prelim].join(C1_Data[0][0][features_C1],rsuffix='_C1')
merged_19 = Prelim_Features[1][features_Prelim].join(C1_Data[1][0][features_C1],rsuffix='_C1')
merged_20 = Prelim_Features[2][features_Prelim].join(C1_Data[2][0][features_C1],rsuffix='_C1')

# %% [markdown]
# ### Check for null values

# %%
# check for null values
print('Batch 18')
print(merged_18.isna().sum())
print()
print('Batch 19')
print(merged_19.isna().sum())
print()
print('Batch 20')
print(merged_20.isna().sum())
print()
# Out:
# Batch 18
# GP/KI         0
# MA2           0
# H1          931
# PTS           0
# H3          935
# GP/KI_C1      1
# MA2_C1        1
# H1_C1       998
# PTS_C1        1
# dtype: int64
#
# Batch 19
# GP/KI         0
# MA2           0
# H1          926
# PTS           0
# H3          824
# GP/KI_C1      1
# MA2_C1        1
# H1_C1       977
# PTS_C1        1
# dtype: int64
#
# Batch 20
# GP/KI         0
# MA2           0
# H1          946
# PTS           0
# H3          813
# GP/KI_C1      5
# MA2_C1        6
# H1_C1       973
# PTS_C1        5
# dtype: int64

# %% [markdown]
# The number of missing values in 'H1_C1' is higher than in 'H1' in the Prelim datasets, because some students downgraded their H2 to H1 only in JC2. We will eventually drop this column, but may use it to impute any 'H1' grade that was 'missed' (due to students missing the Prelim exam).
#
# There are also a handful of entries missing in the other C1 columns, which we investigate below.

# %%
# list to hold indices of NaN rows for imputation later
nan_ind_list = [[],[],[]]

# find rows with missing info
for i in range(3):
    df = C1_Data[i][0][C1_Data[i][0]['MA2'].isna()]
    nan_ind_list[i] = list(df.index)
    display(df)
    print(f'Batch {batch[i]}')
# Out:
#          GENDER  PSLE      REPEAT     INTAKE                  SEC SCHOOL  \
# NEWID
# 20180042      F   258  Repeat Yr2  IP (NYGH)  NANYANG GIRLS' HIGH SCHOOL
#
#          GP/KI   KI KI (H)  MA2  FM2  ... MTL  P/F RANK   % MSG/GPA PTS  \
# NEWID                                 ...
# 20180042   NaN  NaN    NaN  NaN  NaN  ...   C  NaN  NaN NaN     NaN NaN
#
#          NO OF CCA                        CCA PH1   H1
# NEWID
# 20180042         1  ULTIMATE FRISBEE (Member) NaN  NaN
#
# [1 rows x 52 columns]
# Batch 18
#          GENDER  PSLE      REPEAT     INTAKE            SEC SCHOOL GP/KI   KI  \
# NEWID
# 20190711      M   236  Repeat Yr2  DSA (CCA)  CATHOLIC HIGH SCHOOL   NaN  NaN
#
#          KI (H)  MA2  FM2  ... PW MTL  P/F RANK   % MSG/GPA PTS NO OF CCA  \
# NEWID                      ...
# 20190711    NaN  NaN  NaN  ...  A   B  NaN  NaN NaN     NaN NaN         1
#
#                          CCA   H1
# NEWID
# 20190711  SOFTBALL (Captain)  NaN
#
# [1 rows x 52 columns]
# Batch 19
#          GENDER  PSLE      REPEAT                  INTAKE  \
# NEWID
# 20200086      F     0  Repeat Yr2  JAE Ordinary Admission
# 20200346      M   254  Repeat Yr2                IP (HCI)
# 20200458      M     0         NaN                IP (HCI)
# 20200485      M     0  Repeat Yr2  JAE Ordinary Admission
# 20200599      M   260  Repeat Yr2                IP (HCI)
# 20201045      M   264  Repeat Yr2                IP (HCI)
#
#                                    SEC SCHOOL   KI GP/KI KI (H)  MA2  FM2  \
# NEWID
# 20200086       CHUNG CHENG HIGH SCHOOL (MAIN)  NaN   NaN    NaN  NaN  NaN
# 20200346  HWA CHONG INSTITUTION (HIGH SCHOOL)  NaN   NaN    NaN  NaN  NaN
# 20200458  HWA CHONG INSTITUTION (HIGH SCHOOL)  NaN     C    NaN  NaN  NaN
# 20200485         LOYANG VIEW SECONDARY SCHOOL  NaN   NaN    NaN  NaN  NaN
# 20200599  HWA CHONG INSTITUTION (HIGH SCHOOL)  NaN   NaN    NaN  NaN  NaN
# 20201045  HWA CHONG INSTITUTION (HIGH SCHOOL)  NaN   NaN    NaN  NaN  NaN
#
#           ... MTL     P/F   RANK     % MSG/GPA   PTS NO OF CCA  \
# NEWID     ...
# 20200086  ...   B     NaN    NaN   NaN     NaN   NaN         0
# 20200346  ...   S     NaN    NaN   NaN     NaN   NaN         0
# 20200458  ...   A  Passed  808.0  24.0     3.3  57.5         1
# 20200485  ...   A     NaN    NaN   NaN     NaN   NaN         0
# 20200599  ...   A     NaN    NaN   NaN     NaN   NaN         1
# 20201045  ...   A     NaN    NaN   NaN     NaN   NaN         0
#
#                                                   CCA EH1   H1
# NEWID
# 20200086                                          NaN NaN  NaN
# 20200346                                          NaN NaN  NaN
# 20200458  MIND SPORTS (CHESS, BRIDGE) (Quartermaster) NaN  NaN
# 20200485                                          NaN NaN  NaN
# 20200599                            ART CLUB (Member) NaN  NaN
# 20201045                                          NaN NaN  NaN
#
# [6 rows x 52 columns]
# Batch 20

# %% [markdown]
# Except for one student in Batch 20, the results are missing for these students as they repeated year 2. We will impute these missing values using Prelim data before modelling if we decide to use these features.
#
# We look for the subjects taken by this non-repeat student in C1 and C2 (i.e. Prelim).

# %%
# C1 subjects
C1_Data[2][0].loc[20200458][C1_Data[2][0].loc[20200458].notna()].index
# Out:
# Index(['GENDER', 'PSLE', 'INTAKE', 'SEC SCHOOL', 'GP/KI', 'EL2', 'EG2', 'CLL2',
#        'MA1', 'PW', 'MTL', 'P/F', 'RANK', '%', 'MSG/GPA', 'PTS', 'NO OF CCA',
#        'CCA'],
#       dtype='object')

# %%
# Prelim subjects
Prelim_Data[2][0].loc[20200458][Prelim_Data[2][0].loc[20200458].notna()].index
# Out:
# Index(['GENDER', 'PSLE', 'REPEAT', 'INTAKE', 'SEC SCHOOL', 'PW', 'GP/KI',
#        'MA2', 'EL2', 'EG2', 'CLL2', 'PW.1', 'MTL', 'P/F', 'RANK', '%',
#        'MSG/GPA', 'PTS', 'NO OF CCA', 'CCA'],
#       dtype='object')

# %% [markdown]
# This student was allowed to upgrade from H1 Math in C1 to H2 Math in C2. We change his 'MA2' mark from NaN to 'missed' and we removed him from the nan_ind_list.

# %%
# change 'MA2' mark from NaN to 'missed'
merged_20.loc[20200458, 'MA2_C1'] = 'missed'
nan_ind_list[2].remove(20200458)

# %%
# check Prelim results for students with missing C1 results
for i in range(3):
    display(merged_data[i].loc[nan_ind_list[i]])
# Out:
#          GP/KI MA2 H1   PTS   H3 GP/KI_C1 MA2_C1 H1_C1  PTS_C1
# NEWID
# 20180042     C  48  C  62.5  NaN      NaN    NaN   NaN     NaN
#          GP/KI   MA2 H1   PTS   H3 GP/KI_C1 MA2_C1 H1_C1  PTS_C1
# NEWID
# 20190711     D  54.5  B  77.5  NaN      NaN    NaN   NaN     NaN
#            GP/KI     MA2      H1    PTS   H3 GP/KI_C1 MA2_C1 H1_C1  PTS_C1
# NEWID
# 20200086       B      26     NaN  22.50  NaN      NaN    NaN   NaN     NaN
# 20200346  missed  missed  missed   7.50  NaN      NaN    NaN   NaN     NaN
# 20200485       E  missed  missed  28.75  NaN      NaN    NaN   NaN     NaN
# 20200599       A    86.2     NaN  88.75   DI      NaN    NaN   NaN     NaN
# 20201045       C    67.9     NaN  78.75  NaN      NaN    NaN   NaN     NaN

# %% [markdown]
# We copy the columns of the Prelim results over to the C1 results for these 7 students, including entries with 'missed' so these get imputed later.

# %%
# copy Prelim results to C1 results
for i in range(3):
    for j in nan_ind_list[i]:
        for feature in ['GP/KI', 'MA2', 'H1', 'PTS']:
            merged_data[i].loc[j, feature+'_C1'] = merged_data[i].loc[j, feature]

# %% [markdown]
# ### Check correlation coefficients

# %%
# create dataframes with selected features in Prelim and C1 datasets, and targets for Batches 18 and 19
test2_18 = pd.concat([merged_18, y_18], axis=1)
test2_19 = pd.concat([merged_19, y_19], axis=1)

# map Prelim grades to numbers
for subj in ['GP/KI', 'GP/KI_C1']:
    test2_18[subj] = test2_18[subj].map(grade_dict)
    test2_19[subj] = test2_19[subj].map(grade_dict)
    
test2_18['H1'] = test2_18['H1'].map(grade_dict_H1)
test2_19['H1'] = test2_19['H1'].map(grade_dict_H1)
test2_18['H1_C1'] = test2_18['H1_C1'].map(grade_dict_H1)
test2_19['H1_C1'] = test2_19['H1_C1'].map(grade_dict_H1)
test2_18['H3'] = test2_18['H3'].map(grade_dict_H3)
test2_19['H3'] = test2_19['H3'].map(grade_dict_H3)
test2_18['MA2'] = pd.to_numeric(test2_18['MA2'], errors='coerce')
test2_19['MA2'] = pd.to_numeric(test2_19['MA2'], errors='coerce')
test2_18['MA2_C1'] = pd.to_numeric(test2_18['MA2_C1'], errors='coerce')
test2_19['MA2_C1'] = pd.to_numeric(test2_19['MA2_C1'], errors='coerce')

# %%
# features ranked by magnitude of correlation to Target
corr2_18 = test2_18.corr().tail(1).T.sort_values('Target', key=abs, ascending=False)
corr2_19 = test2_19.corr().tail(1).T.sort_values('Target', key=abs, ascending=False)
corr2_18.rename(columns={'Target': 'Correlation with Target'}, inplace=True)
corr2_19.rename(columns={'Target': 'Correlation with Target'}, inplace=True)

display(corr2_18)
print('Batch 18')
display(corr2_19)
print('Batch 19')
# Out:
#         Correlation with Target
# Target                 1.000000
# PTS                   -0.682699
# MA2                   -0.673051
# PTS_C1                -0.608747
# MA2_C1                -0.559830
# Batch 18
#         Correlation with Target
# Target                 1.000000
# PTS                   -0.662472
# MA2                   -0.657795
# PTS_C1                -0.578423
# MA2_C1                -0.534474
# Batch 19

# %%
# plot heatmap of correlations for Batch 18
sns.heatmap(test2_18[corr2_18.index].corr(), cmap='coolwarm', annot=True, annot_kws={'size': 15});

# %%
# plot heatmap of correlations for Batch 19
sns.heatmap(test2_19[corr2_19.index].corr(), cmap='coolwarm', annot=True, annot_kws={'size': 15});

# %% [markdown]
# The correlations of the numeric features with the Target are not very low, and the inter-correlation between the features are not exceedingly high, so we will keep all the columns as predictors in our model.

# %% [markdown]
# ## Imputing values for students who missed exam

# %%
# create list for looping
merged_data = [merged_18, merged_19, merged_20]
missed_ind_list = [[],[],[]]

# find 'missed' in Prelim and C1 grades/marks
for i in range(3):
    df = merged_data[i][merged_data[i].isin(['missed']).any(axis=1)]
    missed_ind_list[i] = df.index
    display(df)
    print(f'Batch {batch[i]}')
# Out:
#            GP/KI     MA2      H1    PTS   H3 GP/KI_C1  MA2_C1 H1_C1  PTS_C1
# NEWID
# 20180166  missed      74     NaN  68.75  NaN        D    72.8   NaN   66.25
# 20180182       C  missed     NaN  17.50  NaN        D    45.4     E   41.25
# 20180196       D  missed       C  55.00  NaN        D    39.8     E   41.25
# 20180406       C    54.5     NaN  67.50  NaN        C  missed   NaN   47.50
# 20180409  missed  missed     NaN  10.00  NaN        B    52.1   NaN   63.75
# 20180439       D    36.5  missed  21.25  NaN        E    46.8     U   40.00
# 20180838       D    53.5     NaN  56.25  NaN        E  missed   NaN    5.00
# 20180874       B    61.5     NaN  78.75  NaN        D  missed   NaN   46.25
# 20180895       B      70     NaN  81.25  NaN        C  missed   NaN   35.00
# 20180922       C      47  missed  45.00  NaN        E    29.5   NaN   35.00
# 20180940  missed      60       B  61.25  NaN        D    33.8   NaN   33.75
# 20181098       D      61     NaN  75.00  NaN   missed    49.5   NaN   27.50
# 20181137  missed  missed       S  11.25  NaN        E    31.4     E   15.00
# Batch 18
#            GP/KI     MA2      H1    PTS   H3 GP/KI_C1  MA2_C1 H1_C1  PTS_C1
# NEWID
# 20190082  missed      48     NaN  60.00  NaN        D    44.4   NaN   56.25
# 20190118       D      31       B  47.50  NaN        D  missed   NaN   31.25
# 20190172       A      66     NaN  83.75   ME        B  missed   NaN   66.25
# 20190410       A    44.5     NaN  72.50  NaN        B  missed   NaN   56.25
# 20190420       C      60       D  58.75  NaN   missed    42.2     B   23.75
# 20190504  missed  missed     NaN  21.25  NaN        C    52.1   NaN   67.50
# 20190519       B      44     NaN  71.25  NaN        D  missed   NaN   51.25
# 20190678       D      55     NaN  58.75  NaN   missed    36.7   NaN   27.50
# 20190840       C    53.5     NaN  63.75  NaN        B  missed   NaN   23.75
# 20190898       S      54       D  66.25  NaN        D  missed   NaN   38.75
# 20190906  missed    43.5     NaN  23.75  NaN        E    46.2   NaN   42.50
# 20190977       B      28  missed  23.75  NaN        S    30.6     E   35.00
# 20190987       E    40.5     NaN  42.50  NaN   missed    43.7   NaN   25.00
# Batch 19
#            GP/KI     MA2      H1    PTS      H3 GP/KI_C1  MA2_C1   H1_C1  \
# NEWID
# 20200140       A    33.6       A  53.75     NaN        E  missed  missed
# 20200200       B      17       C  43.75     NaN   missed  missed     NaN
# 20200293       B    51.1     NaN  80.00     NaN        C  missed     NaN
# 20200346  missed  missed  missed   7.50     NaN      NaN     NaN     NaN
# 20200402  missed  missed  missed  10.00     NaN        D  missed     NaN
# 20200437       A    59.6     NaN  80.00     NaN        A  missed     NaN
# 20200458       B    52.3     NaN  52.50     NaN        C  missed     NaN
# 20200485       E  missed  missed  28.75     NaN      NaN     NaN     NaN
# 20200493       A    87.5     NaN  90.00  missed        B      71     NaN
# 20200583  missed  missed     NaN   0.00     NaN   missed  missed     NaN
# 20200611       D    32.4     NaN  26.25     NaN        E  missed     NaN
# 20200696       D  missed       U  32.50     NaN        E      36       S
# 20200719       C    29.4       B  35.00     NaN   missed      38       D
# 20200981       C      71  missed  62.50     NaN        C    59.3       A
#
#           PTS_C1
# NEWID
# 20200140    5.00
# 20200200   10.00
# 20200293   40.00
# 20200346     NaN
# 20200402   31.25
# 20200437   55.00
# 20200458   57.50
# 20200485     NaN
# 20200493   78.75
# 20200583   17.50
# 20200611   30.00
# 20200696   17.50
# 20200719    6.25
# 20200981   65.00
# Batch 20

# %%
features_C1 = ['GP/KI_C1', 'MA2_C1', 'H1_C1', 'PTS_C1']
imputed_18 = pd.DataFrame()
imputed_19 = pd.DataFrame()
imputed_20 = pd.DataFrame()
imputed_df = [imputed_18, imputed_19, imputed_20]

for i in range(3):
    to_knn = Prelim_Features[i].copy()
    for feature in features_C1:
        to_knn[feature] = merged_data[i][feature]
    to_knn['GP/KI'] = to_knn['GP/KI'].map(grade_dict)
    to_knn['GP/KI_C1'] = to_knn['GP/KI_C1'].map(grade_dict)
    to_knn['H1'] = to_knn['H1'].map(grade_dict_H1) 
    to_knn['H1_C1'] = to_knn['H1_C1'].map(grade_dict_H1)
    to_knn['H3'] = to_knn['H3'].map(grade_dict_H3)
    to_knn['MA2'] = to_knn['MA2'].map(lambda m: np.nan if m == 'missed' else float(m))
    to_knn['MA2_C1'] = to_knn['MA2_C1'].map(lambda m: np.nan if m == 'missed' else float(m))
    knn_imp = KNNImputer()
    knn_df = knn_imp.fit_transform(to_knn)
    imputed = pd.DataFrame(knn_df, columns=knn_imp.feature_names_in_)
    imputed['NEWID']=to_knn.index
    imputed_df[i] = imputed.set_index('NEWID', drop=True).loc[missed_ind_list[i]][features_Prelim+features_C1]
    display(imputed_df[i])
    print(f'Batch {batch[i]}')
# Out:
#           GP/KI   MA2   H1    PTS   H3  GP/KI_C1  MA2_C1  H1_C1  PTS_C1
# NEWID
# 20180166    3.6  74.0  0.0  68.75  5.0       4.0   72.80    0.0   66.25
# 20180182    3.0  35.4  0.0  17.50  5.0       4.0   45.40    5.0   41.25
# 20180196    4.0  45.8  3.0  55.00  5.0       4.0   39.80    5.0   41.25
# 20180406    3.0  54.5  0.0  67.50  5.0       3.0   43.16    0.0   47.50
# 20180409    3.4  41.9  0.0  10.00  5.0       2.0   52.10    0.0   63.75
# 20180439    4.0  36.5  1.4  21.25  5.0       5.0   46.80    7.0   40.00
# 20180838    4.0  53.5  0.0  56.25  5.0       5.0   35.70    0.0    5.00
# 20180874    2.0  61.5  0.0  78.75  5.0       4.0   44.64    0.0   46.25
# 20180895    2.0  70.0  0.0  81.25  5.0       3.0   42.04    0.0   35.00
# 20180922    3.0  47.0  1.2  45.00  5.0       5.0   29.50    0.0   35.00
# 20180940    2.6  60.0  2.0  61.25  5.0       4.0   33.80    0.0   33.75
# 20181098    4.0  61.0  0.0  75.00  5.0       3.6   49.50    0.0   27.50
# 20181137    4.4  32.0  6.0  11.25  5.0       5.0   31.40    5.0   15.00
# Batch 18
#           GP/KI   MA2   H1    PTS   H3  GP/KI_C1  MA2_C1  H1_C1  PTS_C1
# NEWID
# 20190082    2.6  48.0  0.0  60.00  5.0       4.0   44.40    0.0   56.25
# 20190118    4.0  31.0  2.0  47.50  5.0       4.0   33.60    0.0   31.25
# 20190172    1.0  66.0  0.0  83.75  2.0       2.0   58.34    0.0   66.25
# 20190410    1.0  44.5  0.0  72.50  5.0       2.0   42.24    0.0   56.25
# 20190420    3.0  60.0  4.0  58.75  5.0       4.6   42.20    2.0   23.75
# 20190504    3.4  29.1  0.0  21.25  5.0       3.0   52.10    0.0   67.50
# 20190519    2.0  44.0  0.0  71.25  5.0       4.0   42.46    0.0   51.25
# 20190678    4.0  55.0  0.0  58.75  5.0       4.0   36.70    0.0   27.50
# 20190840    3.0  53.5  0.0  63.75  5.0       2.0   38.78    0.0   23.75
# 20190898    6.0  54.0  4.0  66.25  5.0       4.0   42.22    0.0   38.75
# 20190906    3.2  43.5  0.0  23.75  5.0       5.0   46.20    0.0   42.50
# 20190977    2.0  28.0  3.6  23.75  5.0       6.0   30.60    5.0   35.00
# 20190987    5.0  40.5  0.0  42.50  5.0       4.2   43.70    0.0   25.00
# Batch 19
#           GP/KI    MA2   H1    PTS   H3  GP/KI_C1  MA2_C1  H1_C1  PTS_C1
# NEWID
# 20200140    1.0  33.60  1.0  53.75  5.0       5.0   37.58    2.4    5.00
# 20200200    2.0  17.00  3.0  43.75  5.0       4.0   32.72    0.0   10.00
# 20200293    2.0  51.10  0.0  80.00  5.0       3.0   45.66    0.0   40.00
# 20200346    3.6  24.48  2.8   7.50  5.0       4.2   35.58    0.0   20.75
# 20200402    4.6  27.84  5.0  10.00  5.0       4.0   41.88    0.0   31.25
# 20200437    1.0  59.60  0.0  80.00  5.0       1.0   55.06    0.0   55.00
# 20200458    2.0  52.30  0.0  52.50  5.0       3.0   50.06    0.0   57.50
# 20200485    5.0  31.18  2.0  28.75  5.0       3.8   41.90    0.0   40.00
# 20200493    1.0  87.50  0.0  90.00  2.0       2.0   71.00    0.0   78.75
# 20200583    4.0  21.14  0.0   0.00  5.0       4.8   34.68    0.0   17.50
# 20200611    4.0  32.40  0.0  26.25  5.0       5.0   37.32    0.0   30.00
# 20200696    4.0  37.84  7.0  32.50  5.0       5.0   36.00    6.0   17.50
# 20200719    3.0  29.40  2.0  35.00  5.0       4.6   38.00    4.0    6.25
# 20200981    3.0  71.00  0.0  62.50  5.0       3.0   59.30    1.0   65.00
# Batch 20

# %% [markdown]
# ## Prepare final csv file ready for modelling
# For modelling, there must be no missing values and all values must be numeric.

# %%
# map Prelim grades to numbers, leave 'missed' as is for imputation later
grade_dict = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'S': 6, 'U': 7, 
              'missed': 'missed', np.nan: np.nan
             }

grade_dict_H1 = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'S': 6, 'U': 7, 
                 'missed': 'missed', np.nan: 0
                }

grade_dict_H3 = {'DI': 1, 'ME': 2, 'PA': 3, 'UC': 4, 'missed': 'missed', np.nan: 5}

# %%
for i in range(3):   
    for feature in features_C1:
        Prelim_Features[i][feature] = merged_data[i][feature]
        
    Prelim_Features[i]['GP/KI'] = Prelim_Features[i]['GP/KI'].map(grade_dict)
    Prelim_Features[i]['GP/KI_C1'] = Prelim_Features[i]['GP/KI_C1'].map(grade_dict)
    Prelim_Features[i]['H1'] = Prelim_Features[i]['H1'].map(grade_dict_H1) 
    Prelim_Features[i]['H1_C1'] = Prelim_Features[i]['H1_C1'].map(grade_dict_H1)
    Prelim_Features[i]['H3'] = Prelim_Features[i]['H3'].map(grade_dict_H3)

    display(Prelim_Features[i].head())
# Out:
#           GENDER_F  GENDER_M  INTAKE_DSA  INTAKE_DSA (CCA)  INTAKE_IP (HCI)  \
# NEWID
# 20180001         0         1           0                 0                1
# 20180002         1         0           0                 0                0
# 20180003         1         0           0                 0                0
# 20180005         0         1           0                 0                0
# 20180006         0         1           0                 0                0
#
#           INTAKE_IP (NYGH)  INTAKE_JAE Ordinary Admission  \
# NEWID
# 20180001                 0                              0
# 20180002                 0                              1
# 20180003                 1                              0
# 20180005                 0                              1
# 20180006                 0                              1
#
#           SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL  \
# NEWID
# 20180001                                           0
# 20180002                                           0
# 20180003                                           0
# 20180005                                           0
# 20180006                                           0
#
#           SEC SCHOOL_CATHOLIC HIGH SCHOOL  \
# NEWID
# 20180001                                0
# 20180002                                0
# 20180003                                0
# 20180005                                0
# 20180006                                1
#
#           SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL  ...  CLL3_EC3-MOE   MA2  \
# NEWID                                                 ...
# 20180001                                           0  ...             0  69.5
# 20180002                                           0  ...             0    84
# 20180003                                           0  ...             0  61.5
# 20180005                                           0  ...             0  56.5
# 20180006                                           0  ...             0  66.5
#
#            PTS  GP/KI  H1  H3  GP/KI_C1  MA2_C1  H1_C1  PTS_C1
# NEWID
# 20180001  85.0      2   0   5         3    62.3      0   70.00
# 20180002  80.0      3   0   5         4      71      0   72.50
# 20180003  57.5      3   0   5         3    40.5      0   45.00
# 20180005  65.0      4   0   5         4    68.8      0   58.75
# 20180006  87.5      1   0   2         1    61.9      0   75.00
#
# [5 rows x 52 columns]
#           GENDER_F  GENDER_M  INTAKE_DSA  INTAKE_DSA (CCA)  INTAKE_IP (HCI)  \
# NEWID
# 20190001         0         1           0                 1                0
# 20190002         0         1           0                 0                1
# 20190003         0         1           0                 0                1
# 20190004         0         1           0                 0                1
# 20190005         0         1           0                 0                0
#
#           INTAKE_IP (NYGH)  INTAKE_JAE Ordinary Admission  \
# NEWID
# 20190001                 0                              0
# 20190002                 0                              0
# 20190003                 0                              0
# 20190004                 0                              0
# 20190005                 0                              1
#
#           SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL  \
# NEWID
# 20190001                                           0
# 20190002                                           0
# 20190003                                           0
# 20190004                                           0
# 20190005                                           0
#
#           SEC SCHOOL_CATHOLIC HIGH SCHOOL  \
# NEWID
# 20190001                                1
# 20190002                                0
# 20190003                                0
# 20190004                                0
# 20190005                                0
#
#           SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL  ...  CLL3_EC3-MOE   MA2  \
# NEWID                                                 ...
# 20190001                                           0  ...             0    41
# 20190002                                           0  ...             0  71.5
# 20190003                                           0  ...             0    63
# 20190004                                           0  ...             0    49
# 20190005                                           0  ...             0  37.5
#
#             PTS  GP/KI  H1  H3  GP/KI_C1  MA2_C1  H1_C1  PTS_C1
# NEWID
# 20190001  47.50      6   5   5         5    46.7      7   22.50
# 20190002  88.75      1   0   1         1    70.7      0   80.00
# 20190003  81.25      2   0   5         3    49.5      0   61.25
# 20190004  58.75      3   0   5         3    52.8      0   37.50
# 20190005  50.00      3   0   5         4    48.8      0   51.25
#
# [5 rows x 52 columns]
#           GENDER_F  GENDER_M  INTAKE_DSA  INTAKE_DSA (CCA)  INTAKE_IP (HCI)  \
# NEWID
# 20200001         1         0           0                 0                0
# 20200002         1         0           0                 0                0
# 20200003         1         0           0                 0                0
# 20200004         0         1           0                 0                1
# 20200005         1         0           0                 0                0
#
#           INTAKE_IP (NYGH)  INTAKE_JAE Ordinary Admission  \
# NEWID
# 20200001                 0                              1
# 20200002                 1                              0
# 20200003                 0                              1
# 20200004                 0                              0
# 20200005                 1                              0
#
#           SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL  \
# NEWID
# 20200001                                           0
# 20200002                                           0
# 20200003                                           0
# 20200004                                           0
# 20200005                                           0
#
#           SEC SCHOOL_CATHOLIC HIGH SCHOOL  \
# NEWID
# 20200001                                0
# 20200002                                0
# 20200003                                0
# 20200004                                0
# 20200005                                0
#
#           SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL  ...  CLL3_EC3-MOE   MA2  \
# NEWID                                                 ...
# 20200001                                           0  ...             0    68
# 20200002                                           0  ...             0  62.8
# 20200003                                           0  ...             0  64.2
# 20200004                                           0  ...             0    50
# 20200005                                           0  ...             0  40.2
#
#             PTS  GP/KI  H1  H3  GP/KI_C1  MA2_C1  H1_C1  PTS_C1
# NEWID
# 20200001  85.00      2   0   5         2    67.5      0   72.50
# 20200002  78.75      2   0   5         3    61.1      0   66.25
# 20200003  66.25      2   0   5         3    63.1      0   55.00
# 20200004  52.50      3   0   5         4    59.2      0   58.75
# 20200005  43.75      4   0   5         3    42.4      0   50.00
#
# [5 rows x 52 columns]

# %%
for i in range(3):
    print(Prelim_Features[i].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1097 entries, 20180001 to 20181154
# Data columns (total 52 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   GENDER_F                                        1097 non-null   uint8
#  1   GENDER_M                                        1097 non-null   uint8
#  2   INTAKE_DSA                                      1097 non-null   uint8
#  3   INTAKE_DSA (CCA)                                1097 non-null   uint8
#  4   INTAKE_IP (HCI)                                 1097 non-null   uint8
#  5   INTAKE_IP (NYGH)                                1097 non-null   uint8
#  6   INTAKE_JAE Ordinary Admission                   1097 non-null   uint8
#  7   SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL      1097 non-null   uint8
#  8   SEC SCHOOL_CATHOLIC HIGH SCHOOL                 1097 non-null   uint8
#  9   SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL      1097 non-null   uint8
#  10  SEC SCHOOL_CHUNG CHENG HIGH SCHOOL (MAIN)       1097 non-null   uint8
#  11  SEC SCHOOL_CRESCENT GIRLS' SCHOOL               1097 non-null   uint8
#  12  SEC SCHOOL_HWA CHONG INSTITUTION (HIGH SCHOOL)  1097 non-null   uint8
#  13  SEC SCHOOL_METHODIST GIRLS' SCHOOL (SECONDARY)  1097 non-null   uint8
#  14  SEC SCHOOL_NAN HUA HIGH SCHOOL                  1097 non-null   uint8
#  15  SEC SCHOOL_NANYANG GIRLS' HIGH SCHOOL           1097 non-null   uint8
#  16  SEC SCHOOL__Minority_Sch                        1097 non-null   uint8
#  17  KI                                              1097 non-null   int64
#  18  FM2                                             1097 non-null   int64
#  19  CP2                                             1097 non-null   int64
#  20  PH2                                             1097 non-null   int64
#  21  CH2                                             1097 non-null   int64
#  22  BY2                                             1097 non-null   int64
#  23  EL2                                             1097 non-null   int64
#  24  ELL2                                            1097 non-null   int64
#  25  EC2                                             1097 non-null   int64
#  26  EH2                                             1097 non-null   int64
#  27  EG2                                             1097 non-null   int64
#  28  AP2                                             1097 non-null   int64
#  29  MP2                                             1097 non-null   int64
#  30  CLL2                                            1097 non-null   int64
#  31  CSC2                                            1097 non-null   int64
#  32  TRC2                                            1097 non-null   int64
#  33  EC1                                             1097 non-null   int64
#  34  MA3-MOE                                         1097 non-null   int64
#  35  PH3-MOE                                         1097 non-null   int64
#  36  CH3-MOE                                         1097 non-null   int64
#  37  BY3-MOE                                         1097 non-null   int64
#  38  AP3-MOE                                         1097 non-null   int64
#  39  Foreign_Lang                                    1097 non-null   int64
#  40  H1_Arts                                         1097 non-null   int64
#  41  H1_Sci                                          1097 non-null   int64
#  42  CLL3_EC3-MOE                                    1097 non-null   int64
#  43  MA2                                             1097 non-null   object
#  44  PTS                                             1097 non-null   float64
#  45  GP/KI                                           1097 non-null   object
#  46  H1                                              1097 non-null   object
#  47  H3                                              1097 non-null   object
#  48  GP/KI_C1                                        1096 non-null   object
#  49  MA2_C1                                          1096 non-null   object
#  50  H1_C1                                           1097 non-null   object
#  51  PTS_C1                                          1096 non-null   float64
# dtypes: float64(2), int64(26), object(7), uint8(17)
# memory usage: 359.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1064 entries, 20190001 to 20191099
# Data columns (total 52 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   GENDER_F                                        1064 non-null   uint8
#  1   GENDER_M                                        1064 non-null   uint8
#  2   INTAKE_DSA                                      1064 non-null   uint8
#  3   INTAKE_DSA (CCA)                                1064 non-null   uint8
#  4   INTAKE_IP (HCI)                                 1064 non-null   uint8
#  5   INTAKE_IP (NYGH)                                1064 non-null   uint8
#  6   INTAKE_JAE Ordinary Admission                   1064 non-null   uint8
#  7   SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL      1064 non-null   uint8
#  8   SEC SCHOOL_CATHOLIC HIGH SCHOOL                 1064 non-null   uint8
#  9   SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL      1064 non-null   uint8
#  10  SEC SCHOOL_CHUNG CHENG HIGH SCHOOL (MAIN)       1064 non-null   uint8
#  11  SEC SCHOOL_CRESCENT GIRLS' SCHOOL               1064 non-null   uint8
#  12  SEC SCHOOL_HWA CHONG INSTITUTION (HIGH SCHOOL)  1064 non-null   uint8
#  13  SEC SCHOOL_METHODIST GIRLS' SCHOOL (SECONDARY)  1064 non-null   uint8
#  14  SEC SCHOOL_NAN HUA HIGH SCHOOL                  1064 non-null   uint8
#  15  SEC SCHOOL_NANYANG GIRLS' HIGH SCHOOL           1064 non-null   uint8
#  16  SEC SCHOOL__Minority_Sch                        1064 non-null   uint8
#  17  KI                                              1064 non-null   int64
#  18  FM2                                             1064 non-null   int64
#  19  CP2                                             1064 non-null   int64
#  20  PH2                                             1064 non-null   int64
#  21  CH2                                             1064 non-null   int64
#  22  BY2                                             1064 non-null   int64
#  23  EL2                                             1064 non-null   int64
#  24  ELL2                                            1064 non-null   int64
#  25  EC2                                             1064 non-null   int64
#  26  EH2                                             1064 non-null   int64
#  27  EG2                                             1064 non-null   int64
#  28  AP2                                             1064 non-null   int64
#  29  MP2                                             1064 non-null   int64
#  30  CLL2                                            1064 non-null   int64
#  31  CSC2                                            1064 non-null   int64
#  32  TRC2                                            1064 non-null   int64
#  33  EC1                                             1064 non-null   int64
#  34  MA3-MOE                                         1064 non-null   int64
#  35  PH3-MOE                                         1064 non-null   int64
#  36  CH3-MOE                                         1064 non-null   int64
#  37  BY3-MOE                                         1064 non-null   int64
#  38  AP3-MOE                                         1064 non-null   int64
#  39  Foreign_Lang                                    1064 non-null   int64
#  40  H1_Arts                                         1064 non-null   int64
#  41  H1_Sci                                          1064 non-null   int64
#  42  CLL3_EC3-MOE                                    1064 non-null   int64
#  43  MA2                                             1064 non-null   object
#  44  PTS                                             1064 non-null   float64
#  45  GP/KI                                           1064 non-null   object
#  46  H1                                              1064 non-null   object
#  47  H3                                              1064 non-null   object
#  48  GP/KI_C1                                        1063 non-null   object
#  49  MA2_C1                                          1063 non-null   object
#  50  H1_C1                                           1064 non-null   object
#  51  PTS_C1                                          1063 non-null   float64
# dtypes: float64(2), int64(26), object(7), uint8(17)
# memory usage: 349.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025 entries, 20200001 to 20201057
# Data columns (total 52 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   GENDER_F                                        1025 non-null   uint8
#  1   GENDER_M                                        1025 non-null   uint8
#  2   INTAKE_DSA                                      1025 non-null   uint8
#  3   INTAKE_DSA (CCA)                                1025 non-null   uint8
#  4   INTAKE_IP (HCI)                                 1025 non-null   uint8
#  5   INTAKE_IP (NYGH)                                1025 non-null   uint8
#  6   INTAKE_JAE Ordinary Admission                   1025 non-null   uint8
#  7   SEC SCHOOL_BUKIT PANJANG GOVT. HIGH SCHOOL      1025 non-null   uint8
#  8   SEC SCHOOL_CATHOLIC HIGH SCHOOL                 1025 non-null   uint8
#  9   SEC SCHOOL_CHIJ ST. NICHOLAS GIRLS' SCHOOL      1025 non-null   uint8
#  10  SEC SCHOOL_CHUNG CHENG HIGH SCHOOL (MAIN)       1025 non-null   uint8
#  11  SEC SCHOOL_CRESCENT GIRLS' SCHOOL               1025 non-null   uint8
#  12  SEC SCHOOL_HWA CHONG INSTITUTION (HIGH SCHOOL)  1025 non-null   uint8
#  13  SEC SCHOOL_METHODIST GIRLS' SCHOOL (SECONDARY)  1025 non-null   uint8
#  14  SEC SCHOOL_NAN HUA HIGH SCHOOL                  1025 non-null   uint8
#  15  SEC SCHOOL_NANYANG GIRLS' HIGH SCHOOL           1025 non-null   uint8
#  16  SEC SCHOOL__Minority_Sch                        1025 non-null   uint8
#  17  KI                                              1025 non-null   int64
#  18  FM2                                             1025 non-null   int64
#  19  CP2                                             1025 non-null   int64
#  20  PH2                                             1025 non-null   int64
#  21  CH2                                             1025 non-null   int64
#  22  BY2                                             1025 non-null   int64
#  23  EL2                                             1025 non-null   int64
#  24  ELL2                                            1025 non-null   int64
#  25  EC2                                             1025 non-null   int64
#  26  EH2                                             1025 non-null   int64
#  27  EG2                                             1025 non-null   int64
#  28  AP2                                             1025 non-null   int64
#  29  MP2                                             1025 non-null   int64
#  30  CLL2                                            1025 non-null   int64
#  31  CSC2                                            1025 non-null   int64
#  32  TRC2                                            1025 non-null   int64
#  33  EC1                                             1025 non-null   int64
#  34  MA3-MOE                                         1025 non-null   int64
#  35  PH3-MOE                                         1025 non-null   int64
#  36  CH3-MOE                                         1025 non-null   int64
#  37  BY3-MOE                                         1025 non-null   int64
#  38  AP3-MOE                                         1025 non-null   int64
#  39  Foreign_Lang                                    1025 non-null   int64
#  40  H1_Arts                                         1025 non-null   int64
#  41  H1_Sci                                          1025 non-null   int64
#  42  CLL3_EC3-MOE                                    1025 non-null   int64
#  43  MA2                                             1025 non-null   object
#  44  PTS                                             1025 non-null   float64
#  45  GP/KI                                           1025 non-null   object
#  46  H1                                              1025 non-null   object
#  47  H3                                              1025 non-null   object
#  48  GP/KI_C1                                        1020 non-null   object
#  49  MA2_C1                                          1020 non-null   object
#  50  H1_C1                                           1025 non-null   object
#  51  PTS_C1                                          1020 non-null   float64
# dtypes: float64(2), int64(26), object(7), uint8(17)
# memory usage: 337.6+ KB
# None

# %% [markdown]
# # (4) Sec 4 Results

# %%
Sec4_18 = pd.read_csv('../data_raw/18 Batch Sec 4 Results.csv')
Sec4_18

# %%
Sec4_18.columns

# %% [markdown]
# # (5) CCA CIP

# %%
CCA_CIP_18 = pd.read_csv('../data_raw/18 Batch CCA CIP.csv', index_col=['NewID'])
CCA_CIP_18.head()
