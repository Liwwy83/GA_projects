# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The ACT was introduced as an alternative standardized test to the SAT in 1959. The ACT has seen a gradual increase in the number of test takers since its inception, and in 2012 the ACT surpassed the SAT for the first time in total test takers.
#
# In the three years from 2017 to 2019, ACT participation rates saw a general declining trend (national 60% in 2017 to 52% in 2019) while SAT participation rates saw an increase (more than 1.8 million in 2017 to more than 2.2 million in 2019).
#
# What are the contributing factors for this trend? How can we further increase the popularity of SAT?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# We will use the following 6 datasets for our analysis.
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# Source: [SAT](https://en.wikipedia.org/wiki/SAT)
#
# The SAT underwent a major redesign in 2016 to align more with the Common Core standards. There is more emphasis on the use of evidence to support answers, and a shift away from obscure vocabulary. The scope of mathematics was narrowed and the optional essay's score was separated from the final score so that the total score had a maximum of 1600 and no longer 2400. Penalty for wrong answers were also removed.
#
# Starting in the 2015-2016 school year, the College Board also began working with Khan Academy to provide free SAT prep.
#
# With such major changes, were there any impact on the SAT participation rates?

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean(num_list):
    """Takes in a list of numbers and returns its arithmetic mean."""
    sum = 0
    for num in num_list:
        sum += num
    return sum / len(num_list)

num_list = [1, 4, -4, 0, 30, 11]
mean(num_list)
# Out:
# 7.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(num_list):
    """Takes in a list of numbers and returns its standard deviation."""
    mu = mean(num_list)
    var = mean([(num - mu) ** 2 for num in num_list])
    return var ** 0.5
        
print(std_dev(num_list))

def unbiased_std_dev(num_list):
    """Takes in a list of numbers and returns its UNBIASED ESTIMATE for population standard deviation."""
    """This is done by dividing by (n - 1) instead of n."""
    n = len(num_list)
    mu = mean(num_list)
    var = mean([(num - mu) ** 2 for num in num_list]) * n / (n - 1)
    return var ** 0.5
        
print(unbiased_std_dev(num_list))
# Out:
# 11.254628677422755
# 12.328828005937952

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def perc_to_dec(strng):
    """Takes in a string comprising a number followed by a percent symbol and returns the value as a decimal between 0 and 1."""
    return float(strng.replace('%', '')) / 100

perc_to_dec('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %%
# Import 6 datasets into dataframes
act_2017 = pd.read_csv('../data/act_2017.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')
sat_2019 = pd.read_csv('../data/sat_2019.csv')

# %%
# Display first 5 rows of each dataframe
print('ACT 2017')
display(act_2017.head())
print('\n\nACT 2018')
display(act_2018.head())
print('\n\nACT 2019')
display(act_2019.head())
print('\n\nSAT 2017')
display(sat_2017.head())
print('\n\nSAT 2018')
display(sat_2018.head())
print('\n\nSAT 2019')
display(sat_2019.head())
# Out:
# ACT 2017
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4
# ACT 2018
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
# ACT 2019
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6
# SAT 2017
# ...

# %%
# Check datatypes and look for missing values
# Since number of entries match number of non-null in each column, there are no missing values

# ACT 2017 Composite column has type 'object' instead of 'float'
# -- look at raw data to see extra 'x' at last entry '20.2x' that caused entire column to be type 'string'

# SAT 2019 has 53 entries compared to 51 entries in SAT 2018 and SAT 2017 
# -- look at raw data to see that 2 territories of Puerto Rico and Virgin Islands are not found in other years
print('ACT 2017')
display(act_2017.info())
print('\n\nACT 2018')
display(act_2018.info())
print('\n\nACT 2019')
display(act_2019.info())
print('\n\nSAT 2017')
display(sat_2017.info())
print('\n\nSAT 2018')
display(sat_2018.info())
print('\n\nSAT 2019')
display(sat_2019.info())
# Out:
# ACT 2017
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB
# None
# ACT 2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB
# None
# ...

# %%
# Rename column names to lowercase
act_2017.columns = act_2017.columns.map(lambda c: c.lower())
act_2018.columns = act_2018.columns.map(lambda c: c.lower())
act_2019.columns = act_2019.columns.map(lambda c: c.lower())

# %%
# Change % participation to decimal value between 0 and 1
act_2017.participation = act_2017.participation.apply(perc_to_dec)
act_2018.participation = act_2018.participation.apply(perc_to_dec)
act_2019.participation = act_2019.participation.apply(perc_to_dec)

# %%
# Fix errors in ACT dataframes
act_2018.drop_duplicates(inplace = True)                         # Remove duplicate of State of Maine
act_2018.state[8] = 'District of Columbia'                       # Change 'c' to 'C' to align with other dataframes

act_2017.composite[51] = act_2017.composite[51].replace('x', '') # Remove extra 'x' at end of file
act_2017.composite = act_2017.composite.map(lambda s: float(s))  # Change data type from 'str' to 'float'

# Check ACT 2017 dataframe has correct data types
print('ACT 2017')
display(act_2017.info())

# Note that ACT 2019 and ACT 2017 have info for National that are not in the other dataframes
# We choose NOT to remove National info for now
# Out:
# ACT 2017
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   participation  52 non-null     float64
#  2   english        52 non-null     float64
#  3   math           52 non-null     float64
#  4   reading        52 non-null     float64
#  5   science        52 non-null     float64
#  6   composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB
# /var/folders/f5/csz5_csd4c11cy5h6lqwj2nw0000gp/T/ipykernel_73397/865823479.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Check that values in ACT dataframes are all valid
# Participation is between 0 and 1
# Scores are between 1 and 36
# Code flags out any rows that do not satisfy above criteria - none found

print('ACT participation 2017, 2018, 2019')
display(act_2017[(act_2017.participation < 0) | (act_2017.participation > 1)])
display(act_2018[(act_2018.participation < 0) | (act_2018.participation > 1)])
display(act_2019[(act_2019.participation < 0) | (act_2019.participation > 1)])
print('\n\ncomposite 2017, 2018, 2019')
display(act_2017[(act_2017.composite < 1) | (act_2017.composite > 36)])
display(act_2018[(act_2018.composite < 1) | (act_2018.composite > 36)])
display(act_2019[(act_2019.composite < 1) | (act_2019.composite > 36)])
print('\n\nenglish, math, reading, science 2017')
display(act_2017[(act_2017.english < 1) | (act_2017.english > 36)])
display(act_2017[(act_2017.math < 1) | (act_2017.math > 36)])
display(act_2017[(act_2017.reading < 1) | (act_2017.reading > 36)])
display(act_2017[(act_2017.science < 1) | (act_2017.science > 36)])
# Out:
# ACT participation 2017, 2018, 2019
# Empty DataFrame
# Columns: [state, participation, english, math, reading, science, composite]
# Index: []
# Empty DataFrame
# Columns: [state, participation, composite]
# Index: []
# Empty DataFrame
# Columns: [state, participation, composite]
# Index: []
# composite 2017, 2018, 2019
# Empty DataFrame
# Columns: [state, participation, english, math, reading, science, composite]
# Index: []
# Empty DataFrame
# Columns: [state, participation, composite]
# Index: []
# Empty DataFrame
# Columns: [state, participation, composite]
# Index: []
# english, math, reading, science 2017
# Empty DataFrame
# Columns: [state, participation, english, math, reading, science, composite]
# Index: []
# Empty DataFrame
# Columns: [state, participation, english, math, reading, science, composite]
# Index: []
# Empty DataFrame
# Columns: [state, participation, english, math, reading, science, composite]
# Index: []
# Empty DataFrame
# ...

# %%
# Check that composite score is within +-0.2 of average of 4 subsection scores in ACT 2017 dataframe
display(act_2017[abs((act_2017.english + act_2017.math + act_2017.reading + act_2017.science) / 4 - act_2017.composite) > 0.2])
# Out:
#        state  participation  english  math  reading  science  composite
# 21  Maryland           0.28     23.3  23.1     24.2      2.3       23.6

# %%
# Looks like Maryland's science score was a typo. 
# Replace this score with composite * 4 - (english + math + reading)
act_2017.science[21] = 23.6 * 4 - (23.3 + 23.1 + 24.2)
# Out:
# /var/folders/f5/csz5_csd4c11cy5h6lqwj2nw0000gp/T/ipykernel_73397/1544317425.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   act_2017.science[21] = 23.6 * 4 - (23.3 + 23.1 + 24.2)

# %%
# Rename SAT column names to sync all 3 years' dataframes
sat_2017.rename(columns = {'Evidence-Based Reading and Writing':'ebrw'}, inplace = True)
sat_2018.rename(columns = {'Evidence-Based Reading and Writing':'ebrw'}, inplace = True)
sat_2019.rename(columns = {'Participation Rate':'participation'}, inplace = True)

# Rename column names to lowercase
sat_2017.columns = sat_2017.columns.map(lambda c: c.lower())
sat_2018.columns = sat_2018.columns.map(lambda c: c.lower())
sat_2019.columns = sat_2019.columns.map(lambda c: c.lower())

# %%
# Remove 2 territories under 'state' that are not found in other dataframes and do not have Participation Rate
sat_2019.drop(labels = [39, 47], inplace = True)  # Remove Puerto Rico and Virgin Islands
sat_2019.reset_index(drop = True, inplace = True) # Reset index

# %%
sat_2017.participation = sat_2017.participation.apply(perc_to_dec)
sat_2018.participation = sat_2018.participation.apply(perc_to_dec)
sat_2019.participation = sat_2019.participation.apply(perc_to_dec)

# %%
# Check that values in SAT dataframes are all valid
# Participation is between 0 and 1
# ebrw and math are between 200 and 800
# total is between 400 and 1600
# Code flags out any rows that do not satisfy above criteria -- Maryland flagged out in SAT 2017

print('SAT participation 2017, 2018, 2019')
display(sat_2017[(sat_2017.participation < 0) | (sat_2017.participation > 1)])
display(sat_2018[(sat_2018.participation < 0) | (sat_2018.participation > 1)])
display(sat_2019[(sat_2019.participation < 0) | (sat_2019.participation > 1)])
print('\n\nebrw 2017, 2018, 2019')
display(sat_2017[(sat_2017.ebrw < 200) | (sat_2017.ebrw > 800)])
display(sat_2018[(sat_2018.ebrw < 200) | (sat_2018.ebrw > 800)])
display(sat_2019[(sat_2019.ebrw < 200) | (sat_2019.ebrw > 800)])
print('\n\nmath 2017, 2018, 2019')
display(sat_2017[(sat_2017.math < 200) | (sat_2017.math > 800)])
display(sat_2018[(sat_2018.math < 200) | (sat_2018.math > 800)])
display(sat_2019[(sat_2019.math < 200) | (sat_2019.math > 800)])
print('\n\ntotal 2017, 2018, 2019')
display(sat_2017[(sat_2017.total < 400) | (sat_2017.total > 1600)])
display(sat_2018[(sat_2018.total < 400) | (sat_2018.total > 1600)])
display(sat_2019[(sat_2019.total < 400) | (sat_2019.total > 1600)])
# Out:
# SAT participation 2017, 2018, 2019
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# ebrw 2017, 2018, 2019
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# math 2017, 2018, 2019
#        state  participation  ebrw  math  total
# 20  Maryland           0.69   536    52   1060
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# total 2017, 2018, 2019
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# Empty DataFrame
# ...

# %%
# Since Maryland's total score is 1060, math score should be total - ebrw = 1060 - 536 = 524
# There was likely a typo when entering math score by keying in one less digit
# Correct this math score back to 524
sat_2017.math[20] = 524
# Out:
# /var/folders/f5/csz5_csd4c11cy5h6lqwj2nw0000gp/T/ipykernel_73397/520802374.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_2017.math[20] = 524

# %%
# Check that total score is within +-1 of sum of ebrw and math scores
display(sat_2017[abs(sat_2017.ebrw + sat_2017.math - sat_2017.total) > 1])
display(sat_2018[abs(sat_2018.ebrw + sat_2018.math - sat_2018.total) > 1])
display(sat_2019[abs(sat_2019.ebrw + sat_2019.math - sat_2019.total) > 1])
# Out:
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []
# Empty DataFrame
# Columns: [state, participation, ebrw, math, total]
# Index: []

# %%
# Save cleaned datasets
act_2017.to_csv('../data/act_2017_clean.csv')
act_2018.to_csv('../data/act_2018_clean.csv')
act_2019.to_csv('../data/act_2019_clean.csv')
sat_2017.to_csv('../data/sat_2017_clean.csv')
sat_2018.to_csv('../data/sat_2018_clean.csv')
sat_2019.to_csv('../data/sat_2019_clean.csv')

# %%
# Merge ACT data over 3 years, ignoring subsection scores from 2017 dataframe
# Inner merge used so National data will not be included
act_merged = act_2019.merge(act_2018, on = 'state', suffixes = ('', '_2018'))\
                .merge(act_2017[['state', 'participation', 'composite']], on = 'state', suffixes = ('_2019', '_2017'))

# Merge SAT data over 3 years
sat_merged = sat_2019.merge(sat_2018, on = 'state', suffixes = ('', '_2018'))\
                .merge(sat_2017, on = 'state', suffixes = ('_2019', '_2017'))

# Merge ACT and SAT participation data
act_sat_participation = act_merged[['state', 'participation_2019', 'participation_2018', 'participation_2017']]\
                        .merge(sat_merged[['state', 'participation_2019', 'participation_2018', 'participation_2017']],\
                               on = 'state', suffixes = ('_act','_sat'))

# %%
# Save merged datasets
act_merged.to_csv('../data/act_merged.csv')
sat_merged.to_csv('../data/sat_merged.csv')
act_sat_participation.to_csv('../data/act_sat_participation.csv')

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset(s)|Description|
# |---|---|---|---|
# |**state**|*object*|**ALL**|Name of each of the 50 states in US and District of Columbia (ACT_2019/2017 also includes National)|
# |**participation**|*float*|**ALL**|Participation rate (value between 0 and 1)|
# |**composite**|*float*|ACT|Average composite ACT score (value between 1 and 36)|
# |**english**|*float*|ACT_2017|Average ACT score for English section (value between 1 and 36)|
# |**math**|*float*|ACT_2017|Average ACT score for Math section (value between 1 and 36)|
# |**reading**|*float*|ACT_2017|Average ACT score for Reading section (value between 1 and 36)|
# |**science**|*float*|ACT_2017|Average ACT score for Science section (value between 1 and 36)|
# |**ebrw**|*integer*|SAT|Average SAT score for Evidence-Based Reading and Writing section (value between 200 and 800)|
# |**math**|*integer*|SAT|Average SAT score for Math section (value between 200 and 800)|
# |**total**|*integer*|SAT|Average SAT total score (value between 400 and 1600)|
#
# Note: Features in merged files are tagged with '_201X' to indicate the year, and '_act' or '_sat' to indicate which test as necessary.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Summary statistics
# We use the merged file for ACT as we do not want to include 'National'
print('ACT')
display(act_merged.describe())
print('\n\nSAT')
display(sat_merged.describe())

# We separately find statistics for ACT 2017 as it contains more details on scores of subsections
# We ignore first row that contains info on 'National'
print('\n\nACT 2017')
display(act_2017[1:].describe())
# Out:
# ACT
#        participation_2019  composite_2019  participation_2018  composite_2018  \
# count           51.000000       51.000000           51.000000       51.000000
# mean             0.586667       21.464706            0.617255       21.496078
# std              0.345159        2.194523            0.340371        2.111583
# min              0.060000       17.900000            0.070000       17.700000
# 25%              0.245000       19.800000            0.285000       19.950000
# 50%              0.540000       21.100000            0.660000       21.300000
# 75%              1.000000       23.700000            1.000000       23.650000
# max              1.000000       25.500000            1.000000       25.600000
#
#        participation_2017  composite_2017
# count           51.000000       51.000000
# mean             0.652549       21.519608
# std              0.321408        2.020695
# min              0.080000       17.800000
# 25%              0.310000       19.800000
# ...

# %%
print('ACT 2017 National')
display(act_2017.head(1))
# Out:
# ACT 2017 National
#       state  participation  english  math  reading  science  composite
# 0  National            0.6     20.3  20.7     21.4     21.0       21.0

# %% [markdown]
# ### Mean values
# Comparing the ACT 2017 mean values found by averaging the 50 states + D.C. to the National values provided,
# computed values are higher than provided values. This is possibly because distribution of test-takers and population sizes in various states are uneven.

# %%
# Calculate standard deviations for all features in ACT and SAT merged dataframes
act_std = {x: round(std_dev(act_merged[x]), 3) for x in act_merged.set_index('state')}
sat_std = {x: round(std_dev(sat_merged[x]), 3) for x in sat_merged.set_index('state')}

# Calculate standard deviations for features in ACT 2017 excluding 'National'
act_2017_std = {x: round(std_dev(act_2017[1:][x]), 3) for x in act_2017[1:].set_index('state')}

# %%
# Print dictionaries of standard deviations
print('ACT standard deviations')
display(act_std)
print('\n\nSAT standard deviations')
display(sat_std)
print('\n\nACT 2017 standard deviations')
display(act_2017_std)
# Out:
# ACT standard deviations
# {'participation_2019': 0.342,
#  'composite_2019': 2.173,
#  'participation_2018': 0.337,
#  'composite_2018': 2.091,
#  'participation_2017': 0.318,
#  'composite_2017': 2.001}
# SAT standard deviations
# {'participation_2019': 0.384,
#  'ebrw_2019': 45.792,
#  'math_2019': 50.785,
#  'total_2019': 96.24,
#  'participation_2018': 0.369,
#  'ebrw_2018': 47.035,
#  'math_2018': 47.302,
#  'total_2018': 93.227,
#  'participation_2017': 0.349,
#  'ebrw_2017': 45.217,
#  'math_2017': 46.657,
#  'total_2017': 91.584}
# ACT 2017 standard deviations
# {'participation': 0.318,
#  'english': 2.33,
#  'math': 1.962,
#  'reading': 2.047,
#  'science': 1.736,
#  'composite': 2.001}

# %% [markdown]
# ### Standard deviations
# Standard deviations provided by pandas describe method are all higher than the ones calculated using our own function.
# This is because the describe method treats the data as a sample and calculates the unbiased estimate for population standard deviation, adjusting for the degree of freedom by dividing by (sample size - 1) instead of (sample size) in the formula.
#
# We verify this below by creating another function called unbiased_std_dev and checking that the values tally.

# %%
# Calculate unbiased estimates of standard deviations for all features in ACT and SAT merged dataframes
act_unbiased_std = {x: round(unbiased_std_dev(act_merged[x]), 3) for x in act_merged.set_index('state')}
sat_unbiased_std = {x: round(unbiased_std_dev(sat_merged[x]), 3) for x in sat_merged.set_index('state')}

# Calculate standard deviations for features in ACT 2017 excluding 'National'
act_2017_unbiased_std = {x: round(unbiased_std_dev(act_2017[1:][x]), 3) for x in act_2017[1:].set_index('state')}

# %%
# Print dictionaries of unbiased estimates of standard deviations
print('ACT unbiased estimates of standard deviations')
display(act_unbiased_std)
print('\n\nSAT unbiased estimates of standard deviations')
display(sat_unbiased_std)
print('\n\nACT 2017 unbiased estimates of standard deviations')
display(act_2017_unbiased_std)
# Out:
# ACT unbiased estimates of standard deviations
# {'participation_2019': 0.345,
#  'composite_2019': 2.195,
#  'participation_2018': 0.34,
#  'composite_2018': 2.112,
#  'participation_2017': 0.321,
#  'composite_2017': 2.021}
# SAT unbiased estimates of standard deviations
# {'participation_2019': 0.387,
#  'ebrw_2019': 46.248,
#  'math_2019': 51.291,
#  'total_2019': 97.198,
#  'participation_2018': 0.373,
#  'ebrw_2018': 47.503,
#  'math_2018': 47.773,
#  'total_2018': 94.155,
#  'participation_2017': 0.353,
#  'ebrw_2017': 45.667,
#  'math_2017': 47.121,
#  'total_2017': 92.495}
# ACT 2017 unbiased estimates of standard deviations
# {'participation': 0.321,
#  'english': 2.354,
#  'math': 1.982,
#  'reading': 2.067,
#  'science': 1.753,
#  'composite': 2.021}

# %%
# Find states with highest and lowest participation rates for ACT
print('ACT 2017 highest and lowest participation')
display(act_2017.sort_values(['participation', 'state']).tail(20))
display(act_2017.sort_values('participation').head(3))
print('\n\nACT 2018 highest and lowest participation')
display(act_2018.sort_values(['participation', 'state']).tail(20))
display(act_2018.sort_values('participation').head(3))
print('\n\nACT 2019 highest and lowest participation')
display(act_2019.sort_values(['participation', 'state']).tail(20))
display(act_2019.sort_values('participation').head(3))
# Out:
# ACT 2017 highest and lowest participation
#              state  participation  english  math  reading  science  composite
# 12          Hawaii           0.90     17.8  19.2     19.2     19.3       19.0
# 14        Illinois           0.93     21.0  21.2     21.6     21.3       21.4
# 35    North Dakota           0.98     19.0  20.4     20.5     20.6       20.3
# 1          Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 4         Arkansas           1.00     18.9  19.0     19.7     19.5       19.4
# 6         Colorado           1.00     20.1  20.3     21.2     20.9       20.8
# 18        Kentucky           1.00     19.6  19.4     20.5     20.1       20.0
# 19       Louisiana           1.00     19.4  18.8     19.8     19.6       19.5
# 24       Minnesota           1.00     20.4  21.5     21.8     21.6       21.5
# 25     Mississippi           1.00     18.2  18.1     18.8     18.8       18.6
# ...

# %%
# Find states with highest and lowest participation rates for SAT
print('SAT 2017 highest and lowest participation')
display(sat_2017.sort_values(['participation', 'state']).tail())
display(sat_2017.sort_values(['participation', 'state']).head())
print('\n\nSAT 2018 highest and lowest participation')
display(sat_2018.sort_values(['participation', 'state']).tail(8))
display(sat_2018.sort_values(['participation', 'state']).head())
print('\n\nSAT 2019 highest and lowest participation')
display(sat_2019.sort_values(['participation', 'state']).tail(10))
display(sat_2019.sort_values(['participation', 'state']).head())
# Out:
# SAT 2017 highest and lowest participation
#                    state  participation  ebrw  math  total
# 29         New Hampshire           0.96   532   520   1052
# 6            Connecticut           1.00   530   512   1041
# 7               Delaware           1.00   503   492    996
# 8   District of Columbia           1.00   482   468    950
# 22              Michigan           1.00   509   495   1005
#            state  participation  ebrw  math  total
# 15          Iowa           0.02   641   635   1275
# 24   Mississippi           0.02   634   607   1242
# 34  North Dakota           0.02   635   621   1256
# 3       Arkansas           0.03   614   594   1208
# 23     Minnesota           0.03   644   651   1295
# SAT 2018 highest and lowest participation
#            state  participation  ebrw  math  total
# 39  Rhode Island           0.97   513   505   1018
# 13      Illinois           0.99   513   506   1019
# 19         Maine           0.99   512   501   1013
# ...

# %%
# Find states with highest and lowest composite scores for ACT
print('ACT 2017 highest and lowest composite')
display(act_2017.sort_values('composite').tail(3))
display(act_2017.sort_values('composite').head(3))
print('\n\nACT 2018 highest and lowest composite')
display(act_2018.sort_values('composite').tail(3))
display(act_2018.sort_values('composite').head(3))
print('\n\nACT 2019 highest and lowest composite')
display(act_2019.sort_values('composite').tail(3))
display(act_2019.sort_values('composite').head(3))
# Out:
# ACT 2017 highest and lowest composite
#             state  participation  english  math  reading  science  composite
# 7     Connecticut           0.31     25.5  24.6     25.6     24.6       25.2
# 22  Massachusetts           0.29     25.4  25.3     25.9     24.7       25.4
# 30  New Hampshire           0.18     25.4  25.1     26.0     24.9       25.5
#              state  participation  english  math  reading  science  composite
# 29          Nevada            1.0     16.3  18.0     18.1     18.2       17.8
# 25     Mississippi            1.0     18.2  18.1     18.8     18.8       18.6
# 41  South Carolina            1.0     17.5  18.6     19.1     18.9       18.7
# ACT 2018 highest and lowest composite
#             state  participation  composite
# 30  New Hampshire           0.16       25.1
# 22  Massachusetts           0.25       25.5
# 6     Connecticut           0.26       25.6
#              state  participation  composite
# 29          Nevada            1.0       17.7
# ...

# %%
# Find states with highest and lowest total scores for SAT
print('SAT 2017 highest and lowest total')
display(sat_2017.sort_values('total').tail(3))
display(sat_2017.sort_values('total').head(3))
print('\n\nSAT 2018 highest and lowest total')
display(sat_2018.sort_values('total').tail(3))
display(sat_2018.sort_values('total').head(3))
print('\n\nSAT 2019 highest and lowest total')
display(sat_2019.sort_values('total').tail(3))
display(sat_2019.sort_values('total').head(3))
# Out:
# SAT 2017 highest and lowest total
#         state  participation  ebrw  math  total
# 15       Iowa           0.02   641   635   1275
# 49  Wisconsin           0.03   642   649   1291
# 23  Minnesota           0.03   644   651   1295
#                    state  participation  ebrw  math  total
# 8   District of Columbia           1.00   482   468    950
# 7               Delaware           1.00   503   492    996
# 12                 Idaho           0.93   513   493   1005
# SAT 2018 highest and lowest total
#            state  participation  ebrw  math  total
# 34  North Dakota           0.02   640   643   1283
# 49     Wisconsin           0.03   641   653   1294
# 23     Minnesota           0.04   643   655   1298
#                    state  participation  ebrw  math  total
# 8   District of Columbia           0.92   497   480    977
# 7               Delaware           1.00   505   492    998
# 48         West Virginia           0.28   513   486    999
# ...

# %% [markdown]
# ### States with the highest and lowest participation rates
#
# |Test|Year|State(s) with highest participation (rate) [Number of states]|State(s) with lowest participation (rate) [Number of states]|
# |---|---|---|---|
# |ACT|2017|Alabama, Arkansas, Colorado, Kentucky, Louisiana, Minnesota, Mississippi, Missouri, Montana, Nevada, North Carolina, Oklahama, South Carolina, Tennessee, Utah, Wisconsin, Wyoming (100%) [17]|Maine (8%) [1]|
# |ACT|2018|Alabama, Arkansas, Kentucky, Louisiana, Mississippi, Missouri, Montana, Nebraska, Nevada, North Carolina, Ohio, Oklahama, South Carolina, Tennessee, Utah, Wisconsin, Wyoming (100%) [17]|Maine (7%) [1]|
# |ACT|2019|Alabama, Arkansas, Kentucky, Louisiana, Mississippi, Montana, Nebraska, Nevada, North Carolina, Ohio, Oklahama, Tennessee, Utah, Wisconsin, Wyoming (100%) [15]|Maine (6%) [1]|
# |SAT|2017|Connecticut, Delaware, District of Columbia, Michigan (100%) [4]|Iowa, Mississippi, North Dakota (2%) [3]|
# |SAT|2018|Colorado, Connecticut, Delaware, Idaho, Michigan (100%) [5]|North Dakota (2%) [1]|
# |SAT|2019|Colorado, Connecticut, Delaware, Florida, Idaho, Illinois, Michigan, Rhode Island (100%) [8]|North Dakota (2%) [1]|
#
# ### States with the highest and lowest mean scores
# |Test|Year|State(s) with highest mean scores (score)|State(s) with lowest mean scores (score)|
# |---|---|---|---|
# |ACT|2017|New Hampshire (25.5)|Nevada (17.8)|
# |ACT|2018|Connecticut (25.6)|Nevada (17.7)|
# |ACT|2019|Connecticut, Massachusetts (25.5)|Nevada (17.9)|
# |SAT|2017|Minnesota (1295)|District of Columbia (950)|
# |SAT|2018|Minnesota (1298)|District of Columbia (977)|
# |SAT|2019|Minnesota (1284)|West Virginia (943)|

# %%
# For use in presentation
# Number of states with 100% participation rate in either test 
plt.style.use('seaborn-bright')
plt.style.use('seaborn-white')
plt.style.use('seaborn-talk')
years = ['2017', '2018', '2019']
n_states_act = [17, 17, 15]
n_states_sat = [4, 5, 8]
plt.bar(years, n_states_act, label = 'ACT', width = 0.5)
plt.bar(years, n_states_sat, bottom = n_states_act, label = 'SAT', width = 0.5)
plt.legend(loc = 'upper left')
plt.title('Number of States with 100% Participation Rate')
plt.xlabel('Year')
plt.ylabel('Number of States')
plt.show()

# %%
# Filter out states with 100% participation in ACT for all 3 years
act_100 = act_sat_participation[(act_sat_participation.participation_2017_act == 1) 
                                &(act_sat_participation.participation_2018_act == 1) 
                                &(act_sat_participation.participation_2019_act == 1)
                               ]
# Filter out states with 100% participation in SAT for all 3 years
sat_100 = act_sat_participation[(act_sat_participation.participation_2017_sat == 1) 
                                &(act_sat_participation.participation_2018_sat == 1) 
                                &(act_sat_participation.participation_2019_sat == 1)
                               ]
print('ACT 100% in all 3 years')
display(act_100)
print('\n\nSAT 100% in all 3 years')
display(sat_100)
# Out:
# ACT 100% in all 3 years
#              state  participation_2019_act  participation_2018_act  \
# 0          Alabama                     1.0                     1.0
# 3         Arkansas                     1.0                     1.0
# 17        Kentucky                     1.0                     1.0
# 18       Louisiana                     1.0                     1.0
# 24     Mississippi                     1.0                     1.0
# 26         Montana                     1.0                     1.0
# 28          Nevada                     1.0                     1.0
# 33  North Carolina                     1.0                     1.0
# 36        Oklahoma                     1.0                     1.0
# 42       Tennessee                     1.0                     1.0
# 44            Utah                     1.0                     1.0
# 49       Wisconsin                     1.0                     1.0
# 50         Wyoming                     1.0                     1.0
#
# ...

# %% [markdown]
# ### States with 100% participation in all three years
# There are 13 states with 100% participation rate in ACT for all three years, and only 3 states with 100% participation rate in SAT for all three years.

# %%
# Filter out states with 100% participation in ACT for some but not all 3 years
act_any_100 = act_sat_participation[(act_sat_participation.participation_2017_act == 1) 
                                    |(act_sat_participation.participation_2018_act == 1) 
                                    |(act_sat_participation.participation_2019_act == 1)
                                   ]
act_some_100 = act_sat_participation.iloc[(i for i in act_any_100.index if i not in act_100.index)]
print('ACT 100% in some years')
display(act_some_100)

# Filter out states with 100% participation in SAT for some but not all 3 years
sat_any_100 = act_sat_participation[(act_sat_participation.participation_2017_sat == 1) 
                                    |(act_sat_participation.participation_2018_sat == 1) 
                                    |(act_sat_participation.participation_2019_sat == 1)
                                   ]
sat_some_100 = act_sat_participation.iloc[(i for i in sat_any_100.index if i not in sat_100.index)]
print('\n\nSAT 100% in some years')
display(sat_some_100)
# Out:
# ACT 100% in some years
#              state  participation_2019_act  participation_2018_act  \
# 5         Colorado                    0.27                    0.30
# 23       Minnesota                    0.95                    0.99
# 25        Missouri                    0.82                    1.00
# 27        Nebraska                    1.00                    1.00
# 35            Ohio                    1.00                    1.00
# 40  South Carolina                    0.78                    1.00
#
#     participation_2017_act  participation_2019_sat  participation_2018_sat  \
# 5                     1.00                    1.00                    1.00
# 23                    1.00                    0.04                    0.04
# 25                    1.00                    0.04                    0.04
# 27                    0.84                    0.03                    0.03
# 35                    0.75                    0.19                    0.18
# ...

# %% [markdown]
# ### Notable changes to ACT participation rates
# 4 states with 100% participation rate in 2017 had decreased participation rates over the years. Participation rates in Minnesota declined very slightly to 95% in 2019, while those in Missouri and South Carolina declined to 82% and 78% respectively in 2019.
#
# Colorado had the most drastic decline from 100% to 30% in 2018 and then 27% in 2019.
#
# On the other hand, 2 states, namely Nebraska and Ohio, increased their participation rates from 84% and 75% respectively in 2017 to 100% in both 2018 and 2019.
#
# ### Notable changes to SAT participation rates
# District of Columbia was the only region to see a slight decline in participation rate from 100% in 2017 to over 90% in both 2018 and 2019.
#
# 5 states increased their participation rates to 100% by 2019. Idaho started off high at 93% in 2017 and hit 100% in both 2018 and 2019. Florida was at 83% in 2017, decreased to 56% in 2018 and recovered sharply to 100% in 2019. Rhode Island jumped from 71% in 2017 to almost 100% in 2018 and hit 100% in 2019.
#
# Most remarkably, Colorado and Illinois had very low participation rates of just 11% and 9% respectively in 2017, but rose very sharply to 100% and 99% respectively within a year in 2018.

# %%
both_50_2017 = act_sat_participation[(act_sat_participation.participation_2017_act > 0.5) 
                                     & (act_sat_participation.participation_2017_sat > 0.5)
                                    ]
both_50_2018 = act_sat_participation[(act_sat_participation.participation_2018_act > 0.5) 
                                     & (act_sat_participation.participation_2018_sat > 0.5)
                                    ]
both_50_2019 = act_sat_participation[(act_sat_participation.participation_2019_act > 0.5) 
                                     & (act_sat_participation.participation_2019_sat > 0.5)
                                    ]
print('States with more than 50% participation in both tests')
display(both_50_2017[['state', 'participation_2017_act', 'participation_2017_sat']])
display(both_50_2018[['state', 'participation_2018_act', 'participation_2018_sat']])
display(both_50_2019[['state', 'participation_2019_act', 'participation_2019_sat']])
# Out:
# States with more than 50% participation in both tests
#       state  participation_2017_act  participation_2017_sat
# 9   Florida                    0.73                    0.83
# 10  Georgia                    0.55                    0.61
# 11   Hawaii                    0.90                    0.55
#              state  participation_2018_act  participation_2018_sat
# 9          Florida                    0.66                    0.56
# 10         Georgia                    0.53                    0.70
# 11          Hawaii                    0.89                    0.56
# 33  North Carolina                    1.00                    0.52
# 40  South Carolina                    1.00                    0.55
#              state  participation_2019_act  participation_2019_sat
# 9          Florida                    0.54                    1.00
# 11          Hawaii                    0.80                    0.54
# 33  North Carolina                    1.00                    0.51
# ...

# %% [markdown]
# ### States with more than 50% participation on both tests
#
# Some states had more than 50% participation on both tests, meaning there must have been some students who took both tests.
#
# Florida and Hawaii had more than 50% participation on both tests in all 3 years. For Florida, there was no strong preference for choice of test in 2017 and 2018, but in 2019 the SAT participation rate shot to 100%, though more than half (54%) took ACT in addition to SAT. For Hawaii, ACT was preferred with a 80%-90% participation rate while SAT maintained a participation rate of 50%-60%.
#
# Georgia had slightly more than 50% participation (50%-70%) on both tests in 2017 and 2018 but not in 2019.
#
# North and South Carolina had 100% ACT participation in 2018 and slightly more than half (52% and 54%) took SAT in addition to ACT. North Carolina maintained the same rates in 2019 (100% ACT and 51% SAT) while South Carolina saw more students switching from ACT to SAT (78% ACT and 68% SAT).

# %% [markdown]
# ## Visualize the Data

# %%
# Heatmaps
display(sns.heatmap(act_sat_participation.corr(), annot = True))
plt.title('Correlations of ACT and SAT participation rates')
plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Interpretation of correlations between participation rates
# There are very strong positive correlations between the participation rates of the same test across different years, though ACT shows a stronger correlation than SAT, meaning there was more changes to participation rates for SAT from 2017 to 2019.
#
# There are strong negative correlations between the participation rates of different tests, meaning for states with high participation rates for ACT, they would have lower participation rates for SAT and vice versa.

# %%
display(sns.heatmap(act_merged.corr(), annot = True))
plt.title('Correlations of ACT participation rates and composite scores')
plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Interpretation of correlations between ACT participation rates and composite scores
# There are strong negative correlations between ACT participation rates and composite scores, meaning for states with high participation rates, they would have lower composite scores.

# %%
plt.figure(figsize = (10,8))
display(sns.heatmap(sat_merged.corr(), annot = True))
plt.title('Correlations of SAT participation rates and scores')
plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Interpretation of correlations between SAT participation rates and scores
# There are moderately strong negative correlations between SAT participation rates and scores, meaning for states with high participation rates, they would have lower composite scores.
#
# The correlation between SAT participation rate 2017 and scores in both 2018 and 2019 is relatively weaker than the others, meaning that higher SAT participation rate in 2017 may not as accurately predict lower scores in 2018 and 2019.

# %%
# Histograms
fig, axes = plt.subplots(2, 3, figsize=(15, 5), sharey=True)
fig.suptitle('Distributions of ACT Participation Rates and Composite Scores in 2017 to 2019', fontsize = 24)

sns.histplot(ax=axes[0,0], x=act_merged['participation_2017'], bins = 10)
sns.histplot(ax=axes[0,1], x=act_merged['participation_2018'], bins = 10)
sns.histplot(ax=axes[0,2], x=act_merged['participation_2019'], bins = 10)

sns.histplot(ax=axes[1, 0], x=act_merged['composite_2017'], bins = 10)
sns.histplot(ax=axes[1, 1], x=act_merged['composite_2018'], bins = 10)
sns.histplot(ax=axes[1, 2], x=act_merged['composite_2019'], bins = 10)

plt.tight_layout()

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 5), sharey=True)
fig.suptitle('Distributions of SAT Participation Rates and Total Scores in 2017 to 2019', fontsize = 24)

sns.histplot(ax=axes[0,0], x=sat_merged['participation_2017'], bins = 10)
sns.histplot(ax=axes[0,1], x=sat_merged['participation_2018'], bins = 10)
sns.histplot(ax=axes[0,2], x=sat_merged['participation_2019'], bins = 10)

sns.histplot(ax=axes[1, 0], x=sat_merged['total_2017'], bins = 10)
sns.histplot(ax=axes[1, 1], x=sat_merged['total_2018'], bins = 10)
sns.histplot(ax=axes[1, 2], x=sat_merged['total_2019'], bins = 10)

plt.tight_layout()

# %% [markdown]
# ### Distributions of Participation Rates and Scores
# The participation rates are NOT normally distributed, but instead have multiple peaks.
#
# For ACT, the primary peak is at 100% and they have a secondary peak at around 30%. The secondary peak shifted down to around 20%, showing that there is a general decline in ACT participation rates over the years.
#
# For SAT, the primary peak is at 0%, with 2 more secondary peaks at around 65% and at 100%. The peak at 0% decreased while the peak at 100% increased over the years, showing that there is a general increase in SAT participation rates over the years.
#
# The scores are also NOT normally distributed, but instead appear to have 2 peaks.
#
# For ACT, the peaks are at around 20 and 24, and these peaks appear to shift outwards over the years, meaning that more students scored at the extreme ends (poorly or well) than students who scored average.
#
# For SAT, the peaks are at around 1080 and 1240, and these peaks appear to flatten out over the years such that the distribution became more uniform.

# %%
# Boxplots
fig, axes = plt.subplots(2, 3, figsize=(5, 8))
fig.suptitle('Boxplots of ACT Participation Rates and Composite Scores in 2017 to 2019', fontsize = 24)

sns.boxplot(ax=axes[0,0], y=act_merged['participation_2017'])
sns.boxplot(ax=axes[0,1], y=act_merged['participation_2018'])
sns.boxplot(ax=axes[0,2], y=act_merged['participation_2019'])

sns.boxplot(ax=axes[1, 0], y=act_merged['composite_2017'])
sns.boxplot(ax=axes[1, 1], y=act_merged['composite_2018'])
sns.boxplot(ax=axes[1, 2], y=act_merged['composite_2019'])

plt.tight_layout()

# %%
fig, axes = plt.subplots(2, 3, figsize=(5, 8))
fig.suptitle('Boxplots of SAT Participation Rates and Total Scores in 2017 to 2019', fontsize = 24)

sns.boxplot(ax=axes[0,0], y=sat_merged['participation_2017'])
sns.boxplot(ax=axes[0,1], y=sat_merged['participation_2018'])
sns.boxplot(ax=axes[0,2], y=sat_merged['participation_2019'])

sns.boxplot(ax=axes[1, 0], y=sat_merged['total_2017'])
sns.boxplot(ax=axes[1, 1], y=sat_merged['total_2018'])
sns.boxplot(ax=axes[1, 2], y=sat_merged['total_2019'])

plt.tight_layout()

# %% [markdown]
# ### Interpretation of boxplots
# The boxplots show that ACT participation rates declined (median decreased from 69% to 54%) while SAT participation rates increased (median increased from 38% to 54%).
#
# For the scores, no significant changes are seen over the years, except that the interquartile range increased for the SAT total scores in 2019, meaning that the range of scores for the middle 50% scorers was wider.

# %%
# For use in presentation
# To create boxplots below

boxplot_sat_2017 = sat_2017[['participation']]
boxplot_sat_2017['year'] = '2017'
boxplot_sat_2018 = sat_2018[['participation']]
boxplot_sat_2018['year'] = '2018'
boxplot_sat_2019 = sat_2019[['participation']]
boxplot_sat_2019['year'] = '2019'
boxplot_sat = pd.concat([boxplot_sat_2017, boxplot_sat_2018, boxplot_sat_2019])
boxplot_sat['test'] = 'SAT'

boxplot_act_2017 = act_2017[act_2017.state != 'National'][['participation']]
boxplot_act_2017['year'] = '2017'
boxplot_act_2018 = act_2018[['participation']]
boxplot_act_2018['year'] = '2018'
boxplot_act_2019 = act_2019[act_2019.state != 'National'][['participation']]
boxplot_act_2019['year'] = '2019'
boxplot_act = pd.concat([boxplot_act_2017, boxplot_act_2018, boxplot_act_2019])
boxplot_act['test'] = 'ACT'

boxplot_data = pd.concat([boxplot_act, boxplot_sat])
# Out:
# /var/folders/f5/csz5_csd4c11cy5h6lqwj2nw0000gp/T/ipykernel_73397/1016810807.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxplot_sat_2017['year'] = '2017'
# /var/folders/f5/csz5_csd4c11cy5h6lqwj2nw0000gp/T/ipykernel_73397/1016810807.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxplot_sat_2018['year'] = '2018'
# /var/folders/f5/csz5_csd4c11cy5h6lqwj2nw0000gp/T/ipykernel_73397/1016810807.py:9: SettingWithCopyWarning:
# ...

# %%
# For use in presentation
# Box plots comparing ACT and SAT participation rates

plt.style.use('seaborn-whitegrid')
sns.boxplot(x = 'year', y = 'participation', hue = 'test', data = boxplot_data)
plt.legend(loc = 'upper right', bbox_to_anchor=(1.05, 0.95))
plt.title('Boxplots of ACT and SAT Participation Rates')
plt.xlabel('Year')
plt.ylabel('Participation Rate')
plt.show()

# %%
# Scatter plots
act_sorted = act_sat_participation.sort_values(['participation_2017_act', 
                                                'participation_2018_act', 
                                                'participation_2017_act'
                                               ], ascending = False)
sat_sorted = act_sat_participation.sort_values(['participation_2019_sat', 
                                                'participation_2018_sat', 
                                                'participation_2017_sat'
                                               ], ascending = False)

# %%
# Scatter plot of ACT participation rates over the years
plt.style.use('ggplot')
plt.figure(figsize = (15,6))
plt.scatter(act_sorted.state, act_sorted['participation_2019_act'], alpha = 0.8, color = 'red', marker = '^', label = '2019')
plt.scatter(act_sorted.state, act_sorted['participation_2018_act'], alpha = 0.8, color = 'green', marker = 'x', label = '2018')
plt.scatter(act_sorted.state, act_sorted['participation_2017_act'], alpha = 0.8, color = 'blue', marker = 'v', label = '2017')
plt.xticks(rotation = 90)
plt.legend()
plt.title('ACT Participation Rates in Each State')
plt.xlabel('State')
plt.ylabel('Participation Rate')
plt.show()

# %% [markdown]
# ### Interpretation of scatter plot of ACT participation rates over the years
# There are more 2019 data points (red triangles) below 2017 data points (blue triangles), showing that there is a decreasing trend in ACT participation rates over the years.
#
# Two states in particular, Colorado and Illinois, had drastic decline in their ACT participation rates from more than 90% to less than 40%.

# %%
# Scatter plot of SAT participation rates over the years
plt.style.use('ggplot')
plt.figure(figsize = (15,6))
plt.scatter(sat_sorted.state, sat_sorted['participation_2019_sat'], alpha = 0.8, color = 'red', marker = '^', label = '2019')
plt.scatter(sat_sorted.state, sat_sorted['participation_2018_sat'], alpha = 0.8, color = 'green', marker = 'x', label = '2018')
plt.scatter(sat_sorted.state, sat_sorted['participation_2017_sat'], alpha = 0.8, color = 'blue', marker = 'v', label = '2017')
plt.xticks(rotation = 90)
plt.legend()
plt.title('SAT Participation Rates in Each State')
plt.xlabel('State')
plt.ylabel('Participation Rate')
plt.show()

# %% [markdown]
# ### Interpretation of scatter plot of SAT participation rates over the years
# There are more 2017 data points (blue triangles) below 2019 data points (red triangles), showing that there is an increasing trend in SAT participation rates over the years.
#
# Three states in particular, Colorado, Illinois and West Virginia, had drastic increase in their SAT participation rates from less than 20% to 100% or almost 100%.

# %%
# For use in presentation
# Show trends of SAT vs ACT participation rates in Colorado, Illinois and West Virginia
plt.style.use('seaborn-whitegrid')
colorado_act = [act_2017[act_2017.state=='Colorado'].participation,
                act_2018[act_2018.state=='Colorado'].participation,
                act_2019[act_2019.state=='Colorado'].participation
               ]
illinois_act = [act_2017[act_2017.state=='Illinois'].participation,
                act_2018[act_2018.state=='Illinois'].participation,
                act_2019[act_2019.state=='Illinois'].participation
               ]
w_virginia_act = [act_2017[act_2017.state=='West Virginia'].participation,
                  act_2018[act_2018.state=='West Virginia'].participation,
                  act_2019[act_2019.state=='West Virginia'].participation
                 ]
colorado_sat = [sat_2017[sat_2017.state=='Colorado'].participation,
                sat_2018[sat_2018.state=='Colorado'].participation,
                sat_2019[sat_2019.state=='Colorado'].participation
               ]
illinois_sat = [sat_2017[sat_2017.state=='Illinois'].participation,
                sat_2018[sat_2018.state=='Illinois'].participation,
                sat_2019[sat_2019.state=='Illinois'].participation
               ]
w_virginia_sat = [sat_2017[sat_2017.state=='West Virginia'].participation,
                  sat_2018[sat_2018.state=='West Virginia'].participation,
                  sat_2019[sat_2019.state=='West Virginia'].participation
                 ]
years = ['2017', '2018', '2019']
plt.figure(figsize = (8,10))
plt.plot(years, colorado_act, color = 'r', marker = 'x', label = 'Colorado ACT', linestyle = ':')
plt.plot(years, illinois_act, color = 'b', marker = 'o', label = 'Illinois ACT', linestyle = ':')
plt.plot(years, w_virginia_act, color = 'g', marker = 'd', label = 'West Virginia ACT', linestyle = ':')
plt.plot(years, colorado_sat, color = 'r', marker = 'x', label = 'Colorado SAT', linestyle = '-.')
plt.plot(years, illinois_sat, color = 'b', marker = 'o', label = 'Illinois SAT', linestyle = '-.')
plt.plot(years, w_virginia_sat, color = 'g', marker = 'd', label = 'West Virginia SAT', linestyle = '-.')
plt.legend(loc = 'lower right')
plt.title('SAT Participation Rates in States with Steep Increase')
plt.xlabel('Year')
plt.ylabel('Participation Rate')
plt.show()

# %%
# ACT vs SAT participation rates over the years
sat_sorted_2017 = act_sat_participation.sort_values('participation_2017_sat', ascending = False)
plt.style.use('ggplot')
plt.figure(figsize = (15,6))
plt.scatter(sat_sorted_2017.state, sat_sorted_2017['participation_2017_act'], \
            alpha = 0.8, color = 'red', marker = 'o', label = 'ACT')
plt.scatter(sat_sorted_2017.state, sat_sorted_2017['participation_2017_sat'], \
            alpha = 0.8, color = 'green', marker = 's', label = 'SAT')
plt.xticks(rotation = 90)
plt.legend()
plt.title('2017 ACT/SAT Participation Rates in Each State')
plt.xlabel('State')
plt.ylabel('Participation Rate')
plt.show()

# %%
sat_sorted_2018 = act_sat_participation.sort_values('participation_2018_sat', ascending = False)
plt.figure(figsize = (15,6))
plt.scatter(sat_sorted_2018.state, sat_sorted_2018['participation_2018_act'], \
            alpha = 0.8, color = 'red', marker = 'o', label = 'ACT')
plt.scatter(sat_sorted_2018.state, sat_sorted_2018['participation_2018_sat'], \
            alpha = 0.8, color = 'green', marker = 's', label = 'SAT')
plt.xticks(rotation = 90)
plt.legend()
plt.title('2018 ACT/SAT Participation Rates in Each State')
plt.xlabel('State')
plt.ylabel('Participation Rate')
plt.show()

# %%
plt.figure(figsize = (15,6))
plt.scatter(sat_sorted.state, sat_sorted['participation_2019_act'], \
            alpha = 0.8, color = 'red', marker = 'o', label = 'ACT')
plt.scatter(sat_sorted.state, sat_sorted['participation_2019_sat'], \
            alpha = 0.8, color = 'green', marker = 's', label = 'SAT')
plt.xticks(rotation = 90)
plt.legend()
plt.title('2019 ACT/SAT Participation Rates in Each State')
plt.xlabel('State')
plt.ylabel('Participation Rate')
plt.show()

# %% [markdown]
# ### Interpretation of scatter plots of ACT vs SAT participation rates
# In all 3 years, the participation rates of ACT and SAT have a very strong inverse relationship, meaning that states with high ACT participation rates tended to have low SAT participation rates and vice versa.
#
# In each of the 3 years, only 3 states show no strong preference for one test over the other, with their participation rates being less than 10% apart. They are Florida, Georgia and Oregon in 2017, Alaska, Florida and Oregon in 2018, and Alaska, Oregon and South Carolina in 2019.

# %%
# Scatter plots of SAT Participation Rates vs Total Scores
sat_total_sorted_2017 = sat_2017.sort_values('participation', ascending = False)

fig, ax1 = plt.subplots(figsize = (15,6))

ax1.scatter(sat_total_sorted_2017.state, sat_total_sorted_2017['participation'], \
            alpha = 0.8, color = 'red', marker = 'o', label = 'Participation')

ax2 = ax1.twinx() 
ax2.scatter(sat_total_sorted_2017.state, sat_total_sorted_2017['total'], \
            alpha = 0.8, color = 'green', marker = 's', label = 'Total')
ax1.tick_params(labelrotation=90)
ax1.legend(loc = 'center right')
ax2.legend(loc = 'center right', bbox_to_anchor=(1, 0.4))
ax1.set_title('2017 SAT Participation Rates vs Total Scores in Each State')

ax1.set_ylabel('Participation Rate')
ax2.set_ylabel('Total Score')
plt.show()

# %%
sat_total_sorted_2018 = sat_2018.sort_values('participation', ascending = False)

fig, ax1 = plt.subplots(figsize = (15,6))

ax1.scatter(sat_total_sorted_2018.state, sat_total_sorted_2018['participation'], \
            alpha = 0.8, color = 'red', marker = 'o', label = 'Participation')

ax2 = ax1.twinx() 
ax2.scatter(sat_total_sorted_2018.state, sat_total_sorted_2018['total'], \
            alpha = 0.8, color = 'green', marker = 's', label = 'Total')
ax1.tick_params(labelrotation=90)
ax1.legend(loc = 'center right')
ax2.legend(loc = 'center right', bbox_to_anchor=(1, 0.4))
ax1.set_title('2018 SAT Participation Rates vs Total Scores in Each State')

ax1.set_ylabel('Participation Rate')
ax2.set_ylabel('Total Score')
plt.show()

# %%
sat_total_sorted_2019 = sat_2019.sort_values('participation', ascending = False)

fig, ax1 = plt.subplots(figsize = (15,6))

ax1.scatter(sat_total_sorted_2019.state, sat_total_sorted_2019['participation'], \
            alpha = 0.8, color = 'red', marker = 'o', label = 'Participation')

ax2 = ax1.twinx() 
ax2.scatter(sat_total_sorted_2019.state, sat_total_sorted_2019['total'], \
            alpha = 0.8, color = 'green', marker = 's', label = 'Total')
ax1.tick_params(labelrotation=90)
ax1.legend(loc = 'center right')
ax2.legend(loc = 'center right', bbox_to_anchor=(1, 0.4))
ax1.set_title('2019 SAT Participation Rates vs Total Scores in Each State')

ax1.set_ylabel('Participation Rate')
ax2.set_ylabel('Total Score')
plt.show()

# %% [markdown]
# ### Interpretation of scatter plots of SAT participation rates vs total scores
# In all 3 years, the SAT participation rates and total scores have a very strong inverse relationship, meaning that states with high SAT participation rates tended to have low total scores and vice versa.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# ### Factors influencing SAT participation rates
# Higher SAT participation rates are strongly associated with higher SAT participation rates in other years, lower ACT participation rates, and lower total scores.
#
# #### SAT participation rates in other years
# We are unable to change historical participation rates, thus we should focus on the other 2 factors.
#
# #### Total scores
# It is highly possible that the strong negative correlation is because in states with low participation rates, only the higher ability students took the test. Thus even if we intentionally deflate SAT total scores, this is unlikely to lead to an increase in participation rates.
#
# #### ACT participation rates
# We can work on trying to convince more states to switch over from ACT (or other tests) to SAT.
# In particular, we focus on the three states of Colorado, Illinois and West Virginia, which had drastic increase in their SAT participation rates from less than 20% to 100% or almost 100%. We research into these 3 states to see what happened to cause this change.

# %% [markdown]
# ### Research into specific states
# **Colorado**
# * [Colorado's switch from ACT to SAT](https://www.coloradokids.org/wp-content/uploads/2016/01/ACTvsSAT_FINAL.pdf)
# Since 2001, Colorado has required every high school junior to take the ACT as their 11th grade college entrance
# exam, for which the state covered the cost. In December of 2015, a selection committee voted to adopt SAT as the required test instead.
#
# Among the reasons quoted are:
# 1. The SAT is aligned to the Common Core standards in English and math, which are a part of the Colorado Academic Standards. The redesigned SAT measures the skills and knowledge that evidence shows is critical for college and career readiness, including critical thinking and analytical reasoning.
# 2. In March 2015, College Board partnered with Khan Academy to provide free, personalized test prep for any student with computer access, leveling the playing field for families that might not be able to afford test prep or tutors for their children.
#
# **Illinois**
# * [Illinois moves ahead with new testing plan, replacing ACT with SAT](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
# In 2016, College Board won a three-year, $14.3 million bid to give its exam to all public high school juniors in Illinois.
#
# **West Virginia**
# * [WV chooses SAT as new high school standardized test for juniors](https://www.wvgazettemail.com/news/education/wv-chooses-sat-as-new-high-school-standardized-test-for-juniors/article_b60d2618-4943-56f6-b180-4b4442172ef8.html)
# The West Virginia Department of Education has chosen SAT as the new statewide standardized test to replace the Smarter Balanced exam for high school students in spring 2018.

# %% [markdown]
# ### Recommendations
# 1. Continuously monitor any changes to the Common Core standards and align the SAT to them.
# 2. Actively reach out to the Departments of Education in more states to persuade them of the strengths of the SAT and the benefits it offers to their students.
# 3. Continue partnering with Khan Academy to provide free test prep. Review test prep resources to ensure quality and alignment to the SAT.
